# %% [markdown]
# # setup

# %%
import pickle
import dask.dataframe as dd
cols=[
'text_tokens',
'hashtags',
'tweet_id',
'present_media',
'present_links',
'present_domains',
'tweet_type',
'language',
'timestamp',

'engaged_user_id',
'engaged_follower_count',
'engaged_following_count',
'engaged_is_verified',
'engaged_account_creation_time',

'engaging_user_id',
'engaging_follower_count',
'engaging_following_count',
'engaging_is_verified',
'engaging_account_creation_time',

'engagee_follows_engager',
'reply_engagement_timestamp',
'retweet_engagement_timestamp',
'retweet_with_comment_engagement_timestamp',
'like_engagement_timestamp',
]

col2i={v:k for k,v in enumerate(cols)}
cols_val=cols[:-4]
cols_time=[
'timestamp',
'engaged_account_creation_time',
'engaging_account_creation_time',
'reply_engagement_timestamp',
'retweet_engagement_timestamp',
'retweet_with_comment_engagement_timestamp',
'like_engagement_timestamp',
]

HOME='/tmp/working/data/git/recsys20'
p_in=f'{HOME}/input'

prfx_prep='0312_1'

# %%
df=dd.read_csv(f'{p_in}/trn1e5.tsv',
               sep='\x01',
               header=None,
               names=cols,)

# %%
# %%time
# http://localhost:8888/notebooks/data/git/recsys20/working/prep0311_1.ipynb
i2twttyp=pickle.load(open(f'{p_in}/i2twttyp_{prfx_prep}.p','rb'))
i2lang=pickle.load(open(f'{p_in}/i2lang_{prfx_prep}.p','rb'))
i2hshtg=pickle.load(open(f'{p_in}/i2hshtg_{prfx_prep}.p','rb'))
i2link=pickle.load(open(f'{p_in}/i2link_{prfx_prep}.p','rb'))
i2domn=pickle.load(open(f'{p_in}/i2domn_{prfx_prep}.p','rb'))

def make_x2i(i2x): return {v:k for k,v in enumerate(i2x)}

twttyp2i=make_x2i(i2twttyp)
lang2i=make_x2i(i2lang)
hshtg2i=make_x2i(i2hshtg)
link2i=make_x2i(i2link)
domn2i=make_x2i(i2domn)
# Out:
# CPU times: user 780 ms, sys: 266 ms, total: 1.05 s
# Wall time: 1.04 s

# %%
df.head()
# Out:
#                                          text_tokens  \
# 0  101\t6417\t3410\t3398\t3184\t1909\t56910\t1683...
# 1  101\t14120\t131\t120\t120\t188\t119\t11170\t12...
# 2  101\t62342\t10858\t54439\t19571\t22480\t7831\t...
# 3  101\t58955\t10898\t103305\t1901\t16181\t7168\t...
# 4  101\t2435\t5656\t2594\t8279\t8623\t1925\t64126...
#
#                                             hashtags  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  F0F2FBE57F08E7C4326682B5EDA63E3E\tE78674D32346...
# 4                                                NaN
#
#                            tweet_id present_media  \
# 0  D4D1EBDE74F74C5DA529959AF979625C           NaN
# 1  BFB529DAB6D384EB83E899A72AB3830D         Photo
# 2  519078C7834E9642508F72A6C2D0F3B7           NaN
# 3  52AAE9E33EFAC8C478C57B31A9E31ED1           NaN
# 4  89C1298C55EB3D68E2784F0BFB69E6F8           NaN
#
# ...

# %%
hashtags=df.hashtags.fillna('')
hashtags=hashtags.apply(lambda x: len(x.split('\t')), meta=('hashtags', 'str'))

# %%
hashtags.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    1
# Name: hashtags, dtype: int64

# %%
type(hashtags.values)
# Out:
# dask.array.core.Array

# %%
hashtags.values
# Out:
# dask.array<values, shape=(nan,), dtype=object, chunksize=(nan,), chunktype=numpy.ndarray>

# %%
hashtags.apply(lambda x: len(x), meta=('hashtags', 'list'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py in pandas_dtype(dtype)
#    2049     try:
# -> 2050         npdtype = np.dtype(dtype)
#    2051     except Exception:
#
# TypeError: data type "list" not understood
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-692c1b3a1710> in <module>
# ----> 1 hashtags.apply(lambda x: len(x), meta=('hashtags', 'list'))
#
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/core.py in apply(self, func, convert_dtype, meta, args, **kwds)
#    2960
#    2961         return map_partitions(
# -> 2962             M.apply, self, func, convert_dtype, args, meta=meta, **kwds
#    2963         )
#    2964
#
# ...

# %%
hshtgs=hashtags.apply(lambda x: [hshtg2i[o] for o in x])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/utils.py in raise_on_meta_error(funcname, udf)
#     168     try:
# --> 169         yield
#     170     except Exception as e:
#
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/core.py in _emulate(func, *args, **kwargs)
#    4740     with raise_on_meta_error(funcname(func), udf=kwargs.pop("udf", False)):
# -> 4741         return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#    4742
#
# /opt/conda/lib/python3.6/site-packages/dask/utils.py in __call__(self, obj, *args, **kwargs)
#     880     def __call__(self, obj, *args, **kwargs):
# --> 881         return getattr(obj, self.method)(*args, **kwargs)
#     882
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
# ...

# %%
df['hshtg'] = df.hashtags.fillna('').apply(lambda x: [hshtg2i[o] for o in x.split('\t') if o in lang2i], 
                             meta=('hashtags', 'str')).compute()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-04485e30fc15> in <module>
#       1 df['hshtg'] = df.hashtags.fillna('').apply(lambda x: [hshtg2i[o] for o in x.split('\t') if o in lang2i],
# ----> 2                              meta=('hashtags', 'str')).compute()
#
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/core.py in __setitem__(self, key, value)
#    3278             df = self.assign(**{k: value for k in key})
#    3279         else:
# -> 3280             df = self.assign(**{key: value})
#    3281
#    3282         self.dask = df.dask
#
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/core.py in assign(self, **kwargs)
#    3541         # Figure out columns of the output
#    3542         df2 = self._meta_nonempty.assign(**_extract_meta(kwargs, nonempty=True))
# -> 3543         return elemwise(methods.assign, self, *pairs, meta=df2)
# ...

# %%
df['hashtags']
# Out:
# Dask Series Structure:
# npartitions=1
#     object
#        ...
# Name: hashtags, dtype: object
# Dask Name: getitem, 4 tasks

# %%
df['hashtags']=df.hashtags.map(hshtg2i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-8e2d54a8ae89> in <module>
# ----> 1 df['hashtags']=df.hashtags.map(hshtg2i)
#
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/core.py in map(self, arg, na_action, meta)
#    2795         graph = HighLevelGraph.from_collections(name, dsk, dependencies=[self])
#    2796         if meta is no_default:
# -> 2797             meta = _emulate(M.map, self, arg, na_action=na_action, udf=True)
#    2798         else:
#    2799             meta = make_meta(meta, index=getattr(make_meta(self), "index", None))
#
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/core.py in _emulate(func, *args, **kwargs)
#    4739     """
#    4740     with raise_on_meta_error(funcname(func), udf=kwargs.pop("udf", False)):
# -> 4741         return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#    4742
# ...

# %%
df.tail()
# Out:
#                                              text_tokens hashtags  \
# 99995  101\t56898\t137\t25444\t10797\t32169\t10884\t1...      NaN
# 99996  101\t56898\t137\t174\t61762\t27593\t10129\t131...      NaN
# 99997  101\t11399\t77536\t10107\t117\t10827\t10124\t1...      NaN
# 99998  101\t149\t11403\t11403\t39272\t146\t110014\t11...      NaN
# 99999        101\t10357\t10124\t10435\t11098\t26059\t102      NaN
#
#                                tweet_id present_media  \
# 99995  5742C1A6BA649B9CC9B6CAE5A88FE70F         Photo
# 99996  12DC6C199625D4319832E51451AD480C           NaN
# 99997  35C81BB074E9D4E5C1F8120B0D5DC0CF           NaN
# 99998  DD783F095EFB87458F6DE0B5F117AFE3           NaN
# 99999  54F8D6684A8AC0C8C649C7C26ECB2B9B           NaN
#
#                           present_links                   present_domains  \
# 99995                               NaN                               NaN
# 99996  7A8FDF03CD02A1DCF24A20F7E3602D18  8E98AD4804271F227F16EF65FFE64E89
# ...
