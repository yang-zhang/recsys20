# %% [markdown]
# # start

# %% [markdown]
# from 0320_3_2_lang; random search for params with early stopping

# %% [markdown]
# - https://www.kaggle.com/tilii7/hyperparameter-grid-search-with-xgboost
# - https://www.kaggle.com/c/liberty-mutual-group-property-inspection-prediction/discussion/15235

# %%
PRFX='0321_2'
trntmstmp=1584412344
valtmstmp=1584806233
import datetime
print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (trntmstmp, valtmstmp)])

grand_total=1.5e8
MIN_TM_TRN=1580947200
MIN_TM_TST=1581552000
print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (MIN_TM_TRN, MIN_TM_TST)])

params = {
    'objective': 'binary:logistic',
    'verbosity': 2,
    'eval_metric': ['error', 'logloss'],
    'max_delta_step': 1,
}
num_rounds = 800
# Out:
# ['2020-03-17 02:32:24', '2020-03-21 15:57:13']
# ['2020-02-06 00:00:00', '2020-02-13 00:00:00']

# %% [markdown]
# # setup

# %%
from pathlib import Path
import dask
print('dask.__version__', dask.__version__)
import xgboost as xgb
import dask_xgboost
import dask.dataframe as dd
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, StratifiedKFold
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from dask.distributed import Client
import pickle
import lightgbm as lgb
from tqdm import tqdm
import matplotlib.pyplot as plt

import datetime
def dtnow(): return datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

SEED=101
HOME='/data/git/recsys20'
p_in=f'{HOME}/input'
p_out=f'{HOME}/output/{PRFX}'
Path(p_out).mkdir(exist_ok=True, parents=True)

from sklearn.metrics import precision_recall_curve, auc, log_loss

def compute_prauc(pred, gt):
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return prauc

def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive/float(len(gt))
    return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

cols=[
'toks',
'hshtgs',
'twtid',
'media',
'links',
'domns',
'twttyp',
'lang',
'tm',

'u1id',
'u1_fllwer_cnt',
'u1_fllwng_cnt',
'u1_vrfed',
'u1_create_tm',

'u2id',
'u2_fllwer_cnt',
'u2_fllwng_cnt',
'u2_vrfed',
'u2_create_tm',

'u1_fllw_u2',
'reply_tm',
'retwt_tm',
'retwt_cmmnt_tm',
'like_tm',
]

cols_val = cols[:-4]
cols_tgt_tmstmp=[
    'retwt_tm',
    'reply_tm',
    'like_tm',
    'retwt_cmmnt_tm',
]
cols_tgt=[o.split('_tm')[0] for o in cols_tgt_tmstmp]
tgts             = ['Retweet','Reply','Like','RTwCmnt',]
assert cols_tgt == ['retwt',  'reply','like','retwt_cmmnt',]
ntgts=len(tgts)
# Out:
# dask.__version__ 2.12.0

# %% [markdown]
# # prepare data

# %% [markdown]
# ## get maps from dfval

# %%
# dfval=dd.read_csv(
#     f'{p_in}/val_{valtmstmp}.tsv',
#     sep='\x01', header=None, names=cols_val,)
# lang2cnt=dict(dfval.lang.value_counts().compute())
# ttl=sum(lang2cnt.values())
# lang2perc={k:v/ttl for k,v in lang2cnt.items()}
langs=['D3164C7FBCF2565DDF915B1B3AEFB1DC', '22C448FF81263D4BAF2A176145EE9EAD', '06D61DCBBE938971E1EA0C38BD9B5446', 'ECED8A16BE2A5E8871FD55F4842F16B1', 'B9175601E87101A984A50F8A62A1C374', '4DC22C3F31C5C43721E6B5815A595ED6', '167115458A0DBDFF7E9C0C53A83BAC9B', '125C57F4FA6D4E110983FB11B52EFD4E', '022EC308651FACB02794A8147AEE1B78', 'FA3F382BC409C271E3D6EAF8BE
        df[f'has_media_{media}'] = df.media.fillna('').apply(lambda x: media in x)
    for col in ['hshtgs', 'links', 'domns',]:
        df[f'num_{col}'] = df[col].fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0)
    
    df['twt_age'] = df.tm - tm_min
    df['u1_age']  = df.tm - df.u1_create_tm
    df['u2_age']  = df.tm - df.u2_create_tm
        
    tm_dt=pd.to_datetime(df.tm, unit='s')
    df['tm_dayofweek']=tm_dt.dt.dayofweek
    df['tm_hour']=tm_dt.dt.hour
    
    df['tmdlta_u2u1']  = df.u2_create_tm - df.u1_create_tm
    
    df['u1_fllwer_cnt_by_age'] = df.u1_fllwer_cnt / df.u1_age
    df['u1_fllwng_cnt_by_age'] = df.u2_fllwng_cnt / df.u2_age
    
    for typ in twttyps:
        df[f'twttyp_{typ}']=(df.twttyp==typ).astype('int8')

    for lang in langs:
        df[f'lang_{lang}']=(df.lang==lang).astype('int8')
    if istrn: 
        df[cols_tgt]=df[cols_tgt_tmstmp].notna().astype('int8')
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 
                                       'tm', 'u1_create_tm','u2_create_tm', 'u1id', 'u2id', 'twtid', ]+cols_tgt_tmstmp, )
    else:
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 
                                       'tm', 'u1_create_tm','u2_create_tm', 'u1id', ])        
    return df

# %% [raw]
# ls -hlS $p_in | grep {trntmstmp}

# %%
grand_total
# Out:
# 150000000.0

# %%
grand_total/1e6
# Out:
# 150.0

# %% [raw]
# chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
#                     header=None,names=cols,
#                         chunksize=1e6
#                        )
# for ichnk,df in enumerate(chnks_trn):
#     print(dtnow(), 'chunk', ichnk, df.tm.max())
# ichnk

# %%
chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                    header=None,names=cols, 
                        chunksize=1e4#1e6
                       )

np.random.seed(SEED)
lst_df = []
for ichnk,df in enumerate(chnks_trn):
    print(dtnow(), 'chunk', ichnk)
    df = prp_df(df)    
    lst_df.append(df)
    if ichnk>=0: break
# Out:
# 2020-03-21 19:48:25 chunk 0

# %%
df = pd.concat(lst_df)

# %%
df.shape
# Out:
# (10000, 95)

# %%
df.columns
# Out:
# Index(['u1_fllwer_cnt', 'u1_fllwng_cnt', 'u1_vrfed', 'u2_fllwer_cnt',
#        'u2_fllwng_cnt', 'u2_vrfed', 'u1_fllw_u2', 'len_toks',
#        'has_media_Photo', 'has_media_Video', 'has_media_GIF', 'num_hshtgs',
#        'num_links', 'num_domns', 'twt_age', 'u1_age', 'u2_age', 'tm_dayofweek',
#        'tm_hour', 'tmdlta_u2u1', 'u1_fllwer_cnt_by_age',
#        'u1_fllwng_cnt_by_age', 'twttyp_TopLevel', 'twttyp_Retweet',
#        'twttyp_Quote', 'lang_D3164C7FBCF2565DDF915B1B3AEFB1DC',
#        'lang_22C448FF81263D4BAF2A176145EE9EAD',
#        'lang_06D61DCBBE938971E1EA0C38BD9B5446',
#        'lang_ECED8A16BE2A5E8871FD55F4842F16B1',
#        'lang_B9175601E87101A984A50F8A62A1C374',
#        'lang_4DC22C3F31C5C43721E6B5815A595ED6',
#        'lang_167115458A0DBDFF7E9C0C53A83BAC9B',
#        'lang_125C57F4FA6D4E110983FB11B52EFD4E',
#        'lang_022EC308651FACB02794A8147AEE1B78',
#        'lang_FA3F382BC409C271E3D6EAF8BE4648DD',
#        'lang_9BF3403E0EB7EA8A256DA9019C0B0716',
#        'lang_975B38F44D65EE42A547283787FF5A21',
#        'lang_2996EB2FE8162C076D070A4C8D6532CD',
#        'lang_FF60A88F53E63000266F8B9149E35AD9',
#        'lang_717293301FE296B0B61950D041485825',
#        'lang_3E16B11B7ADE3A22DDFC4423FBCEAD5
#        'lang_F73266A79468BB89C4325FDEDB0B533C',
#        'lang_4690215948DBF6872B8ED1C2BC87B17E',
#        'lang_D18801336202297E6484F634CAC6592E',
#        'lang_2E18F6F53E3CF073911AF0A93BBE5373',
#        'lang_B2235C8B73239FDC5780DD132419833A',
#        'lang_515E873C86EE1577E75FA2387B7FA59E', 'retwt', 'reply', 'like',
#        'retwt_cmmnt'],
#       dtype='object')

# %%
cols_feat=[o for o in df.columns if o not in cols_tgt]

# %%
X,y=df[cols_feat],df[cols_tgt]

# %% [markdown]
# # model

# %%
tgt2scv={}
for i, tgt in enumerate(tgts):
    print(dtnow(), tgt, '*'*80)
    yi=y.iloc[:,i]

    param_dists = {
        'n_estimators': [10, 20],
        'learning_rate': [0.3, 0.1, 0.5, 0.05],
        'max_depth': [6, 4, 5, 7],
        'min_child_weight': [1, 5, 10],
        'gamma': [0, 0.5, 1, 2, 5],
        'subsample': [1.0, 0.8, 0.5],
        'colsample_bytree': [1.0, 0.8, 0.5],
        'max_delta_step': [0,1,5],
    }

    bst = xgb.XGBClassifier(objective='binary:logistic',
                            verbosity=1)
    scv = RandomizedSearchCV(
        estimator=bst,
        param_distributions=param_dists, 
        scoring='neg_log_loss',
        n_iter=2,
        verbose=1,
        random_state=SEED,
        cv=5)
    scv.fit(X,yi)
    tgt2scv[tgt]=scv
# Out:
# 2020-03-21 19:49:14 Retweet ********************************************************************************
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    7.0s finished
# 2020-03-21 19:49:22 Reply ********************************************************************************
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    6.4s finished
# 2020-03-21 19:49:30 Like ********************************************************************************
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    7.1s finished
# 2020-03-21 19:49:38 RTwCmnt ********************************************************************************
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    5.0s finished

# %%
pickle.dump(tgt2scv, open(f"{p_out}/tgt2scv.p", "wb"))

# %%
bst = tgt2bst[tgt]

# %%
tgt2bst={tgt:scv.best_estimator_ for tgt,scv in tgt2scv.items()}
# tgt2evalres={tgt:bst.evals_result() for tgt,bst in tgt2bst.items()}

# %%
def show_feat_importance(bst):
    ax = xgb.plot_importance(bst, height=0.8, max_num_features=9, importance_type='gain')
    ax.grid(False, axis="y")
    ax.set_title('Estimated feature importance')
    plt.show()
#     feat2importance=bst.get_fscore()
#     display(pd.DataFrame([feat2importance.keys(), feat2importance.values()]).T.sort_values(1, ascending=False).head(20))
    display(pd.DataFrame(zip(cols_feat, bst.feature_importances_)).sort_values(1, ascending=False).head(20))

# %% [raw]
# bst.feature_importances_

# %%
for tgt in tgts:
    print(tgt)
    scv=tgt2scv[tgt]
    bst=tgt2bst[tgt]
    display(pd.DataFrame(scv.cv_results_))
    display(scv.best_params_)
    show_feat_importance(bst)
# Out:
# Retweet
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.504667      0.021462         0.049467        0.003226
# 1       0.782516      0.047427         0.056057        0.005895
#
#   param_subsample param_n_estimators param_min_child_weight param_max_depth  \
# 0             0.5                 20                     10               4
# 1             0.5                 20                      5               7
#
#   param_max_delta_step param_learning_rate  ... param_colsample_bytree  \
# 0                    0                0.05  ...                      1
# 1                    0                 0.5  ...                      1
#
#                                               params split0_test_score  \
# 0  {'subsample': 0.5, 'n_estimators': 20, 'min_ch...         -0.402368
# 1  {'subsample': 0.5, 'n_estimators': 20, 'min_ch...         -0.368797
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.400199          -0.402630          -0.400924          -0.400593
# 1          -0.360870          -0.373732          -0.364794          -0.365391
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.401343        0.000975                2
# 1        -0.366717        0.004317                1
#
# [2 rows x 21 columns]
# {'subsample': 0.5,
#  'n_estimators': 20,
#  'min_child_weight': 5,
#  'max_depth': 7,
#  'max_delta_step': 0,
#  'learning_rate': 0.5,
#  'gamma': 0.5,
#  'colsample_bytree': 1.0}
#                                         0         1
# 33  lang_022EC308651FACB02794A8147AEE1B78  0.106217
# 26  lang_22C448FF81263D4BAF2A176145EE9EAD  0.045837
# 25  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC  0.044563
# 30  lang_4DC22C3F31C5C43721E6B5815A595ED6  0.040860
# 8                         has_media_Photo  0.040514
# 34  lang_FA3F382BC409C271E3D6EAF8BE4648DD  0.039598
# 22                        twttyp_TopLevel  0.034333
# 29  lang_B9175601E87101A984A50F8A62A1C374  0.033177
# 32  lang_125C57F4FA6D4E110983FB11B52EFD4E  0.032460
# 28  lang_ECED8A16BE2A5E8871FD55F4842F16B1  0.031284
# 11                             num_hshtgs  0.031142
# 3                           u2_fllwer_cnt  0.030092
# 6                              u1_fllw_u2  0.029746
# 20                   u1_fllwer_cnt_by_age  0.029182
# 27  lang_06D61DCBBE938971E1EA0C38BD9B5446  0.029168
# 1                           u1_fllwng_cnt  0.028625
# 21                   u1_fllwng_cnt_by_age  0.028336
# 23                         twttyp_Retweet  0.028205
# 16                                 u2_age  0.028037
# 7                                len_toks  0.027897
# Reply
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.476568      0.041141         0.051326        0.004199
# 1       0.693369      0.045490         0.054237        0.010993
#
#   param_subsample param_n_estimators param_min_child_weight param_max_depth  \
# 0             0.5                 20                     10               4
# 1             0.5                 20                      5               7
#
#   param_max_delta_step param_learning_rate  ... param_colsample_bytree  \
# 0                    0                0.05  ...                      1
# 1                    0                 0.5  ...                      1
#
#                                               params split0_test_score  \
# 0  {'subsample': 0.5, 'n_estimators': 20, 'min_ch...         -0.260469
# 1  {'subsample': 0.5, 'n_estimators': 20, 'min_ch...         -0.123104
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.260599          -0.260141          -0.261264          -0.260640
# 1          -0.133624          -0.137543          -0.148912          -0.138792
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.260623        0.000366                2
# 1        -0.136395        0.008344                1
#
# [2 rows x 21 columns]
# {'subsample': 0.5,
#  'n_estimators': 20,
#  'min_child_weight': 5,
#  'max_depth': 7,
#  'max_delta_step': 0,
#  'learning_rate': 0.5,
#  'gamma': 0.5,
#  'colsample_bytree': 1.0}
#                                         0         1
# 31  lang_167115458A0DBDFF7E9C0C53A83BAC9B  0.092726
# 17                           tm_dayofweek  0.075466
# 23                         twttyp_Retweet  0.068879
# 12                              num_links  0.056789
# 20                   u1_fllwer_cnt_by_age  0.052626
# 2                                u1_vrfed  0.052332
# 15                                 u1_age  0.048695
# 3                           u2_fllwer_cnt  0.046255
# 0                           u1_fllwer_cnt  0.044600
# 18                                tm_hour  0.043710
# 6                              u1_fllw_u2  0.043612
# 4                           u2_fllwng_cnt  0.043116
# 19                            tmdlta_u2u1  0.043067
# 16                                 u2_age  0.042341
# 21                   u1_fllwng_cnt_by_age  0.039226
# 14                                twt_age  0.038464
# 7                                len_toks  0.037979
# 22                        twttyp_TopLevel  0.037156
# 1                           u1_fllwng_cnt  0.036325
# 28  lang_ECED8A16BE2A5E8871FD55F4842F16B1  0.029866
# Like
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.528725      0.079698         0.049954        0.011247
# 1       0.784918      0.065464         0.058053        0.006928
#
#   param_subsample param_n_estimators param_min_child_weight param_max_depth  \
# 0             0.5                 20                     10               4
# 1             0.5                 20                      5               7
#
#   param_max_delta_step param_learning_rate  ... param_colsample_bytree  \
# 0                    0                0.05  ...                      1
# 1                    0                 0.5  ...                      1
#
#                                               params split0_test_score  \
# 0  {'subsample': 0.5, 'n_estimators': 20, 'min_ch...         -0.631152
# 1  {'subsample': 0.5, 'n_estimators': 20, 'min_ch...         -0.689242
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.633300          -0.637889          -0.635409          -0.632209
# 1          -0.705185          -0.689667          -0.713975          -0.681090
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.633992        0.002405                1
# 1        -0.695832        0.011962                2
#
# [2 rows x 21 columns]
# {'subsample': 0.5,
#  'n_estimators': 20,
#  'min_child_weight': 10,
#  'max_depth': 4,
#  'max_delta_step': 0,
#  'learning_rate': 0.05,
#  'gamma': 0.5,
#  'colsample_bytree': 1.0}
#                                         0         1
# 23                         twttyp_Retweet  0.306469
# 12                              num_links  0.156979
# 22                        twttyp_TopLevel  0.101873
# 21                   u1_fllwng_cnt_by_age  0.071401
# 7                                len_toks  0.034092
# 15                                 u1_age  0.033208
# 2                                u1_vrfed  0.031840
# 8                         has_media_Photo  0.030690
# 0                           u1_fllwer_cnt  0.026737
# 16                                 u2_age  0.025161
# 3                           u2_fllwer_cnt  0.024937
# 19                            tmdlta_u2u1  0.021603
# 4                           u2_fllwng_cnt  0.019962
# 25  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC  0.019407
# 6                              u1_fllw_u2  0.017370
# 20                   u1_fllwer_cnt_by_age  0.016861
# 14                                twt_age  0.014263
# 18                                tm_hour  0.012754
# 26  lang_22C448FF81263D4BAF2A176145EE9EAD  0.012724
# 1                           u1_fllwng_cnt  0.012071
# RTwCmnt
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.358729      0.017837         0.052719        0.008360
# 1       0.541999      0.073828         0.045151        0.011409
#
#   param_subsample param_n_estimators param_min_child_weight param_max_depth  \
# 0             0.5                 20                     10               4
# 1             0.5                 20                      5               7
#
#   param_max_delta_step param_learning_rate  ... param_colsample_bytree  \
# 0                    0                0.05  ...                      1
# 1                    0                 0.5  ...                      1
#
#                                               params split0_test_score  \
# 0  {'subsample': 0.5, 'n_estimators': 20, 'min_ch...         -0.217783
# 1  {'subsample': 0.5, 'n_estimators': 20, 'min_ch...         -0.047324
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.217980          -0.218088          -0.218612          -0.218470
# 1          -0.045464          -0.048928          -0.050728          -0.049446
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.218186        0.000309                2
# 1        -0.048378        0.001820                1
#
# [2 rows x 21 columns]
# {'subsample': 0.5,
#  'n_estimators': 20,
#  'min_child_weight': 5,
#  'max_depth': 7,
#  'max_delta_step': 0,
#  'learning_rate': 0.5,
#  'gamma': 0.5,
#  'colsample_bytree': 1.0}
#                                         0         1
# 8                         has_media_Photo  0.086083
# 15                                 u1_age  0.083041
# 7                                len_toks  0.080136
# 3                           u2_fllwer_cnt  0.075372
# 6                              u1_fllw_u2  0.068290
# 16                                 u2_age  0.065493
# 21                   u1_fllwng_cnt_by_age  0.061296
# 18                                tm_hour  0.058618
# 20                   u1_fllwer_cnt_by_age  0.055059
# 0                           u1_fllwer_cnt  0.054928
# 14                                twt_age  0.052096
# 25  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC  0.047456
# 29  lang_B9175601E87101A984A50F8A62A1C374  0.047254
# 19                            tmdlta_u2u1  0.041623
# 22                        twttyp_TopLevel  0.031731
# 28  lang_ECED8A16BE2A5E8871FD55F4842F16B1  0.031463
# 4                           u2_fllwng_cnt  0.031120
# 1                           u1_fllwng_cnt  0.028941
# 72  lang_F3E1016563360F9434FA986CA86C249C  0.000000
# 66  lang_259A6F6DFD672CB1F883CBEC01B99F2D  0.000000

# %% [markdown]
# ## valid

# %% [raw]
# evalres.keys()

# %%
for tgt in tgts:
    evalres=tgt2evalres[tgt]
    plt.plot(evalres['validation_0']['aucpr'])
    plt.plot(evalres['validation_1']['aucpr'])
    plt.title(f"{tgt} aucpr {len(evalres['validation_0']['aucpr'])} rounds")
    plt.show()
    
    plt.plot(evalres['validation_0']['logloss'])
    plt.plot(evalres['validation_1']['logloss'])
    plt.title(f"{tgt} logloss {len(evalres['validation_0']['logloss'])} rounds")
    plt.show()

# %% [raw]
# tgt2prdtr={}
# tgt2prdvl={}
# for tgt in tgts:
#     print(dtnow(), tgt)
#     bst = tgt2bst[tgt]
#     tgt2prdtr[tgt] = bst.predict_proba(Xtr)[:,1]
#     tgt2prdvl[tgt] = bst.predict_proba(Xvl)[:,1]

# %%
tgt2auc_trn={}
tgt2rce_trn={}
tgt2auc_val={}
tgt2rce_val={}
for itgt, tgt in enumerate(tgts):
    print(tgt)
    prdtr_i, prdvl_i = tgt2prdtr[tgt], tgt2prdvl[tgt]
    ytr_i, yvl_i = tgt2ytr[tgt], tgt2yvl[tgt]
    scr_rocauc_trn = roc_auc_score(ytr_i, prdtr_i)
    scr_rocauc_val = roc_auc_score(yvl_i, prdvl_i)
    scr_auc_trn=compute_prauc(prdtr_i, ytr_i)
    scr_rce_trn=compute_rce(prdtr_i, ytr_i)
    scr_auc_val=compute_prauc(prdvl_i, yvl_i)
    scr_rce_val=compute_rce(prdvl_i, yvl_i)

    tgt2auc_trn[tgt]=scr_auc_trn
    tgt2rce_trn[tgt]=scr_rce_trn
    tgt2auc_val[tgt]=scr_auc_val
    tgt2rce_val[tgt]=scr_rce_val
    
    print('train rocauc:', f'{scr_rocauc_trn:.4f}', 'valid auc:', f'{scr_rocauc_val:.4f}', )
    print('train prauc:', f'{scr_auc_trn:.4f}', 'valid auc:', f'{scr_auc_val:.4f}', )
    print('train rce:', f'{scr_rce_trn:.4f}', 'valid rce:', f'{scr_rce_val:.4f}', )
# Out:
# Retweet
# train rocauc: 0.8694 valid auc: 0.7031
# train prauc: 0.5733 valid auc: 0.2777
# train rce: 23.0915 valid rce: 8.3066
# Reply
# train rocauc: 0.8620 valid auc: 0.7212
# train prauc: 0.2733 valid auc: 0.0510
# train rce: 18.7388 valid rce: 4.8323
# Like
# train rocauc: 0.7526 valid auc: 0.7229
# train prauc: 0.7071 valid auc: 0.6641
# train rce: 14.0143 valid rce: 10.9530
# RTwCmnt
# train rocauc: 0.8332 valid auc: 0.4727
# train prauc: 0.0563 valid auc: 0.0114
# train rce: 1.2702 valid rce: -1.5429

# %%
lsttrn=[]
lstval=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    lsttrn+=[(f'PRAUC {tgt}',tgt2auc_trn[tgt]),
          (f'RCE {tgt}',tgt2rce_trn[tgt])]
    lstval+=[(f'PRAUC {tgt}',tgt2auc_val[tgt]),
          (f'RCE {tgt}',tgt2rce_val[tgt])]

dfscrtrn=pd.DataFrame(lsttrn)
dfscrtrn.columns=['metric','scr']
dfscrval=pd.DataFrame(lstval)
dfscrval.columns=['metric','scr']
dfscr = pd.merge(dfscrtrn, dfscrval, on='metric', suffixes=('trn','val'))
dfscr.T
# Out:
#                     0            1            2          3           4  \
# metric  PRAUC Retweet  RCE Retweet  PRAUC Reply  RCE Reply  PRAUC Like
# scrtrn       0.573304      23.0915     0.273255    18.7388    0.707051
# scrval       0.277696      8.30656    0.0509837    4.83231    0.664128
#
#                5              6            7
# metric  RCE Like  PRAUC RTwCmnt  RCE RTwCmnt
# scrtrn   14.0143      0.0562823       1.2702
# scrval    10.953      0.0114427     -1.54295

# %% [markdown]
# # old

# %%
tgt2bst={}
tgt2ytr={}
tgt2yvl={}
tgt2evalres={}
for i,tgt in enumerate(tgts):
    evals_result = {}
    print(dtnow(), tgt, '*'*80)
    tgt2ytr[tgt]=ytr.iloc[:,i]
    tgt2yvl[tgt]=yvl.iloc[:,i]
    dtr = xgb.DMatrix(Xtr, label=ytr.iloc[:,i], feature_names=cols_feat)
    dvl = xgb.DMatrix(Xvl, label=yvl.iloc[:,i], feature_names=cols_feat)
    evallist = [(dtr, 'train'), (dvl, 'eval')]
    bst = xgb.train(params=params, dtrain=dtr, num_boost_round=num_rounds, 
                    evals=evallist, evals_result=evals_result, early_stopping_rounds=10)
    tgt2bst[tgt] = bst
    tgt2evalres[tgt] = evals_result
pickle.dump(tgt2bst, open(f"{p_out}/tgt2bst.p", "wb"))
# Out:
# 2020-03-21 02:44:09 Retweet ********************************************************************************
# [02:44:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-error:0.11034	train-logloss:0.58774	eval-error:0.11103	eval-logloss:0.58776
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 10 rounds.
# [02:44:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [1]	train-error:0.11002	train-logloss:0.50363	eval-error:0.11076	eval-logloss:0.50407
# [02:44:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.10988	train-logloss:0.44028	eval-error:0.11075	eval-logloss:0.44084
# [02:44:22] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.10969	train-logloss:0.39630	eval-error:0.11054	eval-logloss:0.39699
# [02:44:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.10966	train-logloss:0.36770	eval-error:0.11083	eval-logloss:0.36872
# [02:44:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.10959	train-logloss:0.34952	eval-error:0.11077	eval-logloss:0.35064
# [02:44:25] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.10955	train-logloss:0.33840	eval-error:0.11071	eval-logloss:0.33975
# [02:44:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.10950	train-logloss:0.33037	eval-error:0.11059	eval-logloss:0.33183
# [02:44:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.10943	train-logloss:0.32540	eval-error:0.11041	eval-logloss:0.32699
# [02:44:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.10939	train-logloss:0.32217	eval-error:0.11051	eval-logloss:0.32390
# [02:44:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [10]	train-error:0.10934	train-logloss:0.31978	eval-error:0.11049	eval-logloss:0.32160
# [02:44:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [11]	train-error:0.10933	train-logloss:0.31792	eval-error:0.11049	eval-logloss:0.31988
# [02:44:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [12]	train-error:0.10921	train-logloss:0.31674	eval-error:0.11037	eval-logloss:0.31880
# [02:44:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [13]	train-error:0.10919	train-logloss:0.31579	eval-error:0.11027	eval-logloss:0.31795
# [02:44:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [14]	train-error:0.10912	train-logloss:0.31487	eval-error:0.11031	eval-logloss:0.31718
# [02:44:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15]	train-error:0.10917	train-logloss:0.31421	eval-error:0.11029	eval-logloss:0.31670
# [02:44:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16]	train-error:0.10908	train-logloss:0.31345	eval-error:0.11023	eval-logloss:0.31606
# [02:44:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 108 extra nodes, 0 pruned nodes, max_depth=6
# [17]	train-error:0.10907	train-logloss:0.31304	eval-error:0.11021	eval-logloss:0.31579
# [02:44:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [18]	train-error:0.10901	train-logloss:0.31259	eval-error:0.11011	eval-logloss:0.31538
# [02:44:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [19]	train-error:0.10896	train-logloss:0.31215	eval-error:0.11011	eval-logloss:0.31508
# [02:44:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [20]	train-error:0.10894	train-logloss:0.31172	eval-error:0.11009	eval-logloss:0.31478
# [02:44:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [21]	train-error:0.10888	train-logloss:0.31124	eval-error:0.11010	eval-logloss:0.31446
# [02:44:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [22]	train-error:0.10886	train-logloss:0.31100	eval-error:0.11009	eval-logloss:0.31430
# [02:44:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [23]	train-error:0.10882	train-logloss:0.31073	eval-error:0.11003	eval-logloss:0.31417
# [02:44:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [24]	train-error:0.10879	train-logloss:0.31039	eval-error:0.11001	eval-logloss:0.31398
# [02:44:41] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [25]	train-error:0.10880	train-logloss:0.31021	eval-error:0.10995	eval-logloss:0.31391
# [02:44:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [26]	train-error:0.10880	train-logloss:0.31002	eval-error:0.10994	eval-logloss:0.31383
# [02:44:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [27]	train-error:0.10877	train-logloss:0.30975	eval-error:0.10994	eval-logloss:0.31367
# [02:44:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 84 extra nodes, 0 pruned nodes, max_depth=6
# [28]	train-error:0.10872	train-logloss:0.30941	eval-error:0.10993	eval-logloss:0.31341
# [02:44:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=6
# [29]	train-error:0.10873	train-logloss:0.30926	eval-error:0.10991	eval-logloss:0.31334
# [02:44:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [30]	train-error:0.10871	train-logloss:0.30900	eval-error:0.10995	eval-logloss:0.31319
# [02:44:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 76 extra nodes, 0 pruned nodes, max_depth=6
# [31]	train-error:0.10865	train-logloss:0.30873	eval-error:0.10989	eval-logloss:0.31303
# [02:44:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [32]	train-error:0.10863	train-logloss:0.30859	eval-error:0.10987	eval-logloss:0.31297
# [02:44:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=6
# [33]	train-error:0
38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=6
# [94]	train-error:0.10737	train-logloss:0.30099	eval-error:0.10975	eval-logloss:0.31007
# [02:45:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [95]	train-error:0.10737	train-logloss:0.30086	eval-error:0.10975	eval-logloss:0.31006
# [02:45:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [96]	train-error:0.10737	train-logloss:0.30071	eval-error:0.10973	eval-logloss:0.31005
# [02:45:41] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [97]	train-error:0.10734	train-logloss:0.30050	eval-error:0.10966	eval-logloss:0.31000
# [02:45:41] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [98]	train-error:0.10733	train-logloss:0.30046	eval-error:0.10966	eval-logloss:0.31000
# [02:45:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [99]	train-error:0.10733	train-logloss:0.30045	eval-error:0.10966	eval-logloss:0.31000
# [02:45:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 100 extra nodes, 0 pruned nodes, max_depth=6
# [100]	train-error:0.10729	train-logloss:0.30033	eval-error:0.10961	eval-logloss:0.30996
# [02:45:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [101]	train-error:0.10727	train-logloss:0.30017	eval-error:0.10955	eval-logloss:0.30996
# [02:45:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=6
# [102]	train-error:0.10724	train-logloss:0.30011	eval-error:0.10951	eval-logloss:0.30996
# [02:45:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [103]	train-error:0.10724	train-logloss:0.30009	eval-error:0.10951	eval-logloss:0.30998
# [02:45:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [104]	train-error:0.10720	train-logloss:0.29993	eval-error:0.10955	eval-logloss:0.30995
# [02:45:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [105]	train-error:0.10719	train-logloss:0.29982	eval-error:0.10954	eval-logloss:0.30994
# [02:45:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [106]	train-error:0.10718	train-logloss:0.29981	eval-error:0.10954	eval-logloss:0.30994
# [02:45:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [107]	train-error:0.10717	train-logloss:0.29977	eval-error:0.10956	eval-logloss:0.30992
# [02:45:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=6
# [108]	train-error:0.10713	train-logloss:0.29968	eval-error:0.10956	eval-logloss:0.30992
# [02:45:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [109]	train-error:0.10712	train-logloss:0.29951	eval-error:0.10953	eval-logloss:0.30987
# [02:45:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [110]	train-error:0.10711	train-logloss:0.29949	eval-error:0.10954	eval-logloss:0.30986
# [02:45:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [111]	train-error:0.10707	train-logloss:0.29941	eval-error:0.10957	eval-logloss:0.30986
# [02:45:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [112]	train-error:0.10703	train-logloss:0.29933	eval-error:0.10955	eval-logloss:0.30986
# [02:45:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [113]	train-error:0.10700	train-logloss:0.29921	eval-error:0.10955	eval-logloss:0.30986
# [02:45:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [114]	train-error:0.10700	train-logloss:0.29920	eval-error:0.10954	eval-logloss:0.30987
# [02:45:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=6
# [115]	train-error:0.10694	train-logloss:0.29910	eval-error:0.10953	eval-logloss:0.30987
# [02:45:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [116]	train-error:0.10693	train-logloss:0.29897	eval-error:0.10953	eval-logloss:0.30984
# [02:45:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [117]	train-error:0.10692	train-logloss:0.29885	eval-error:0.10952	eval-logloss:0.30986
# [02:45:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [118]	train-error:0.10691	train-logloss:0.29873	eval-error:0.10955	eval-logloss:0.30985
# [02:45:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [119]	train-error:0.10690	train-logloss:0.29864	eval-error:0.10957	eval-logloss:0.30987
# [02:45:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [120]	train-error:0.10689	train-logloss:0.29862	eval-error:0.10957	eval-logloss:0.30988
# [02:46:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [121]	train-error:0.10687	train-logloss:0.29857	eval-error:0.10956	eval-logloss:0.30989
# [02:46:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=6
# [122]	train-error:0.10688	train-logloss:0.29850	eval-error:0.10954	eval-logloss:0.30989
# [02:46:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [123]	train-error:0.10688	train-logloss:0.29838	eval-error:0.10957	eval-logloss:0.30990
# [02:46:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [124]	train-error:0.10685	train-logloss:0.29828	eval-error:0.10955	eval-logloss:0.30990
# [02:46:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [125]	train-error:0.10683	train-logloss:0.29815	eval-error:0.10956	eval-logloss:0.30990
# [02:46:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 76 extra nodes, 0 pruned nodes, max_depth=6
# [126]	train-error:0.10678	train-logloss:0.29810	eval-error:0.10954	eval-logloss:0.30990
# Stopping. Best iteration:
# [116]	train-error:0.10693	train-logloss:0.29897	eval-error:0.10953	eval-logloss:0.30984
#
# 2020-03-21 02:46:05 Reply ********************************************************************************
# [02:46:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [0]	train-error:0.02778	train-logloss:0.56290	eval-error:0.02715	eval-logloss:0.56250
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 10 rounds.
# [02:46:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [1]	train-error:0.02778	train-logloss:0.45416	eval-error:0.02715	eval-logloss:0.45379
# [02:46:16] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.02778	train-logloss:0.36613	eval-error:0.02715	eval-logloss:0.36557
# [02:46:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.02778	train-logloss:0.29674	eval-error:0.02715	eval-logloss:0.29589
# [02:46:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.02778	train-logloss:0.24292	eval-error:0.02716	eval-logloss:0.24229
# [02:46:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 94 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.02777	train-logloss:0.20394	eval-error:0.02715	eval-logloss:0.20304
# [02:46:19] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.02778	train-logloss:0.17537	eval-error:0.02715	eval-logloss:0.17450
# [02:46:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.02777	train-logloss:0.15519	eval-error:0.02715	eval-logloss:0.15437
# [02:46:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.02778	train-logloss:0.14123	eval-error:0.02715	eval-logloss:0.14047
# [02:46:22] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.02777	train-logloss:0.13175	eval-error:0.02715	eval-logloss:0.13102
# [02:46:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [10]	train-error:0.02777	train-logloss:0.12535	eval-error:0.02715	eval-logloss:0.12464
# [02:46:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [11]	train-error:0.02777	train-logloss:0.12103	eval-error:0.02715	eval-logloss:0.12035
# [02:46:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [12]	train-error:0.02777	train-logloss:0.11812	eval-error:0.02715	eval-logloss:0.11751
# [02:46:25] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [13]	train-error:0.02777	train-logloss:0.11618	eval-error:0.02715	eval-logloss:0.11563
# [02:46:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [14]	train-error:0.02778	train-logloss:0.11486	eval-error:0.02715	eval-logloss:0.11444
# [02:46:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15]	train-error:0.02777	train-logloss:0.11396	eval-error:0.02715	eval-logloss:0.11365
# [02:46:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [16]	train-error:0.02777	train-logloss:0.11329	eval-error:0.02715	eval-logloss:0.11308
# [02:46:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [17]	train-error:0.02777	train-logloss:0.11285	eval-error:0.02715	eval-logloss:0.11276
# [02:46:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [18]	train-error:0.02777	train-logloss:0.11242	eval-error:0.02715	eval-logloss:0.11239
# [02:46:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [19]	train-error:0.02777	train-logloss:0.11214	eval-error:0.02715	eval-logloss:0.11220
# [02:46:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [20]	train-error:0.02777	train-logloss:0.11189	eval-error:0.02715	eval-logloss:0.11204
# [02:46:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [21]	train-error:0.02777	train-logloss:0.11169	eval-error:0.02715	eval-logloss:0.11196
# [02:46:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [22]	train-error:0.02776	train-logloss:0.11152	eval-error:0.02715	eval-logloss:0.11189
# [02:46:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [23]	train-error:0.02776	train-logloss:0.11130	eval-error:0.02716	eval-logloss:0.11179
# [02:46:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [24]	train-error:0.02776	train-logloss:0.11111	eval-error:0.02716	eval-logloss:0.11172
# [02:46:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [25]	train-error:0
04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [59]	train-error:0.02773	train-logloss:0.10818	eval-error:0.02716	eval-logloss:0.11135
# [02:47:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [60]	train-error:0.02773	train-logloss:0.10815	eval-error:0.02715	eval-logloss:0.11135
# [02:47:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=6
# [61]	train-error:0.02773	train-logloss:0.10812	eval-error:0.02715	eval-logloss:0.11134
# [02:47:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 84 extra nodes, 0 pruned nodes, max_depth=6
# [62]	train-error:0.02773	train-logloss:0.10805	eval-error:0.02716	eval-logloss:0.11135
# [02:47:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [63]	train-error:0.02773	train-logloss:0.10790	eval-error:0.02716	eval-logloss:0.11135
# [02:47:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [64]	train-error:0.02773	train-logloss:0.10780	eval-error:0.02717	eval-logloss:0.11137
# [02:47:09] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [65]	train-error:0.02773	train-logloss:0.10776	eval-error:0.02717	eval-logloss:0.11137
# [02:47:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [66]	train-error:0.02773	train-logloss:0.10765	eval-error:0.02717	eval-logloss:0.11134
# Stopping. Best iteration:
# [56]	train-error:0.02774	train-logloss:0.10832	eval-error:0.02716	eval-logloss:0.11133
#
# 2020-03-21 02:47:10 Like ********************************************************************************
# [02:47:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-error:0.34997	train-logloss:0.66251	eval-error:0.35194	eval-logloss:0.66295
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 10 rounds.
# [02:47:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [1]	train-error:0.34488	train-logloss:0.64438	eval-error:0.34702	eval-logloss:0.64519
# [02:47:22] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.34342	train-logloss:0.63353	eval-error:0.34621	eval-logloss:0.63465
# [02:47:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.34019	train-logloss:0.62640	eval-error:0.34323	eval-logloss:0.62774
# [02:47:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.33953	train-logloss:0.62190	eval-error:0.34212	eval-logloss:0.62351
# [02:47:25] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.33775	train-logloss:0.61870	eval-error:0.34024	eval-logloss:0.62055
# [02:47:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.33571	train-logloss:0.61589	eval-error:0.33826	eval-logloss:0.61798
# [02:47:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.33431	train-logloss:0.61402	eval-error:0.33724	eval-logloss:0.61630
# [02:47:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.33256	train-logloss:0.61196	eval-error:0.33550	eval-logloss:0.61445
# [02:47:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.33177	train-logloss:0.61075	eval-error:0.33505	eval-logloss:0.61335
# [02:47:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [10]	train-error:0.33081	train-logloss:0.60937	eval-error:0.33425	eval-logloss:0.61204
# [02:47:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [11]	train-error:0.32923	train-logloss:0.60809	eval-error:0.33283	eval-logloss:0.61082
# [02:47:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [12]	train-error:0.32800	train-logloss:0.60671	eval-error:0.33144	eval-logloss:0.60959
# [02:47:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [13]	train-error:0.32720	train-logloss:0.60575	eval-error:0.33104	eval-logloss:0.60882
# [02:47:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [14]	train-error:0.32676	train-logloss:0.60487	eval-error:0.33091	eval-logloss:0.60811
# [02:47:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15]	train-error:0.32635	train-logloss:0.60408	eval-error:0.33099	eval-logloss:0.60748
# [02:47:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [16]	train-error:0.32601	train-logloss:0.60346	eval-error:0.33066	eval-logloss:0.60694
# [02:47:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [17]	train-error:0.32485	train-logloss:0.60229	eval-error:0.32949	eval-logloss:0.60587
# [02:47:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [18]	train-error:0.32450	train-logloss:0.60182	eval-error:0.32931	eval-logloss:0.60553
# [02:47:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [19]	train-error:0.32378	train-logloss:0.60085	eval-error:0.32863	eval-logloss:0.60469
# [02:47:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [20]	train-error:0.32303	train-logloss:0.59986	eval-error:0.32763	eval-logloss:0.60382
# [02:47:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [21]	train-error:0.32203	train-logloss:0.59900	eval-error:0.32723	eval-logloss:0.60308
# [02:47:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [22]	train-error:0
26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [23]	train-error:0.00778	train-logloss:0.04246	eval-error:0.00759	eval-logloss:0.04286
# [02:51:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [24]	train-error:0.00778	train-logloss:0.04233	eval-error:0.00759	eval-logloss:0.04281
# [02:51:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 94 extra nodes, 0 pruned nodes, max_depth=6
# [25]	train-error:0.00778	train-logloss:0.04224	eval-error:0.00759	eval-logloss:0.04280
# [02:51:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [26]	train-error:0.00778	train-logloss:0.04217	eval-error:0.00759	eval-logloss:0.04279
# [02:51:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [27]	train-error:0.00778	train-logloss:0.04204	eval-error:0.00759	eval-logloss:0.04279
# [02:51:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 100 extra nodes, 0 pruned nodes, max_depth=6
# [28]	train-error:0.00778	train-logloss:0.04195	eval-error:0.00759	eval-logloss:0.04277
# [02:51:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [29]	train-error:0.00778	train-logloss:0.04186	eval-error:0.00759	eval-logloss:0.04274
# [02:51:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 84 extra nodes, 0 pruned nodes, max_depth=6
# [30]	train-error:0.00778	train-logloss:0.04176	eval-error:0.00759	eval-logloss:0.04269
# [02:51:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [31]	train-error:0.00778	train-logloss:0.04165	eval-error:0.00759	eval-logloss:0.04262
# [02:51:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [32]	train-error:0.00778	train-logloss:0.04163	eval-error:0.00759	eval-logloss:0.04263
# [02:51:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 86 extra nodes, 0 pruned nodes, max_depth=6
# [33]	train-error:0.00778	train-logloss:0.04156	eval-error:0.00759	eval-logloss:0.04262
# [02:51:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 82 extra nodes, 0 pruned nodes, max_depth=6
# [34]	train-error:0.00778	train-logloss:0.04149	eval-error:0.00759	eval-logloss:0.04260
# [02:51:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [35]	train-error:0.00778	train-logloss:0.04137	eval-error:0.00759	eval-logloss:0.04258
# [02:51:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [36]	train-error:0.00778	train-logloss:0.04132	eval-error:0.00759	eval-logloss:0.04258
# [02:51:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [37]	train-error:0.00778	train-logloss:0.04126	eval-error:0.00759	eval-logloss:0.04256
# [02:51:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [38]	train-error:0.00778	train-logloss:0.04115	eval-error:0.00759	eval-logloss:0.04255
# [02:51:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [39]	train-error:0.00778	train-logloss:0.04109	eval-error:0.00759	eval-logloss:0.04256
# [02:51:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [40]	train-error:0.00777	train-logloss:0.04106	eval-error:0.00759	eval-logloss:0.04256
# [02:51:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [41]	train-error:0.00777	train-logloss:0.04104	eval-error:0.00759	eval-logloss:0.04256
# [02:51:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [42]	train-error:0.00777	train-logloss:0.04101	eval-error:0.00759	eval-logloss:0.04256
# [02:51:41] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=6
# [43]	train-error:0.00777	train-logloss:0.04096	eval-error:0.00759	eval-logloss:0.04258
# [02:51:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [44]	train-error:0.00777	train-logloss:0.04092	eval-error:0.00759	eval-logloss:0.04259
# [02:51:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [45]	train-error:0.00777	train-logloss:0.04088	eval-error:0.00759	eval-logloss:0.04258
# [02:51:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [46]	train-error:0.00777	train-logloss:0.04081	eval-error:0.00759	eval-logloss:0.04259
# [02:51:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [47]	train-error:0.00777	train-logloss:0.04075	eval-error:0.00759	eval-logloss:0.04258
# [02:51:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [48]	train-error:0.00777	train-logloss:0.04073	eval-error:0.00759	eval-logloss:0.04259
# Stopping. Best iteration:
# [38]	train-error:0.00778	train-logloss:0.04115	eval-error:0.00759	eval-logloss:0.04255

# %%
def show_feat_importance(bst):
    ax = xgb.plot_importance(bst, height=0.8, max_num_features=9)
    ax.grid(False, axis="y")
    ax.set_title('Estimated feature importance')
    plt.show()
    feat2importance=bst.get_fscore()
    display(pd.DataFrame([feat2importance.keys(), feat2importance.values()]).T.sort_values(1, ascending=False).head(20))

# %%
for tgt,bst in tgt2bst.items():
    print(tgt)
    show_feat_importance(bst)
# Out:
# Retweet
#                                         0    1
# 6                           u2_fllwer_cnt  530
# 3                                len_toks  514
# 11                                 u2_age  501
# 4                           u1_fllwng_cnt  493
# 18                                 u1_age  471
# 1                           u2_fllwng_cnt  457
# 5                           u1_fllwer_cnt  451
# 2                    u1_fllwng_cnt_by_age  434
# 8                    u1_fllwer_cnt_by_age  397
# 9                                 twt_age  352
# 16                            tmdlta_u2u1  261
# 25                                tm_hour  174
# 17                             num_hshtgs  159
# 14                         twttyp_Retweet   98
# 23  lang_22C448FF81263D4BAF2A176145EE9EAD   82
# 24                        has_media_Photo   71
# 20                              num_links   61
# 29                        twttyp_TopLevel   59
# 19                           tm_dayofweek   55
# 7   lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   55
# Reply
#                                         0    1
# 0                                  u2_age  328
# 2                    u1_fllwng_cnt_by_age  258
# 3                           u2_fllwer_cnt  255
# 4                                len_toks  242
# 9                           u1_fllwng_cnt  220
# 7                           u1_fllwer_cnt  219
# 10                                twt_age  215
# 18                          u2_fllwng_cnt  211
# 11                                 u1_age  211
# 1                    u1_fllwer_cnt_by_age  210
# 22                            tmdlta_u2u1  176
# 12                                tm_hour   93
# 6                              num_hshtgs   44
# 21  lang_167115458A0DBDFF7E9C0C53A83BAC9B   40
# 15                           tm_dayofweek   36
# 24                              num_links   29
# 27  lang_22C448FF81263D4BAF2A176145EE9EAD   27
# 20                        twttyp_TopLevel   27
# 16                             u1_fllw_u2   24
# 17                         twttyp_Retweet   24
# Like
#                                         0     1
# 5                           u1_fllwer_cnt  1714
# 4                    u1_fllwer_cnt_by_age  1463
# 20                          u1_fllwng_cnt  1291
# 6                                  u1_age   968
# 14                                twt_age   927
# 11                          u2_fllwer_cnt   924
# 8                                  u2_age   890
# 3                                len_toks   830
# 2                    u1_fllwng_cnt_by_age   826
# 13                          u2_fllwng_cnt   806
# 7                             tmdlta_u2u1   600
# 27                                tm_hour   363
# 18                             num_hshtgs   150
# 16                        has_media_Photo   133
# 17  lang_22C448FF81263D4BAF2A176145EE9EAD   130
# 0                          twttyp_Retweet   117
# 34                           tm_dayofweek   109
# 26                        has_media_Video   100
# 1                               num_links    94
# 19                             u1_fllw_u2    91
# RTwCmnt
#                                         0    1
# 0                                  u2_age  204
# 1                           u2_fllwer_cnt  194
# 5                                len_toks  167
# 9                           u1_fllwng_cnt  145
# 11                   u1_fllwer_cnt_by_age  133
# 10                                twt_age  126
# 6                    u1_fllwng_cnt_by_age  122
# 3                           u1_fllwer_cnt  121
# 2                           u2_fllwng_cnt  114
# 4                             tmdlta_u2u1  114
# 7                                  u1_age  103
# 27                                tm_hour   54
# 23  lang_22C448FF81263D4BAF2A176145EE9EAD   33
# 17                        has_media_Video   31
# 22                        twttyp_TopLevel   25
# 24                         twttyp_Retweet   25
# 19                             u1_fllw_u2   25
# 26  lang_4DC22C3F31C5C43721E6B5815A595ED6   23
# 36                             num_hshtgs   17
# 35                           tm_dayofweek   16

# %% [markdown]
# ## valid

# %%
for tgt in tgts:
    evalres=tgt2evalres[tgt]
    plt.plot(evalres['train']['error'])
    plt.plot(evalres['eval']['error'])
    plt.title(f"{tgt} error {len(evalres['train']['error'])} rounds")
    plt.show()
    
    plt.plot(evalres['train']['logloss'])
    plt.plot(evalres['eval']['logloss'])
    plt.title(f"{tgt} logloss {len(evalres['train']['logloss'])} rounds")
    plt.show()

# %%
tgt2prdtr={}
tgt2prdvl={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtr[tgt] = bst.predict(dtr)
    tgt2prdvl[tgt] = bst.predict(dvl)
# Out:
# 2020-03-21 02:51:48 Retweet
# 2020-03-21 02:51:49 Reply
# 2020-03-21 02:51:49 Like
# 2020-03-21 02:51:51 RTwCmnt

# %%
tgt2auc_trn={}
tgt2rce_trn={}
tgt2auc_val={}
tgt2rce_val={}
for itgt, tgt in enumerate(tgts):
    print(tgt)
    prdtr_i, prdvl_i = tgt2prdtr[tgt], tgt2prdvl[tgt]
    ytr_i, yvl_i = tgt2ytr[tgt], tgt2yvl[tgt]
    scr_rocauc_trn = roc_auc_score(ytr_i, prdtr_i)
    scr_rocauc_val = roc_auc_score(yvl_i, prdvl_i)
    scr_auc_trn=compute_prauc(prdtr_i, ytr_i)
    scr_rce_trn=compute_rce(prdtr_i, ytr_i)
    scr_auc_val=compute_prauc(prdvl_i, yvl_i)
    scr_rce_val=compute_rce(prdvl_i, yvl_i)

    tgt2auc_trn[tgt]=scr_auc_trn
    tgt2rce_trn[tgt]=scr_rce_trn
    tgt2auc_val[tgt]=scr_auc_val
    tgt2rce_val[tgt]=scr_rce_val
    
    print('train rocauc:', f'{scr_rocauc_trn:.4f}', 'valid auc:', f'{scr_rocauc_val:.4f}', )
    print('train prauc:', f'{scr_auc_trn:.4f}', 'valid auc:', f'{scr_auc_val:.4f}', )
    print('train rce:', f'{scr_rce_trn:.4f}', 'valid rce:', f'{scr_rce_val:.4f}', )
# Out:
# Retweet
# train rocauc: 0.7722 valid auc: 0.7443
# train prauc: 0.3659 valid auc: 0.3179
# train rce: 15.5252 valid rce: 12.3984
# Reply
# train rocauc: 0.8107 valid auc: 0.7709
# train prauc: 0.1530 valid auc: 0.0935
# train rce: 15.2062 valid rce: 10.6976
# Like
# train rocauc: 0.7782 valid auc: 0.7513
# train prauc: 0.7330 valid auc: 0.6984
# train rce: 18.4472 valid rce: 15.0775
# RTwCmnt
# train rocauc: 0.7909 valid auc: 0.7011
# train prauc: 0.0658 valid auc: 0.0195
# train rce: 10.5192 valid rce: 4.5635

# %%
lsttrn=[]
lstval=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    lsttrn+=[(f'PRAUC {tgt}',tgt2auc_trn[tgt]),
          (f'RCE {tgt}',tgt2rce_trn[tgt])]
    lstval+=[(f'PRAUC {tgt}',tgt2auc_val[tgt]),
          (f'RCE {tgt}',tgt2rce_val[tgt])]

dfscrtrn=pd.DataFrame(lsttrn)
dfscrtrn.columns=['metric','scr']
dfscrval=pd.DataFrame(lstval)
dfscrval.columns=['metric','scr']
dfscr = pd.merge(dfscrtrn, dfscrval, on='metric', suffixes=('trn','val'))
dfscr.T
# Out:
#                     0            1            2          3           4  \
# metric  PRAUC Retweet  RCE Retweet  PRAUC Reply  RCE Reply  PRAUC Like
# scrtrn       0.365933      15.5252     0.152998    15.2062    0.732972
# scrval       0.317854      12.3984    0.0935055    10.6976    0.698436
#
#                5              6            7
# metric  RCE Like  PRAUC RTwCmnt  RCE RTwCmnt
# scrtrn   18.4472      0.0657798      10.5192
# scrval   15.0775      0.0195177      4.56347

# %% [markdown]
# # infer

# %% [raw]
# ls -lhS $p_in | grep val

# %%
# %%time
dftst=pd.read_csv(
    f'{p_in}/val_{valtmstmp}.tsv',
#     f'{p_in}/val_259A6F6DFD672CB1F883CBEC01B99F2D_1584405047.tsv',
    sep='\x01', header=None, names=cols_val,)
# Out:
# CPU times: user 1min 37s, sys: 8.99 s, total: 1min 46s
# Wall time: 1min 46s

# %%
# %%time
dftst = prp_df(dftst, istrn=False)
# Out:
# CPU times: user 1min 53s, sys: 10.3 s, total: 2min 4s
# Wall time: 2min 4s

# %%
# %%time
dtst = xgb.DMatrix(dftst[cols_feat], feature_names=cols_feat)
tgt2prdtst={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtst[tgt] = bst.predict(dtst)
# Out:
# 2020-03-21 02:57:52 Retweet
# 2020-03-21 02:58:02 Reply
# 2020-03-21 02:58:07 Like
# 2020-03-21 02:58:34 RTwCmnt
# CPU times: user 13min 7s, sys: 36.5 s, total: 13min 43s
# Wall time: 2min 50s

# %%
dfsub_ids = dftst[['twtid','u2id',]]

tgt2dfsub = {}
for tgt,prdtst in tgt2prdtst.items():
    dfsub = dfsub_ids.copy()
    dfsub['scr'] = prdtst
    tgt2dfsub[tgt]=dfsub

# %%
# %%time
for tgt, dfsub in tgt2dfsub.items():
    print(dtnow(), tgt)
    dfsub.to_csv(f'{p_out}/{tgt}__{valtmstmp}__{PRFX}.csv',index=False,header=False)
# Out:
# 2020-03-21 02:58:40 Retweet
# 2020-03-21 02:59:36 Reply
# 2020-03-21 03:00:33 Like
# 2020-03-21 03:01:29 RTwCmnt
# CPU times: user 3min 39s, sys: 6.21 s, total: 3min 46s
# Wall time: 3min 46s
