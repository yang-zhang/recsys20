# %% [markdown]
# # start

# %%
PRFX='0320_1'
trntmstmp=1584412344
valtmstmp=1584626395
import datetime
[datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (trntmstmp, valtmstmp)]
# Out:
# ['2020-03-17 02:32:24', '2020-03-19 13:59:55']

# %%
grand_total=1.5e8

# %% [markdown]
# # setup

# %%
from pathlib import Path
import dask
print('dask.__version__', dask.__version__)
import xgboost as xgb
import dask_xgboost
import dask.dataframe as dd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from dask.distributed import Client
import pickle
import lightgbm as lgb
from tqdm import tqdm
import matplotlib.pyplot as plt

import datetime
def dtnow(): return datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

SEED=101
HOME='/data/git/recsys20'
p_in=f'{HOME}/input'
p_out=f'{HOME}/output/{PRFX}'
Path(p_out).mkdir(exist_ok=True, parents=True)

from sklearn.metrics import precision_recall_curve, auc, log_loss

def compute_prauc(pred, gt):
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return prauc

def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive/float(len(gt))
    return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

cols=[
'toks',
'hshtgs',
'twtid',
'media',
'links',
'domns',
'twttyp',
'lang',
'tm',

'u1id',
'u1_fllwer_cnt',
'u1_fllwing_cnt',
'u1_vrfed',
'u1_create_tm',

'u2id',
'u2_follower_cnt',
'u2_following_cnt',
'u2_vrfed',
'u2_create_tm',

'u1_fllw_u2',
'reply_tm',
'retwt_tm',
'retwt_cmmnt_tm',
'like_tm',
]

cols_val = cols[:-4]
cols_tgt_tmstmp=[
    'retwt_tm',
    'reply_tm',
    'like_tm',
    'retwt_cmmnt_tm',
]
cols_tgt=[o.split('_tm')[0] for o in cols_tgt_tmstmp]
tgts             = ['Retweet','Reply','Like','RTwCmnt',]
assert cols_tgt == ['retwt',  'reply','like','retwt_cmmnt',]
ntgts=len(tgts)
# Out:
# dask.__version__ 2.12.0

# %% [markdown]
# # prepare data

# %% [markdown]
# ## get maps from dfval

# %%
# dfval=dd.read_csv(
#     f'{p_in}/val_{valtmstmp}.tsv',
#     sep='\x01', header=None, names=cols_val,)
# lang2cnt=dict(dfval.lang.value_counts().compute())
# ttl=sum(lang2cnt.values())
# lang2perc={k:v/ttl for k,v in lang2cnt.items()}
langs=['D3164C7FBCF2565DDF915B1B3AEFB1DC', '22C448FF81263D4BAF2A176145EE9EAD', '06D61DCBBE938971E1EA0C38BD9B5446', 'ECED8A16BE2A5E8871FD55F4842F16B1', 'B9175601E87101A984A50F8A62A1C374', '4DC22C3F31C5C43721E6B5815A595ED6', '167115458A0DBDFF7E9C0C53A83BAC9B', '125C57F4FA6D4E110983FB11B52EFD4E', '022EC308651FACB02794A8147AEE1B78', 'FA3F382BC409C271E3D6EAF8BE4648D
        df[f'has_media_{media}'] = df.media.fillna('').apply(lambda x: media in x)
    for col in ['hshtgs', 'links', 'domns',]:
        df[f'num_{col}'] = df[col].fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0)
    tm_dt=pd.to_datetime(df.tm, unit='s')
    df['tm_month']=tm_dt.dt.month
    df['tm_dayofweek']=tm_dt.dt.dayofweek
    df['tm_day']=tm_dt.dt.day
    df['tm_hour']=tm_dt.dt.hour
    df['tmdlta_u2u1']  = df.u2_create_tm - df.u1_create_tm
    df['tmdlta_twtu1'] = df.tm - df.u1_create_tm
    df['tmdlta_twtu2'] = df.tm - df.u2_create_tm

    for typ in twttyps:
        df[f'twttyp_{typ}']=(df.twttyp==typ).astype('int8')

    for lang in langs:
        df[f'lang_{lang}']=(df.lang==lang).astype('int8')
    if istrn: 
        df[cols_tgt]=df[cols_tgt_tmstmp].notna().astype('int8')
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 'twtid', 'u1id', 'u2id']+cols_tgt_tmstmp, )
    else:
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 'u1id',])        
    return df

# %% [raw]
# ls -hlS $p_in | grep {trntmstmp}

# %%
grand_total
# Out:
# 150000000.0

# %%
grand_total/1e6
# Out:
# 150.0

# %% [raw]
# chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
#                     header=None,names=cols,
#                         chunksize=1e6
#                        )
# for ichnk,df in enumerate(chnks_trn):
#     print(dtnow(), 'chunk', ichnk, df.tm.max())
# ichnk

# %%
chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                    header=None,names=cols, 
                        chunksize=1e6
                       )

np.random.seed(SEED)
lst_df = []
for ichnk,df in enumerate(chnks_trn):
    print(dtnow(), 'chunk', ichnk)
    df = prp_df(df)    
    lst_df.append(df)
    if ichnk>=0: break
# Out:
# 2020-03-20 12:07:00 chunk 0

# %%
df = pd.concat(lst_df)

# %%
df.shape
# Out:
# (1000000, 97)

# %%
df.columns
# Out:
# Index(['tm', 'u1_fllwer_cnt', 'u1_fllwing_cnt', 'u1_vrfed', 'u1_create_tm',
#        'u2_follower_cnt', 'u2_following_cnt', 'u2_vrfed', 'u2_create_tm',
#        'u1_fllw_u2', 'len_toks', 'has_media_Photo', 'has_media_Video',
#        'has_media_GIF', 'num_hshtgs', 'num_links', 'num_domns', 'tm_month',
#        'tm_dayofweek', 'tm_day', 'tm_hour', 'tmdlta_u2u1', 'tmdlta_twtu1',
#        'tmdlta_twtu2', 'twttyp_TopLevel', 'twttyp_Retweet', 'twttyp_Quote',
#        'lang_D3164C7FBCF2565DDF915B1B3AEFB1DC',
#        'lang_22C448FF81263D4BAF2A176145EE9EAD',
#        'lang_06D61DCBBE938971E1EA0C38BD9B5446',
#        'lang_ECED8A16BE2A5E8871FD55F4842F16B1',
#        'lang_B9175601E87101A984A50F8A62A1C374',
#        'lang_4DC22C3F31C5C43721E6B5815A595ED6',
#        'lang_167115458A0DBDFF7E9C0C53A83BAC9B',
#        'lang_125C57F4FA6D4E110983FB11B52EFD4E',
#        'lang_022EC308651FACB02794A8147AEE1B78',
#        'lang_FA3F382BC409C271E3D6EAF8BE4648DD',
#        'lang_9BF3403E0EB7EA8A256DA9019C0B0716',
#        'lang_975B38F44D65EE42A547283787FF5A21',
#        'lang_2996EB2FE8162C076D070A4C8D6532CD',
#        'lang_FF60A88F53E63000266F8B9149E35AD9',
#        'lang_717293301FE296B0B61950D041485825',
#        'lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D',
#        'lang_3820C29CBCA409A33BADF68852057C4A',
#        'lang_9ECD42BC079C20F156F53CB3B99E600E',
#        'lang_76B8A9C3013AE6414A3E6012413CDC3B',
#        'lang_AEF22666801F0A5846D853B9CEB2E327',
#        'lang_190BA7DA361BC06BC1D7E824C378064D',
#        'lang_1FFD2FE4297F5E70EBC6C3230D95CB9C',
#        'lang_A0C7021AD8299ADF0C9EBE326C115F6F',
#        'lang_D413F5FE5236E5650A46FD983AB39212',
#        'lang_48236EC80FDDDFADE99420ABC9210DDF',
#        'lang_691890251F2B9FF922BE6D3699ABEFD2',
#        'lang_920502FAA080485768AA89BC96A55C47',
#        'lang_0331BF70E606D62D92C96CE9AD71A7CF',
#        'lang_89616CFF8EC8637092F885C7EFF43D74',
#        'lang_06BEAB41D66CCFF329D1ED8BA120A6C2',
#        'lang_60FBA0E834CC59D647C3599AD763FFDF',
#        'lang_C7A400D9AD489ACF673CF12FBB80AAE5',
#        'lang_E59EF8BB86A6D815331DDF4C467CE0C7',
#        'lang_4249CE88433AEA3F8DCEECF008B3CB95',
#        'lang_544FA32458C903F1125FE6598300A047',
#        'lang_CB11E9CF42BD0A1BAD5E27BF3422D99D',
#        'lang_3A85BCEC571C3F5AB1069E4924189177',
#        'lang_FF7EABB5A382356D54D9C41BA0125E09',
#        'lang_E7BB61D2A87C1E72DF1C7BC292B86A1C',
#        'lang_69C4A33B9AD29AF883D60BA61CC08702',
#        'lang_F4FD40A716F1572C9A28E9CAA58BE3A5',
#        'lang_259A6F6DFD672CB1F883CBEC01B99F2D',
#        'lang_6431A618DCF7F4CB7F62A95A39BAB77A',
#        'lang_3121F7240D488F74EEED9312E174B217',
#        'lang_54208B51D44E7D91DC2F3DD02ADEDEC2',
#        'lang_DBEEFB80F8A314311E2B4BD593E11DFE',
#        'lang_B6D90127A09AB1229731898AEF9D4D7C',
#        'lang_F3E1016563360F9434FA986CA86C249C',
#        'lang_2216D01F7B48554E4211021A46816FCF',
#        'lang_1BC639981AE88E09129594B11F894A21',
#        'lang_C942E369C88CE7C56E69A84D04319FF0',
#        'lang_57ADD4576E2AD6648E9B2DE32F3462A5',
#        'lang_AC1F0671A4B0D5B8112F87DE7B490E6D',
#        'lang_C2EF5FABE7619D8A333D5F0FF76E1BFA',
#        'lang_AA0254541959271ED3453119B787D0C3',
#        'lang_A6B70CDF8C7B934D4A218CA9B6B7FDB4',
#        'lang_BF477808A37E3E4E9C5D9F1839E8519E',
#        'lang_97F81BD92A1ACA3F1F43C154E689350F',
#        'lang_60A3DB168094D41241E45E0DE3539BC0',
#        'lang_12D8CEB94F89D11D7EB95EAE9689B009',
#        'lang_F73266A79468BB89C4325FDEDB0B533C',
#        'lang_4690215948DBF6872B8ED1C2BC87B17E',
#        'lang_D18801336202297E6484F634CAC6592E',
#        'lang_2E18F6F53E3CF073911AF0A93BBE5373',
#        'lang_B2235C8B73239FDC5780DD132419833A',
#        'lang_515E873C86EE1577E75FA2387B7FA59E', 'retwt', 'reply', 'like',
#        'retwt_cmmnt'],
#       dtype='object')

# %%
cols_feat=[o for o in df.columns if o not in cols_tgt]

# %%
# %%time
split=int(len(df)*0.85)
Xtr,Xvl=df[cols_feat][:split],df[cols_feat][split:]
ytr,yvl=df[cols_tgt ][:split],df[cols_tgt ][split:]
# Out:
# CPU times: user 243 ms, sys: 379 ms, total: 622 ms
# Wall time: 630 ms

# %%
Xtr.shape,Xvl.shape,ytr.shape,yvl.shape
# Out:
# ((850000, 93), (150000, 93), (850000, 4), (150000, 4))

# %% [markdown]
# # model

# %%
params = {
    'objective': 'binary:logistic',
    'verbosity': 2,
    'eval_metric': ['error', 'logloss'],
#     https://xgboost.readthedocs.io/en/latest/tutorials/param_tuning.html
#     'max_delta_step': 1,
}
num_rounds = 800

# %%
tgt2bst={}
tgt2ytr={}
tgt2yvl={}
tgt2evalres={}
for i,tgt in enumerate(tgts):
    evals_result = {}
    print(dtnow(), tgt, '*'*80)
    tgt2ytr[tgt]=ytr.iloc[:,i]
    tgt2yvl[tgt]=yvl.iloc[:,i]
    dtr = xgb.DMatrix(Xtr, label=ytr.iloc[:,i], feature_names=cols_feat)
    dvl = xgb.DMatrix(Xvl, label=yvl.iloc[:,i], feature_names=cols_feat)
    evallist = [(dtr, 'train'), (dvl, 'eval')]
    bst = xgb.train(params=params, dtrain=dtr, num_boost_round=num_rounds, 
                    evals=evallist, evals_result=evals_result, early_stopping_rounds=10)
    tgt2bst[tgt] = bst
    tgt2evalres[tgt] = evals_result
pickle.dump(tgt2bst, open(f"{p_out}/tgt2bst.p", "wb"))
# Out:
# 2020-03-20 14:20:40 Retweet ********************************************************************************
# [14:20:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-error:0.11053	train-logloss:0.53311	eval-error:0.11124	eval-logloss:0.53347
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 10 rounds.
# [14:20:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [1]	train-error:0.11016	train-logloss:0.44794	eval-error:0.11111	eval-logloss:0.44842
# [14:20:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.11011	train-logloss:0.39835	eval-error:0.11103	eval-logloss:0.39909
# [14:20:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.10997	train-logloss:0.36824	eval-error:0.11093	eval-logloss:0.36908
# [14:20:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.10983	train-logloss:0.34944	eval-error:0.11110	eval-logloss:0.35056
# [14:20:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.10962	train-logloss:0.33828	eval-error:0.11100	eval-logloss:0.33964
# [14:20:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.10965	train-logloss:0.33045	eval-error:0.11097	eval-logloss:0.33199
# [14:20:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.10961	train-logloss:0.32555	eval-error:0.11074	eval-logloss:0.32727
# [14:20:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.10948	train-logloss:0.32229	eval-error:0.11060	eval-logloss:0.32409
# [14:20:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.10945	train-logloss:0.31966	eval-error:0.11059	eval-logloss:0.32156
# [14:21:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [10]	train-error:0
26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [44]	train-error:0.10834	train-logloss:0.30596	eval-error:0.10988	eval-logloss:0.31196
# [14:21:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [45]	train-error:0.10833	train-logloss:0.30589	eval-error:0.10989	eval-logloss:0.31195
# [14:21:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 100 extra nodes, 0 pruned nodes, max_depth=6
# [46]	train-error:0.10831	train-logloss:0.30574	eval-error:0.10989	eval-logloss:0.31186
# [14:21:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [47]	train-error:0.10828	train-logloss:0.30541	eval-error:0.10987	eval-logloss:0.31168
# [14:21:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [48]	train-error:0.10824	train-logloss:0.30516	eval-error:0.10989	eval-logloss:0.31160
# [14:21:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 94 extra nodes, 0 pruned nodes, max_depth=6
# [49]	train-error:0.10823	train-logloss:0.30506	eval-error:0.10991	eval-logloss:0.31161
# [14:21:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [50]	train-error:0.10819	train-logloss:0.30484	eval-error:0.10993	eval-logloss:0.31149
# [14:21:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [51]	train-error:0.10819	train-logloss:0.30469	eval-error:0.10991	eval-logloss:0.31140
# [14:21:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=6
# [52]	train-error:0.10819	train-logloss:0.30461	eval-error:0.10990	eval-logloss:0.31140
# [14:21:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [53]	train-error:0.10817	train-logloss:0.30454	eval-error:0.10987	eval-logloss:0.31137
# [14:21:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [54]	train-error:0.10816	train-logloss:0.30445	eval-error:0.10986	eval-logloss:0.31135
# [14:21:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 82 extra nodes, 0 pruned nodes, max_depth=6
# [55]	train-error:0.10815	train-logloss:0.30435	eval-error:0.10989	eval-logloss:0.31133
# [14:21:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [56]	train-error:0.10814	train-logloss:0.30428	eval-error:0.10990	eval-logloss:0.31132
# [14:21:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [57]	train-error:0.10810	train-logloss:0.30419	eval-error:0.10990	eval-logloss:0.31128
# [14:21:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [58]	train-error:0.10808	train-logloss:0.30414	eval-error:0.10988	eval-logloss:0.31128
# [14:21:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [59]	train-error:0.10804	train-logloss:0.30386	eval-error:0.10986	eval-logloss:0.31115
# [14:21:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 100 extra nodes, 0 pruned nodes, max_depth=6
# [60]	train-error:0.10801	train-logloss:0.30375	eval-error:0.10984	eval-logloss:0.31112
# [14:21:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [61]	train-error:0.10799	train-logloss:0.30354	eval-error:0.10989	eval-logloss:0.31100
# [14:21:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [62]	train-error:0.10797	train-logloss:0.30338	eval-error:0.10995	eval-logloss:0.31099
# [14:21:41] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [63]	train-error:0.10796	train-logloss:0.30331	eval-error:0.10993	eval-logloss:0.31095
# [14:21:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=6
# [64]	train-error:0.10794	train-logloss:0.30325	eval-error:0.10991	eval-logloss:0.31093
# [14:21:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [65]	train-error:0.10792	train-logloss:0.30309	eval-error:0.10989	eval-logloss:0.31088
# [14:21:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [66]	train-error:0.10787	train-logloss:0.30289	eval-error:0.10987	eval-logloss:0.31084
# [14:21:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [67]	train-error:0.10780	train-logloss:0.30267	eval-error:0.10989	eval-logloss:0.31078
# [14:21:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 82 extra nodes, 0 pruned nodes, max_depth=6
# [68]	train-error:0.10779	train-logloss:0.30258	eval-error:0.10985	eval-logloss:0.31074
# [14:21:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 82 extra nodes, 0 pruned nodes, max_depth=6
# [69]	train-error:0.10778	train-logloss:0.30252	eval-error:0.10987	eval-logloss:0.31074
# [14:21:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [70]	train-error:0.10779	train-logloss:0.30244	eval-error:0.10990	eval-logloss:0.31070
# [14:21:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [71]	train-error:0.10770	train-logloss:0.30232	eval-error:0.10993	eval-logloss:0.31070
# [14:21:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [72]	train-error:0.10766	train-logloss:0.30211	eval-error:0.10993	eval-logloss:0.31068
# [14:21:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [73]	train-error:0.10762	train-logloss:0.30201	eval-error:0.10989	eval-logloss:0.31068
# [14:21:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [74]	train-error:0.10761	train-logloss:0.30197	eval-error:0.10990	eval-logloss:0.31068
# [14:21:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [75]	train-error:0.10761	train-logloss:0.30194	eval-error:0.10991	eval-logloss:0.31069
# [14:21:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [76]	train-error:0.10756	train-logloss:0.30182	eval-error:0.10988	eval-logloss:0.31068
# [14:21:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=6
# [77]	train-error:0.10755	train-logloss:0.30177	eval-error:0.10989	eval-logloss:0.31067
# [14:21:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=6
# [78]	train-error:0.10751	train-logloss:0.30170	eval-error:0.10991	eval-logloss:0.31068
# [14:21:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [79]	train-error:0.10750	train-logloss:0.30167	eval-error:0.10990	eval-logloss:0.31069
# [14:21:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [80]	train-error:0.10750	train-logloss:0.30151	eval-error:0.10990	eval-logloss:0.31070
# [14:21:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [81]	train-error:0.10747	train-logloss:0.30146	eval-error:0.10991	eval-logloss:0.31071
# [14:21:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [82]	train-error:0.10747	train-logloss:0.30142	eval-error:0.10991	eval-logloss:0.31072
# [14:21:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [83]	train-error:0.10744	train-logloss:0.30136	eval-error:0.10988	eval-logloss:0.31071
# [14:21:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 86 extra nodes, 0 pruned nodes, max_depth=6
# [84]	train-error:0.10743	train-logloss:0.30130	eval-error:0.10989	eval-logloss:0.31074
# [14:21:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [85]	train-error:0.10742	train-logloss:0.30111	eval-error:0.10993	eval-logloss:0.31069
# [14:21:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 94 extra nodes, 0 pruned nodes, max_depth=6
# [86]	train-error:0.10739	train-logloss:0.30101	eval-error:0.10989	eval-logloss:0.31071
# [14:21:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [87]	train-error:0.10737	train-logloss:0.30090	eval-error:0.10990	eval-logloss:0.31068
# Stopping. Best iteration:
# [77]	train-error:0.10755	train-logloss:0.30177	eval-error:0.10989	eval-logloss:0.31067
#
# 2020-03-20 14:21:59 Reply ********************************************************************************
# [14:22:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 86 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-error:0.02778	train-logloss:0.46430	eval-error:0.02715	eval-logloss:0.46409
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 10 rounds.
# [14:22:11] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [1]	train-error:0.02778	train-logloss:0.33931	eval-error:0.02715	eval-logloss:0.33888
# [14:22:12] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.02778	train-logloss:0.26232	eval-error:0.02715	eval-logloss:0.26181
# [14:22:12] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.02778	train-logloss:0.21258	eval-error:0.02715	eval-logloss:0.21193
# [14:22:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.02778	train-logloss:0.17952	eval-error:0.02715	eval-logloss:0.17885
# [14:22:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.02778	train-logloss:0.15736	eval-error:0.02715	eval-logloss:0.15663
# [14:22:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.02778	train-logloss:0.14244	eval-error:0.02715	eval-logloss:0.14171
# [14:22:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.02778	train-logloss:0.13241	eval-error:0.02715	eval-logloss:0.13168
# [14:22:16] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.02778	train-logloss:0.12575	eval-error:0.02715	eval-logloss:0.12501
# [14:22:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.02778	train-logloss:0.12124	eval-error:0.02715	eval-logloss:0.12059
# [14:22:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [10]	train-error:0.02777	train-logloss:0.11820	eval-error:0.02715	eval-logloss:0.11764
# [14:22:19] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [11]	train-error:0.02778	train-logloss:0.11621	eval-error:0.02714	eval-logloss:0.11574
# [14:22:19] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [12]	train-error:0.02777	train-logloss:0.11488	eval-error:0.02714	eval-logloss:0.11452
# [14:22:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [13]	train-error:0
46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [47]	train-error:0.02771	train-logloss:0.10825	eval-error:0.02716	eval-logloss:0.11152
# [14:22:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=6
# [48]	train-error:0.02771	train-logloss:0.10815	eval-error:0.02717	eval-logloss:0.11153
# [14:22:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [49]	train-error:0.02771	train-logloss:0.10803	eval-error:0.02717	eval-logloss:0.11151
# [14:22:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [50]	train-error:0.02771	train-logloss:0.10798	eval-error:0.02717	eval-logloss:0.11151
# [14:22:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [51]	train-error:0.02771	train-logloss:0.10794	eval-error:0.02717	eval-logloss:0.11152
# [14:22:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [52]	train-error:0.02771	train-logloss:0.10789	eval-error:0.02717	eval-logloss:0.11152
# [14:22:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [53]	train-error:0.02771	train-logloss:0.10779	eval-error:0.02717	eval-logloss:0.11149
# [14:22:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [54]	train-error:0.02770	train-logloss:0.10768	eval-error:0.02717	eval-logloss:0.11149
# [14:22:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [55]	train-error:0.02770	train-logloss:0.10762	eval-error:0.02717	eval-logloss:0.11149
# [14:22:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 108 extra nodes, 0 pruned nodes, max_depth=6
# [56]	train-error:0.02770	train-logloss:0.10751	eval-error:0.02717	eval-logloss:0.11150
# [14:22:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 94 extra nodes, 0 pruned nodes, max_depth=6
# [57]	train-error:0.02770	train-logloss:0.10742	eval-error:0.02717	eval-logloss:0.11150
# [14:22:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [58]	train-error:0.02769	train-logloss:0.10732	eval-error:0.02717	eval-logloss:0.11149
# [14:22:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [59]	train-error:0.02769	train-logloss:0.10725	eval-error:0.02717	eval-logloss:0.11147
# [14:22:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [60]	train-error:0.02769	train-logloss:0.10718	eval-error:0.02718	eval-logloss:0.11146
# [14:22:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [61]	train-error:0.02769	train-logloss:0.10708	eval-error:0.02718	eval-logloss:0.11145
# [14:22:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [62]	train-error:0.02769	train-logloss:0.10706	eval-error:0.02718	eval-logloss:0.11144
# [14:22:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [63]	train-error:0.02769	train-logloss:0.10699	eval-error:0.02718	eval-logloss:0.11145
# [14:22:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [64]	train-error:0.02769	train-logloss:0.10694	eval-error:0.02718	eval-logloss:0.11144
# [14:23:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=6
# [65]	train-error:0.02768	train-logloss:0.10688	eval-error:0.02718	eval-logloss:0.11145
# [14:23:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [66]	train-error:0.02768	train-logloss:0.10678	eval-error:0.02717	eval-logloss:0.11145
# [14:23:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [67]	train-error:0.02768	train-logloss:0.10674	eval-error:0.02717	eval-logloss:0.11145
# [14:23:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [68]	train-error:0.02768	train-logloss:0.10668	eval-error:0.02717	eval-logloss:0.11146
# [14:23:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [69]	train-error:0.02768	train-logloss:0.10657	eval-error:0.02717	eval-logloss:0.11146
# [14:23:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [70]	train-error:0.02767	train-logloss:0.10646	eval-error:0.02717	eval-logloss:0.11146
# [14:23:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [71]	train-error:0.02767	train-logloss:0.10640	eval-error:0.02716	eval-logloss:0.11146
# [14:23:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=6
# [72]	train-error:0.02767	train-logloss:0.10636	eval-error:0.02716	eval-logloss:0.11146
# [14:23:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=6
# [73]	train-error:0.02767	train-logloss:0.10629	eval-error:0.02717	eval-logloss:0.11149
# [14:23:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
#
05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [59]	train-error:0.31053	train-logloss:0.58544	eval-error:0.31849	eval-logloss:0.59363
# [14:24:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 94 extra nodes, 0 pruned nodes, max_depth=6
# [60]	train-error:0.31042	train-logloss:0.58521	eval-error:0.31839	eval-logloss:0.59345
# [14:24:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [61]	train-error:0.31007	train-logloss:0.58487	eval-error:0.31827	eval-logloss:0.59323
# [14:24:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [62]	train-error:0.31000	train-logloss:0.58470	eval-error:0.31823	eval-logloss:0.59310
# ...
# [302]	train-error:0.28611	train-logloss:0.55480	eval-error:0.30777	eval-logloss:0.57969
# [14:27:09] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [303]	train-error:0.28604	train-logloss:0.55473	eval-error:0.30770	eval-logloss:0.57963
# [14:27:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [304]	train-error:0.28600	train-logloss:0.55471	eval-error:0.30768	eval-logloss:0.57964
# [14:27:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [305]	train-error:0.28601	train-logloss:0.55465	eval-error:0.30753	eval-logloss:0.57963
# [14:27:11] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [306]	train-error:0.28584	train-logloss:0.55448	eval-error:0.30740	eval-logloss:0.57950
# [14:27:12] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [307]	train-error:0.28578	train-logloss:0.55439	eval-error:0.30745	eval-logloss:0.57951
# [14:27:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [308]	train-error:0.28568	train-logloss:0.55427	eval-error:0.30737	eval-logloss:0.57945
# [14:27:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=6
# [309]	train-error:0.28566	train-logloss:0.55422	eval-error:0.30737	eval-logloss:0.57946
# [14:27:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=6
# [310]	train-error:0.28563	train-logloss:0.55415	eval-error:0.30741	eval-logloss:0.57949
# [14:27:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [311]	train-error:0.28552	train-logloss:0.55403	eval-error:0.30732	eval-logloss:0.57951
# [14:27:16] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [312]	train-error:0.28542	train-logloss:0.55389	eval-error:0.30728	eval-logloss:0.57952
# [14:27:16] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 84 extra nodes, 0 pruned nodes, max_depth=6
# [313]	train-error:0.28534	train-logloss:0.55380	eval-error:0.30725	eval-logloss:0.57950
# [14:27:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [314]	train-error:0.28530	train-logloss:0.55375	eval-error:0.30730	eval-logloss:0.57952
# [14:27:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [315]	train-error:0.28525	train-logloss:0.55367	eval-error:0.30728	eval-logloss:0.57953
# [14:27:19] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [316]	train-error:0.28513	train-logloss:0.55354	eval-error:0.30732	eval-logloss:0.57954
# [14:27:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [317]	train-error:0.28493	train-logloss:0.55336	eval-error:0.30729	eval-logloss:0.57943
# [14:27:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [318]	train-error:0.28479	train-logloss:0.55325	eval-error:0.30731	eval-logloss:0.57942
# [14:27:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [319]	train-error:0.28468	train-logloss:0.55311	eval-error:0.30728	eval-logloss:0.57943
# [14:27:22] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 76 extra nodes, 0 pruned nodes, max_depth=6
# [320]	train-error:0.28457	train-logloss:0.55302	eval-error:0.30726	eval-logloss:0.57943
# [14:27:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [321]	train-error:0.28447	train-logloss:0.55287	eval-error:0.30728	eval-logloss:0.57939
# [14:27:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [322]	train-error:0.28441	train-logloss:0.55278	eval-error:0.30727	eval-logloss:0.57935
# [14:27:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [323]	train-error:0.28436	train-logloss:0.55267	eval-error:0.30721	eval-logloss:0.57934
# [14:27:25] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=6
# [324]	train-error:0.28426	train-logloss:0.55256	eval-error:0.30711	eval-logloss:0.57926
# [14:27:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [325]	train-error:0.28413	train-logloss:0.55245	eval-error:0.30715	eval-logloss:0.57929
# [14:27:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [326]	train-error:0.28407	train-logloss:0.55229	eval-error:0.30712	eval-logloss:0.57924
# [14:27:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 94 extra nodes, 0 pruned nodes, max_depth=6
# [327]	train-error:0.28397	train-logloss:0.55220	eval-error:0.30709	eval-logloss:0.57925
# [14:27:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [328]	train-error:0.28388	train-logloss:0.55211	eval-error:0.30725	eval-logloss:0.57930
# [14:27:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [329]	train-error:0.28382	train-logloss:0.55198	eval-error:0.30738	eval-logloss:0.57930
# [14:27:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [330]	train-error:0.28373	train-logloss:0.55190	eval-error:0.30726	eval-logloss:0.57932
# [14:27:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [331]	train-error:0.28368	train-logloss:0.55181	eval-error:0.30723	eval-logloss:0.57933
# [14:27:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [332]	train-error:0.28361	train-logloss:0.55170	eval-error:0.30725	eval-logloss:0.57932
# [14:27:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [333]	train-error:0.28352	train-logloss:0.55160	eval-error:0.30737	eval-logloss:0.57932
# [14:27:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [334]	train-error:0.28340	train-logloss:0.55147	eval-error:0.30743	eval-logloss:0.57935
# [14:27:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [335]	train-error:0.28330	train-logloss:0.55135	eval-error:0.30739	eval-logloss:0.57935
# [14:27:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [336]	train-error:0.28320	train-logloss:0.55128	eval-error:0.30739	eval-logloss:0.57936
# Stopping. Best iteration:
# [326]	train-error:0.28407	train-logloss:0.55229	eval-error:0.30712	eval-logloss:0.57924
#
# 2020-03-20 14:27:34 RTwCmnt ********************************************************************************
# [14:27:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-error:0.00778	train-logloss:0.44532	eval-error:0.00759	eval-logloss:0.44526
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 10 rounds.
# [14:27:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [1]	train-error:0.00778	train-logloss:0.30903	eval-error:0.00759	eval-logloss:0.30886
# [14:27:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.00778	train-logloss:0.22379	eval-error:0.00759	eval-logloss:0.22355
# [14:27:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 86 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.00778	train-logloss:0.16739	eval-error:0.00759	eval-logloss:0.16713
# [14:27:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 102 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.00777	train-logloss:0.12898	eval-error:0.00759	eval-logloss:0.12869
# [14:27:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.00777	train-logloss:0.10244	eval-error:0.00759	eval-logloss:0.10207
# [14:27:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.00777	train-logloss:0.08390	eval-error:0.00759	eval-logloss:0.08352
# [14:27:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.00777	train-logloss:0.07097	eval-error:0.00759	eval-logloss:0.07057
# [14:27:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.00777	train-logloss:0.06197	eval-error:0.00759	eval-logloss:0.06156
# [14:27:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.00778	train-logloss:0.05573	eval-error:0.00759	eval-logloss:0.05532
# [14:27:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [10]	train
INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [38]	train-error:0.00777	train-logloss:0.04096	eval-error:0.00759	eval-logloss:0.04278
# [14:28:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [39]	train-error:0.00777	train-logloss:0.04090	eval-error:0.00759	eval-logloss:0.04281
# Stopping. Best iteration:
# [29]	train-error:0.00777	train-logloss:0.04144	eval-error:0.00759	eval-logloss:0.04272

# %%
def show_feat_importance(bst):
    ax = xgb.plot_importance(bst, height=0.8, max_num_features=9)
    ax.grid(False, axis="y")
    ax.set_title('Estimated feature importance')
    plt.show()
    feat2importance=bst.get_fscore()
    display(pd.DataFrame([feat2importance.keys(), feat2importance.values()]).T.sort_values(1, ascending=False).head(20))

# %%
for tgt,bst in tgt2bst.items():
    print(tgt)
    show_feat_importance(bst)
# Out:
# Retweet
#                                         0    1
# 6                           u1_fllwer_cnt  466
# 15                         u1_fllwing_cnt  407
# 1                         u2_follower_cnt  407
# 9                        u2_following_cnt  395
# 7                                len_toks  378
# 13                           u2_create_tm  363
# 18                           u1_create_tm  249
# 21                                     tm  237
# 16                            tmdlta_u2u1  195
# 22                           tmdlta_twtu1  145
# 12                           tmdlta_twtu2  140
# 23                                tm_hour  132
# 10                             num_hshtgs  131
# 4                          twttyp_Retweet   74
# 11  lang_22C448FF81263D4BAF2A176145EE9EAD   59
# 24                        has_media_Photo   59
# 17                              num_links   54
# 34                           tm_dayofweek   51
# 5                         has_media_Video   44
# 20  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   37
# Reply
#                                         0    1
# 8                           u1_fllwer_cnt  383
# 5                        u2_following_cnt  320
# 11                         u1_fllwing_cnt  317
# 17                        u2_follower_cnt  309
# 4                                len_toks  298
# 14                           u2_create_tm  294
# 15                            tmdlta_u2u1  260
# 3                                      tm  249
# 2                            tmdlta_twtu2  196
# 6                            u1_create_tm  188
# 31                                tm_hour  132
# 16                           tmdlta_twtu1  130
# 23                             num_hshtgs   58
# 34                           tm_dayofweek   48
# 7   lang_167115458A0DBDFF7E9C0C53A83BAC9B   41
# 29  lang_22C448FF81263D4BAF2A176145EE9EAD   36
# 18                        twttyp_TopLevel   31
# 9                               num_links   29
# 36                        has_media_Photo   28
# 12  lang_4DC22C3F31C5C43721E6B5815A595ED6   28
# Like
#                                         0     1
# 5                           u1_fllwer_cnt  2868
# 17                         u1_fllwing_cnt  1638
# 6                         u2_follower_cnt  1321
# 8                        u2_following_cnt  1262
# 2                                len_toks  1169
# 10                                     tm  1162
# 3                            u2_create_tm  1098
# 9                            u1_create_tm  1000
# 12                            tmdlta_u2u1   835
# 13                           tmdlta_twtu1   690
# 19                                tm_hour   450
# 7                            tmdlta_twtu2   352
# 18                             num_hshtgs   189
# 34                           tm_dayofweek   182
# 0                          twttyp_Retweet   174
# 1                               num_links   146
# 16                        has_media_Photo   138
# 23                        twttyp_TopLevel   136
# 28  lang_22C448FF81263D4BAF2A176145EE9EAD   134
# 21                             u1_fllw_u2   112
# RTwCmnt
#                                         0    1
# 0                         u2_follower_cnt  188
# 11                          u1_fllwer_cnt  178
# 8                                len_toks  174
# 12                       u2_following_cnt  155
# 17                         u1_fllwing_cnt  152
# 4                            u2_create_tm  146
# 3                            tmdlta_twtu2  105
# 5                             tmdlta_u2u1  103
# 6                                      tm   99
# 15                           u1_create_tm   73
# 18                                tm_hour   49
# 20                           tmdlta_twtu1   48
# 2   lang_22C448FF81263D4BAF2A176145EE9EAD   45
# 9                         has_media_Video   34
# 1                              u1_fllw_u2   30
# 14  lang_4DC22C3F31C5C43721E6B5815A595ED6   29
# 16                         twttyp_Retweet   28
# 32                           tm_dayofweek   19
# 13                        twttyp_TopLevel   18
# 29                             num_hshtgs   18

# %% [markdown]
# ## valid

# %%
for tgt in tgts:
    evalres=tgt2evalres[tgt]
    plt.plot(evalres['train']['error'])
    plt.plot(evalres['eval']['error'])
    plt.title(f"{tgt} error {len(evalres['train']['error'])} rounds")
    plt.show()
    
    plt.plot(evalres['train']['logloss'])
    plt.plot(evalres['eval']['logloss'])
    plt.title(f"{tgt} logloss {len(evalres['train']['logloss'])} rounds")
    plt.show()

# %%
tgt2prdtr={}
tgt2prdvl={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtr[tgt] = bst.predict(dtr)
    tgt2prdvl[tgt] = bst.predict(dvl)
# Out:
# 2020-03-20 14:28:18 Retweet
# 2020-03-20 14:28:19 Reply
# 2020-03-20 14:28:19 Like
# 2020-03-20 14:28:22 RTwCmnt

# %%
tgt2auc_trn={}
tgt2rce_trn={}
tgt2auc_val={}
tgt2rce_val={}
for itgt, tgt in enumerate(tgts):
    print(tgt)
    prdtr_i, prdvl_i = tgt2prdtr[tgt], tgt2prdvl[tgt]
    ytr_i, yvl_i = tgt2ytr[tgt], tgt2yvl[tgt]
    scr_rocauc_trn = roc_auc_score(ytr_i, prdtr_i)
    scr_rocauc_val = roc_auc_score(yvl_i, prdvl_i)
    scr_auc_trn=compute_prauc(prdtr_i, ytr_i)
    scr_rce_trn=compute_rce(prdtr_i, ytr_i)
    scr_auc_val=compute_prauc(prdvl_i, yvl_i)
    scr_rce_val=compute_rce(prdvl_i, yvl_i)

    tgt2auc_trn[tgt]=scr_auc_trn
    tgt2rce_trn[tgt]=scr_rce_trn
    tgt2auc_val[tgt]=scr_auc_val
    tgt2rce_val[tgt]=scr_rce_val
    
    print('train rocauc:', f'{scr_rocauc_trn:.4f}', 'valid auc:', f'{scr_rocauc_val:.4f}', )
    print('train prauc:', f'{scr_auc_trn:.4f}', 'valid auc:', f'{scr_auc_val:.4f}', )
    print('train rce:', f'{scr_rce_trn:.4f}', 'valid rce:', f'{scr_rce_val:.4f}', )
# Out:
# Retweet
# train rocauc: 0.7651 valid auc: 0.7426
# train prauc: 0.3548 valid auc: 0.3141
# train rce: 14.7339 valid rce: 12.1765
# Reply
# train rocauc: 0.8192 valid auc: 0.7700
# train prauc: 0.1723 valid auc: 0.0920
# train rce: 16.3578 valid rce: 10.5661
# Like
# train rocauc: 0.7871 valid auc: 0.7544
# train prauc: 0.7440 valid auc: 0.7013
# train rce: 19.6046 valid rce: 15.4487
# RTwCmnt
# train rocauc: 0.7834 valid auc: 0.6962
# train prauc: 0.0632 valid auc: 0.0173
# train rce: 10.1568 valid rce: 4.0695

# %%
lsttrn=[]
lstval=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    lsttrn+=[(f'PRAUC {tgt}',tgt2auc_trn[tgt]),
          (f'RCE {tgt}',tgt2rce_trn[tgt])]
    lstval+=[(f'PRAUC {tgt}',tgt2auc_val[tgt]),
          (f'RCE {tgt}',tgt2rce_val[tgt])]

dfscrtrn=pd.DataFrame(lsttrn)
dfscrtrn.columns=['metric','scr']
dfscrval=pd.DataFrame(lstval)
dfscrval.columns=['metric','scr']
dfscr = pd.merge(dfscrtrn, dfscrval, on='metric', suffixes=('trn','val'))
dfscr.T
# Out:
#                     0            1            2          3           4  \
# metric  PRAUC Retweet  RCE Retweet  PRAUC Reply  RCE Reply  PRAUC Like
# scrtrn       0.354813      14.7339      0.17228    16.3578    0.743975
# scrval       0.314137      12.1765    0.0919746    10.5661    0.701262
#
#                5              6            7
# metric  RCE Like  PRAUC RTwCmnt  RCE RTwCmnt
# scrtrn   19.6046      0.0632438      10.1568
# scrval   15.4487      0.0173482      4.06954

# %% [markdown]
# # infer

# %% [raw]
# ls -lhS $p_in | grep val

# %%
# %%time
dftst=pd.read_csv(
    f'{p_in}/val_{valtmstmp}.tsv',
#     f'{p_in}/val_259A6F6DFD672CB1F883CBEC01B99F2D_1584405047.tsv',
    sep='\x01', header=None, names=cols_val,)
# Out:
# CPU times: user 1min 38s, sys: 8.77 s, total: 1min 46s
# Wall time: 1min 47s

# %%
# %%time
dftst = prp_df(dftst, istrn=False)
# Out:
# CPU times: user 1min 56s, sys: 9.91 s, total: 2min 6s
# Wall time: 2min 6s

# %%
# %%time
dtst = xgb.DMatrix(dftst[cols_feat], feature_names=cols_feat)
tgt2prdtst={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtst[tgt] = bst.predict(dtst)
# Out:
# 2020-03-20 14:35:37 Retweet
# 2020-03-20 14:35:44 Reply
# 2020-03-20 14:35:50 Like
# 2020-03-20 14:36:29 RTwCmnt
# CPU times: user 15min 29s, sys: 35.8 s, total: 16min 5s
# Wall time: 3min 3s

# %%
dfsub_ids = dftst[['twtid','u2id',]]

tgt2dfsub = {}
for tgt,prdtst in tgt2prdtst.items():
    dfsub = dfsub_ids.copy()
    dfsub['scr'] = prdtst
    tgt2dfsub[tgt]=dfsub

# %%
# %%time
for tgt, dfsub in tgt2dfsub.items():
    print(dtnow(), tgt)
    dfsub.to_csv(f'{p_out}/{tgt}__{valtmstmp}__{PRFX}.csv',index=False,header=False)
# Out:
# 2020-03-20 14:36:34 Retweet
# 2020-03-20 14:37:33 Reply
# 2020-03-20 14:38:33 Like
# 2020-03-20 14:39:32 RTwCmnt
# CPU times: user 3min 49s, sys: 6.79 s, total: 3min 56s
# Wall time: 3min 56s
