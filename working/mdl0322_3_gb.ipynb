# %% [markdown]
# # start

# %% [markdown]
# from 0320_6; on gpubox

# %%
PRFX='0322_3'
trntmstmp=1584412344
valtmstmp=1584979040
import datetime
print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (trntmstmp, valtmstmp)])

grand_total=1.5e8
MIN_TM_TRN=1580947200
MIN_TM_TST=1581552000
print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (MIN_TM_TRN, MIN_TM_TST)])
# Out:
# ['2020-03-17 02:32:24', '2020-03-23 15:57:20']
# ['2020-02-06 00:00:00', '2020-02-13 00:00:00']

# %% [markdown]
# # setup

# %%
from pathlib import Path
import dask
print('dask.__version__', dask.__version__)
import xgboost as xgb
import dask_xgboost
import dask.dataframe as dd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from dask.distributed import Client
import pickle
import lightgbm as lgb
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)

import datetime
def dtnow(): return datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

SEED=101
HOME='/data/git/recsys20'
p_in=f'{HOME}/input'
p_out=f'{HOME}/output/{PRFX}'
Path(p_out).mkdir(exist_ok=True, parents=True)

from sklearn.metrics import precision_recall_curve, auc, log_loss

def compute_prauc(pred, gt):
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return prauc

def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive/float(len(gt))
    return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

cols=[
'toks',
'hshtgs',
'twtid',
'media',
'links',
'domns',
'twttyp',
'lang',
'tm',

'u1id',
'u1_fllwer_cnt',
'u1_fllwng_cnt',
'u1_vrfed',
'u1_create_tm',

'u2id',
'u2_fllwer_cnt',
'u2_fllwng_cnt',
'u2_vrfed',
'u2_create_tm',

'u1_fllw_u2',
'reply_tm',
'retwt_tm',
'retwt_cmmnt_tm',
'like_tm',
]

cols_val = cols[:-4]
cols_tgt_tmstmp=[
    'retwt_tm',
    'reply_tm',
    'like_tm',
    'retwt_cmmnt_tm',
]
cols_tgt=[o.split('_tm')[0] for o in cols_tgt_tmstmp]
tgts             = ['Retweet','Reply','Like','RTwCmnt',]
assert cols_tgt == ['retwt',  'reply','like','retwt_cmmnt',]
ntgts=len(tgts)
# Out:
# dask.__version__ 2.12.0

# %% [markdown]
# # prepare data

# %% [markdown]
# ## get maps from dfval

# %%
# dfval=dd.read_csv(
#     f'{p_in}/val_{valtmstmp}.tsv',
#     sep='\x01', header=None, names=cols_val,)
# lang2cnt=dict(dfval.lang.value_counts().compute())
# ttl=sum(lang2cnt.values())
# lang2perc={k:v/ttl for k,v in lang2cnt.items()}
langs=['D3164C7FBCF2565DDF915B1B3AEFB1DC', '22C448FF81263D4BAF2A176145EE9EAD', '06D61DCBBE938971E1EA0C38BD9B5446', 'ECED8A16BE2A5E8871FD55F4842F16B1', 'B9175601E87101A984A50F8A62A1C374', '4DC22C3F31C5C43721E6B5815A595ED6', '167115458A0DBDFF7E9C0C53A83BAC9B', '125C57F4FA6D4E110983FB11B52EFD4E', '022EC308651FACB02794A8147AEE1B78', 'FA3F382BC409C271E3D6EAF8BE4648DD', '9BF3403E0EB7EA8A256DA9019C0B0716', '975B38F44D65EE42A547283787FF5A21', '2996EB2FE8162C076D070A4C8D6532CD', 'FF60A88F53E63000266F8B9149E35AD9', '717293301FE296B0B61950D041485825', '3E16B11B7ADE3A22DDFC4423FBCEAD5D', '3820C29CBCA409A33BADF68852057C4A', '9ECD42BC079C20F156F53CB3B99E600E', '76B8A9C3013AE6414A3E6012413CDC3B', 'AEF22666801F0A5846D853B9CEB2E327', '190BA7DA361BC06BC1D7E824C378064D', '1FFD2FE4297F5E70EBC6C3230D95CB9C', 'A0C7021AD8299ADF0C9EBE326C115F6F', 'D413F5FE5236E5650A46FD983AB39212', '48236EC80FDDDFADE99420ABC9210DDF', '691890251F2B9FF922BE6D3699ABEFD2', '920502FAA080485768AA89BC96A55C47', '0331BF70E606D62D92C96CE9AD71A7CF', '89616CFF8EC8637092F885C7EFF43D74', '06BEAB41D66CCFF329D1ED8BA120A6C2', '60FBA0E834CC59D647C3599AD763FFDF', 'C7A400D9AD489ACF673CF12FBB80AAE5', 'E59EF8BB86A6D815331DDF4C467CE0C7', '4249CE88433AEA3F8DCEECF008B3CB95', '544FA32458C903F1125FE6598300A047', 'CB11E9CF42BD0A1BAD5E27BF3422D99D', '3A85BCEC571C3F5AB1069E4924189177', 'FF7EABB5A382356D54D9C41BA0125E09', 'E7BB61D2A87C1E72DF1C7BC292B86A1C', '69C4A33B9AD29AF883D60BA61CC08702', 'F4FD40A716F1572C9A28E9CAA58BE3A5', '259A6F6DFD672CB1F883CBEC01B99F2D', '6431A618DCF7F4CB7F62A95A39BAB77A', '3121F7240D488F74EEED9312E174B217', '54208B51D44E7D91DC2F3DD02ADEDEC2', 'DBEEFB80F8A314311E2B4BD593E11DFE', 'B6D90127A09AB1229731898AEF9D4D7C', 'F3E1016563360F9434FA986CA86C249C', '2216D01F7B48554E4211021A46816FCF', '1BC639981AE88E09129594B11F894A21', 'C942E369C88CE7C56E69A84D04319FF0', '57ADD4576E2AD6648E9B2DE32F3462A5', 'AC1F0671A4B0D5B8112F87DE7B490E6D', 'C2EF5FABE7619D8A333D5F0FF76E1BFA', 'AA0254541959271ED3453119B787D0C3', 'A6B70CDF8C7B934D4A218CA9B6B7FDB4', 'BF477808A37E3E4E9C5D9F1839E8519E', '97F81BD92A1ACA3F1F43C154E689350F', '60A3DB168094D41241E45E0DE3539BC0', '12D8CEB94F89D11D7EB95EAE9689B009', 'F73266A79468BB89C4325FDEDB0B533C', '4690215948DBF6872B8ED1C2BC87B17E', 'D18801336202297E6484F634CAC6592E', '2E18F6F53E3CF073911AF0A93BBE5373', 'B2235C8B73239FDC5780DD132419833A', '515E873C86EE1577E75FA2387B7FA59E',]

# dfval.twttyp.value_counts().compute()
# TopLevel    2932
# Retweet      994
# Quote        213
twttyps=['TopLevel','Retweet','Quote']

# %%
def prp_df(df, istrn=True):
    tm_min = MIN_TM_TRN if istrn else MIN_TM_TST
    df['len_toks'] = df.toks.apply(len)
    for media in ['Photo', 'Video', 'GIF']:
        df[f'has_media_{media}'] = df.media.fillna('').apply(lambda x: media in x)
    for col in ['hshtgs', 'links', 'domns',]:
        df[f'num_{col}'] = df[col].fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0)
    
    df['twt_age'] = df.tm - tm_min
    df['u1_age']  = df.tm - df.u1_create_tm
    df['u2_age']  = df.tm - df.u2_create_tm
        
    tm_dt=pd.to_datetime(df.tm, unit='s')
    df['tm_dayofweek']=tm_dt.dt.dayofweek
    df['tm_hour']=tm_dt.dt.hour
    
    df['tmdlta_u2u1']  = df.u2_create_tm - df.u1_create_tm
    
    df['u1_fllwer_cnt_by_age'] = df.u1_fllwer_cnt / df.u1_age
    df['u1_fllwng_cnt_by_age'] = df.u2_fllwng_cnt / df.u2_age
    
    for typ in twttyps:
        df[f'twttyp_{typ}']=(df.twttyp==typ).astype('int8')

    for lang in langs:
        df[f'lang_{lang}']=(df.lang==lang).astype('int8')
    if istrn: 
        df[cols_tgt]=df[cols_tgt_tmstmp].notna().astype('int8')
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 
                                       'tm', 'u1_create_tm','u2_create_tm', 'u1id', 'u2id', 'twtid', ]+cols_tgt_tmstmp, )
    else:
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 
                                       'tm', 'u1_create_tm','u2_create_tm', 'u1id', ])        
    return df

# %% [raw]
# ls -hlS $p_in | grep {trntmstmp}

# %%
grand_total
# Out:
# 150000000.0

# %%
grand_total/1e6
# Out:
# 150.0

# %% [raw]
# chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
#                     header=None,names=cols,
#                         chunksize=1e6
#                        )
# for ichnk,df in enumerate(chnks_trn):
#     print(dtnow(), 'chunk', ichnk, df.tm.max())
# ichnk

# %%
chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                    header=None,names=cols, 
                        chunksize=1e6
                       )

np.random.seed(SEED)
lst_df = []
for ichnk,df in enumerate(chnks_trn):
    print(dtnow(), 'chunk', ichnk)
    print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') 
           for o in (df.tm.min(), df.tm.max())])
    df = prp_df(df)    
    lst_df.append(df)
    if ichnk>=0: break
# Out:
# 2020-03-22 15:55:26 chunk 0
# ['2020-02-06 00:00:00', '2020-02-12 23:59:59']

# %%
df = pd.concat(lst_df)

# %%
df.shape
# Out:
# (1000000, 95)

# %%
# df.columns

# %%
cols_feat=[o for o in df.columns if o not in cols_tgt]

# %%
# %%time
split=int(len(df)*0.85)
Xtr,Xvl=df[cols_feat][:split],df[cols_feat][split:]
ytr,yvl=df[cols_tgt ][:split],df[cols_tgt ][split:]
# Out:
# CPU times: user 214 ms, sys: 281 ms, total: 495 ms
# Wall time: 493 ms

# %%
Xtr.shape,Xvl.shape,ytr.shape,yvl.shape
# Out:
# ((850000, 91), (150000, 91), (850000, 4), (150000, 4))

# %%
tgt2ytr={tgt:ytr.iloc[:,i] for i,tgt in enumerate(tgts)}
tgt2yvl={tgt:yvl.iloc[:,i] for i,tgt in enumerate(tgts)}

# %% [markdown]
# # model

# %%
tgt2bst={}
tgt2evalres={}

tgt2params = {k:{'objective': 'binary:logistic',
    'verbosity': 1,
    'eval_metric': ['aucpr', 'logloss', ],
} for k in tgts}
tgt2params
# Out:
# {'Retweet': {'objective': 'binary:logistic',
#   'verbosity': 1,
#   'eval_metric': ['aucpr', 'logloss']},
#  'Reply': {'objective': 'binary:logistic',
#   'verbosity': 1,
#   'eval_metric': ['aucpr', 'logloss']},
#  'Like': {'objective': 'binary:logistic',
#   'verbosity': 1,
#   'eval_metric': ['aucpr', 'logloss']},
#  'RTwCmnt': {'objective': 'binary:logistic',
#   'verbosity': 1,
#   'eval_metric': ['aucpr', 'logloss']}}

# %%
def traintgt(tgt):
    evals_result = {}
    i=tgts.index(tgt)
    params = tgt2params[tgt]
    print(tgt, params)
    dtr = xgb.DMatrix(Xtr, label=tgt2ytr[tgt], feature_names=cols_feat)
    dvl = xgb.DMatrix(Xvl, label=tgt2yvl[tgt], feature_names=cols_feat)
    evallist = [(dtr, 'train'), (dvl, 'eval')]
    bst = xgb.train(params=params, dtrain=dtr, num_boost_round=1000, 
                    evals=evallist, evals_result=evals_result, 
                    verbose_eval=20,
                    early_stopping_rounds=50)
    tgt2bst[tgt] = bst
    tgt2evalres[tgt] = evals_result
    return bst,evals_result

# %%
tgts
# Out:
# ['Retweet', 'Reply', 'Like', 'RTwCmnt']

# %%
for i,tgt in enumerate(tgts):
    print(dtnow(), tgt, '*'*80)
    tgt2bst[tgt],tgt2evalres[tgt] = traintgt(tgt)
pickle.dump(tgt2bst, open(f"{p_out}/tgt2bst.p", "wb"))
# Out:
# 2020-03-22 15:19:55 Retweet ********************************************************************************
# Retweet {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['aucpr', 'logloss']}
# [0]	train-aucpr:0.25822	train-logloss:0.53334	eval-aucpr:0.25622	eval-logloss:0.53337
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [20]	train-aucpr:0.31836	train-logloss:0.31108	eval-aucpr:0.30334	eval-logloss:0.31477
# [40]	train-aucpr:0.33502	train-logloss:0.30614	eval-aucpr:0.31123	eval-logloss:0.31214
# [60]	train-aucpr:0.34519	train-logloss:0.30325	eval-aucpr:0.31435	eval-logloss:0.31100
# [80]	train-aucpr:0.35468	train-logloss:0.30102	eval-aucpr:0.31636	eval-logloss:0.31048
# [100]	train-aucpr:0.36190	train-logloss:0.29929	eval-aucpr:0.31705	eval-logloss:0.31025
# [120]	train-aucpr:0.37242	train-logloss:0.29687	eval-aucpr:0.31701	eval-logloss:0.31018
# [140]	train-aucpr:0.37963	train-logloss:0.29533	eval-aucpr:0.31733	eval-logloss:0.31014
# [160]	train-aucpr:0.38740	train-logloss:0.29353	eval-aucpr:0.31697	eval-logloss:0.31014
# [180]	train-aucpr:0.39431	train-logloss:0.29191	eval-aucpr:0.31683	eval-logloss:0.31011
# [200]	train-aucpr:0.40094	train-logloss:0.29043	eval-aucpr:0.31716	eval-logloss:0.31014
# Stopping. Best iteration:
# [169]	train-aucpr:0.38980	train-logloss:0.29288	eval-aucpr:0.31740	eval-logloss:0.31002
#
# 2020-03-22 15:23:55 Reply ********************************************************************************
# Reply {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['aucpr', 'logloss']}
# [0]	train-aucpr:0.08357	train-logloss:0.46443	eval-aucpr:0.07402	eval-logloss:0.46408
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [20]	train-aucpr:0.12114	train-logloss:0.11134	eval-aucpr:0.09044	eval-logloss:0.11190
# [40]	train-aucpr:0.14317	train-logloss:0.10867	eval-aucpr:0.09184	eval-logloss:0.11143
# [60]	train-aucpr:0.16200	train-logloss:0.10709	eval-aucpr:0.09230	eval-logloss:0.11141
# [80]	train-aucpr:0.18108	train-logloss:0.10564	eval-aucpr:0.09153	eval-logloss:0.11154
# [100]	train-aucpr:0.19827	train-logloss:0.10440	eval-aucpr:0.09083	eval-logloss:0.11163
# Stopping. Best iteration:
# [55]	train-aucpr:0.15720	train-logloss:0.10749	eval-aucpr:0.09234	eval-logloss:0.11138
#
# 2020-03-22 15:25:57 Like ********************************************************************************
# Like {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['aucpr', 'logloss']}
# [0]	train-aucpr:0.62526	train-logloss:0.65999	eval-aucpr:0.62120	eval-logloss:0.66050
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [20]	train-aucpr:0.67519	train-logloss:0.59977	eval-aucpr:0.66769	eval-logloss:0.60366
# [40]	train-aucpr:0.68798	train-logloss:0.59124	eval-aucpr:0.67713	eval-logloss:0.59730
# [60]	train-aucpr:0.69579	train-logloss:0.58576	eval-aucpr:0.68203	eval-logloss:0.59376
# [80]	train-aucpr:0.70179	train-logloss:0.58176	eval-aucpr:0.68535	eval-logloss:0.59162
# [100]	train-aucpr:0.70730	train-logloss:0.57782	eval-aucpr:0.68850	eval-logloss:0.58924
# [120]	train-aucpr:0.71242	train-logloss:0.57411	eval-aucpr:0.69081	eval-logloss:0.58763
# [140]	train-aucpr:0.71682	train-logloss:0.57075	eval-aucpr:0.69331	eval-logloss:0.58570
# [160]	train-aucpr:0.72037	train-logloss:0.56836	eval-aucpr:0.69445	eval-logloss:0.58490
# [180]	train-aucpr:0.72363	train-logloss:0.56620	eval-aucpr:0.69519	eval-logloss:0.58435
# [200]	train-aucpr:0.72690	train-logloss:0.56367	eval-aucpr:0.69677	eval-logloss:0.58313
# [220]	train-aucpr:0.72973	train-logloss:0.56164	eval-aucpr:0.69719	eval-logloss:0.58267
# [240]	train-aucpr:0.73241	train-logloss:0.55975	eval-aucpr:0.69764	eval-logloss:0.58239
# [260]	train-aucpr:0.73583	train-logloss:0.55722	eval-aucpr:0.69908	eval-logloss:0.58143
# [280]	train-aucpr:0.73812	train-logloss:0.55571	eval-aucpr:0.69908	eval-logloss:0.58142
# [300]	train-aucpr:0.73978	train-logloss:0.55444	eval-aucpr:0.69922	eval-logloss:0.58124
# [320]	train-aucpr:0.74260	train-logloss:0.55229	eval-aucpr:0.69979	eval-logloss:0.58075
# [340]	train-aucpr:0.74511	train-logloss:0.55031	eval-aucpr:0.70047	eval-logloss:0.58023
# [360]	train-aucpr:0.74709	train-logloss:0.54892	eval-aucpr:0.70085	eval-logloss:0.57998
# [380]	train-aucpr:0.74953	train-logloss:0.54697	eval-aucpr:0.70139	eval-logloss:0.57955
# [400]	train-aucpr:0.75184	train-logloss:0.54525	eval-aucpr:0.70176	eval-logloss:0.57923
# [420]	train-aucpr:0.75393	train-logloss:0.54361	eval-aucpr:0.70186	eval-logloss:0.57908
# [440]	train-aucpr:0.75647	train-logloss:0.54159	eval-aucpr:0.70279	eval-logloss:0.57834
# [460]	train-aucpr:0.75835	train-logloss:0.54029	eval-aucpr:0.70271	eval-logloss:0.57830
# [480]	train-aucpr:0.76044	train-logloss:0.53874	eval-aucpr:0.70331	eval-logloss:0.57793
# [500]	train-aucpr:0.76216	train-logloss:0.53741	eval-aucpr:0.70378	eval-logloss:0.57751
# [520]	train-aucpr:0.76413	train-logloss:0.53595	eval-aucpr:0.70383	eval-logloss:0.57745
# [540]	train-aucpr:0.76648	train-logloss:0.53407	eval-aucpr:0.70390	eval-logloss:0.57734
# [560]	train-aucpr:0.76817	train-logloss:0.53276	eval-aucpr:0.70379	eval-logloss:0.57740
# Stopping. Best iteration:
# [528]	train-aucpr:0.76508	train-logloss:0.53516	eval-aucpr:0.70407	eval-logloss:0.57728
#
# 2020-03-22 15:37:31 RTwCmnt ********************************************************************************
# RTwCmnt {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['aucpr', 'logloss']}
# [0]	train-aucpr:0.01364	train-logloss:0.44555	eval-aucpr:0.01209	eval-logloss:0.44525
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [20]	train-aucpr:0.04424	train-logloss:0.04240	eval-aucpr:0.01678	eval-logloss:0.04288
# [40]	train-aucpr:0.07194	train-logloss:0.04055	eval-aucpr:0.01808	eval-logloss:0.04278
# [60]	train-aucpr:0.10395	train-logloss:0.03933	eval-aucpr:0.01741	eval-logloss:0.04296
# Stopping. Best iteration:
# [26]	train-aucpr:0.05386	train-logloss:0.04158	eval-aucpr:0.01811	eval-logloss:0.04273

# %%
for tgt in tgt2evalres:
    evalres=tgt2evalres[tgt]
    plt.plot(evalres['train']['logloss'][10:])
    plt.plot(evalres['eval']['logloss'][10:])
    plt.title(f"{tgt} logloss {len(evalres['train']['logloss'])} rounds")
    plt.show()
    plt.plot(evalres['train']['aucpr'])
    plt.plot(evalres['eval']['aucpr'])
    plt.title(f"{tgt} aucpr {len(evalres['train']['aucpr'])} rounds")
    plt.show()

# %%
def show_feat_importance(tgt):
    bst=tgt2bst[tgt]
    ax = xgb.plot_importance(bst, height=0.8, max_num_features=9)
    ax.grid(False, axis="y")
    ax.set_title(f'{tgt} Estimated feature importance')
    plt.show()
    feat2importance=bst.get_fscore()
    print(tgt)
    display(pd.DataFrame([feat2importance.keys(), 
                          feat2importance.values()]).T.sort_values(1, ascending=False))

for tgt in tgt2bst:
    show_feat_importance(tgt)
# Out:
# Retweet
#                                         0    1
# 1                           u2_fllwer_cnt  901
# 14                                 u2_age  855
# 19                                 u1_age  812
# 16                          u1_fllwng_cnt  807
# 9                           u2_fllwng_cnt  774
# 6                           u1_fllwer_cnt  770
# 7                                len_toks  747
# 22                                twt_age  736
# 10                   u1_fllwer_cnt_by_age  733
# 13                   u1_fllwng_cnt_by_age  689
# 17                            tmdlta_u2u1  504
# 23                                tm_hour  329
# 11                             num_hshtgs  201
# 4                          twttyp_Retweet  121
# 12  lang_22C448FF81263D4BAF2A176145EE9EAD  109
# 28                           tm_dayofweek  102
# 21                        has_media_Photo   94
# 5                         has_media_Video   83
# 26                        twttyp_TopLevel   73
# 20  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   73
# 24                             u1_fllw_u2   71
# 18                              num_links   68
# 35  lang_ECED8A16BE2A5E8871FD55F4842F16B1   48
# 0   lang_022EC308651FACB02794A8147AEE1B78   47
# 3                                u1_vrfed   46
# 2   lang_125C57F4FA6D4E110983FB11B52EFD4E   38
# 15  lang_4DC22C3F31C5C43721E6B5815A595ED6   36
# 30  lang_06D61DCBBE938971E1EA0C38BD9B5446   35
# 27  lang_167115458A0DBDFF7E9C0C53A83BAC9B   27
# 31                           twttyp_Quote   27
# 33  lang_B9175601E87101A984A50F8A62A1C374   24
# 8                           has_media_GIF   21
# 39  lang_9BF3403E0EB7EA8A256DA9019C0B0716   19
# 32  lang_FA3F382BC409C271E3D6EAF8BE4648DD   16
# 25  lang_975B38F44D65EE42A547283787FF5A21   16
# 29  lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D   14
# 34  lang_2996EB2FE8162C076D070A4C8D6532CD   11
# 36  lang_3820C29CBCA409A33BADF68852057C4A   10
# 46                               u2_vrfed    8
# 37  lang_FF60A88F53E63000266F8B9149E35AD9    8
# 51  lang_57ADD4576E2AD6648E9B2DE32F3462A5    7
# 44  lang_E7BB61D2A87C1E72DF1C7BC292B86A1C    7
# 50  lang_6431A618DCF7F4CB7F62A95A39BAB77A    6
# 38  lang_CB11E9CF42BD0A1BAD5E27BF3422D99D    6
# 43  lang_0331BF70E606D62D92C96CE9AD71A7CF    6
# 42  lang_9ECD42BC079C20F156F53CB3B99E600E    6
# 41  lang_06BEAB41D66CCFF329D1ED8BA120A6C2    6
# 40  lang_89616CFF8EC8637092F885C7EFF43D74    5
# 45  lang_A0C7021AD8299ADF0C9EBE326C115F6F    4
# 57  lang_76B8A9C3013AE6414A3E6012413CDC3B    4
# 55  lang_AEF22666801F0A5846D853B9CEB2E327    4
# 54  lang_D413F5FE5236E5650A46FD983AB39212    4
# 49  lang_190BA7DA361BC06BC1D7E824C378064D    4
# 48  lang_1FFD2FE4297F5E70EBC6C3230D95CB9C    4
# 47  lang_1BC639981AE88E09129594B11F894A21    4
# 52  lang_717293301FE296B0B61950D041485825    3
# 53  lang_C7A400D9AD489ACF673CF12FBB80AAE5    3
# 64  lang_2216D01F7B48554E4211021A46816FCF    3
# 56  lang_3A85BCEC571C3F5AB1069E4924189177    3
# 59  lang_54208B51D44E7D91DC2F3DD02ADEDEC2    3
# 68  lang_12D8CEB94F89D11D7EB95EAE9689B009    3
# 73  lang_BF477808A37E3E4E9C5D9F1839E8519E    2
# 71  lang_97F81BD92A1ACA3F1F43C154E689350F    2
# 65  lang_DBEEFB80F8A314311E2B4BD593E11DFE    2
# 60  lang_FF7EABB5A382356D54D9C41BA0125E09    2
# 63  lang_C2EF5FABE7619D8A333D5F0FF76E1BFA    2
# 62  lang_691890251F2B9FF922BE6D3699ABEFD2    2
# 61  lang_259A6F6DFD672CB1F883CBEC01B99F2D    2
# 58  lang_920502FAA080485768AA89BC96A55C47    2
# 66  lang_E59EF8BB86A6D815331DDF4C467CE0C7    1
# 67  lang_60FBA0E834CC59D647C3599AD763FFDF    1
# 69  lang_F4FD40A716F1572C9A28E9CAA58BE3A5    1
# 70  lang_48236EC80FDDDFADE99420ABC9210DDF    1
# 72  lang_F3E1016563360F9434FA986CA86C249C    1
# 74  lang_69C4A33B9AD29AF883D60BA61CC08702    1
# 75  lang_60A3DB168094D41241E45E0DE3539BC0    1
# 76  lang_4249CE88433AEA3F8DCEECF008B3CB95    1
# Reply
#                                         0    1
# 2                                  u2_age  455
# 3                    u1_fllwng_cnt_by_age  390
# 19                                twt_age  374
# 13                          u1_fllwng_cnt  363
# 5                                len_toks  352
# 17                          u2_fllwer_cnt  352
# 6                           u2_fllwng_cnt  350
# 12                   u1_fllwer_cnt_by_age  331
# 9                           u1_fllwer_cnt  326
# 7                                  u1_age  322
# 16                            tmdlta_u2u1  304
# 4                                 tm_hour  151
# 8   lang_167115458A0DBDFF7E9C0C53A83BAC9B   56
# 27                           tm_dayofweek   55
# 23                             num_hshtgs   49
# 30  lang_22C448FF81263D4BAF2A176145EE9EAD   40
# 11  lang_9BF3403E0EB7EA8A256DA9019C0B0716   37
# 18                        twttyp_TopLevel   30
# 14  lang_4DC22C3F31C5C43721E6B5815A595ED6   29
# 38                        has_media_Photo   27
# 10                              num_links   27
# 32  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   27
# 1                              u1_fllw_u2   26
# 0                          twttyp_Retweet   26
# 31                               u1_vrfed   21
# 39                        has_media_Video   17
# 36  lang_125C57F4FA6D4E110983FB11B52EFD4E   15
# 15  lang_022EC308651FACB02794A8147AEE1B78   14
# 44  lang_06D61DCBBE938971E1EA0C38BD9B5446   12
# 25  lang_B9175601E87101A984A50F8A62A1C374   11
# 46                           twttyp_Quote   11
# 24  lang_975B38F44D65EE42A547283787FF5A21   11
# 33  lang_76B8A9C3013AE6414A3E6012413CDC3B   10
# 35  lang_ECED8A16BE2A5E8871FD55F4842F16B1    9
# 41  lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D    9
# 26  lang_FF60A88F53E63000266F8B9149E35AD9    8
# 34  lang_FA3F382BC409C271E3D6EAF8BE4648DD    7
# 22  lang_AEF22666801F0A5846D853B9CEB2E327    6
# 29                          has_media_GIF    6
# 48                               u2_vrfed    4
# 45  lang_2996EB2FE8162C076D070A4C8D6532CD    4
# 55  lang_3820C29CBCA409A33BADF68852057C4A    4
# 43  lang_1FFD2FE4297F5E70EBC6C3230D95CB9C    4
# 37  lang_190BA7DA361BC06BC1D7E824C378064D    3
# 47  lang_9ECD42BC079C20F156F53CB3B99E600E    3
# 49  lang_C7A400D9AD489ACF673CF12FBB80AAE5    3
# 50  lang_89616CFF8EC8637092F885C7EFF43D74    3
# 40  lang_717293301FE296B0B61950D041485825    3
# 28  lang_06BEAB41D66CCFF329D1ED8BA120A6C2    3
# 51  lang_57ADD4576E2AD6648E9B2DE32F3462A5    2
# 53  lang_60FBA0E834CC59D647C3599AD763FFDF    2
# 42  lang_69C4A33B9AD29AF883D60BA61CC08702    1
# 57  lang_48236EC80FDDDFADE99420ABC9210DDF    1
# 60  lang_DBEEFB80F8A314311E2B4BD593E11DFE    1
# 59  lang_D413F5FE5236E5650A46FD983AB39212    1
# 58  lang_544FA32458C903F1125FE6598300A047    1
# 52  lang_691890251F2B9FF922BE6D3699ABEFD2    1
# 56  lang_3A85BCEC571C3F5AB1069E4924189177    1
# 54  lang_0331BF70E606D62D92C96CE9AD71A7CF    1
# 21  lang_12D8CEB94F89D11D7EB95EAE9689B009    1
# 20  lang_97F81BD92A1ACA3F1F43C154E689350F    1
# 61  lang_1BC639981AE88E09129594B11F894A21    1
# Like
#                                         0     1
# 5                           u1_fllwer_cnt  3102
# 4                    u1_fllwer_cnt_by_age  2503
# 20                          u1_fllwng_cnt  2476
# 6                                  u1_age  2115
# 11                                twt_age  2049
# 10                          u2_fllwer_cnt  2023
# 8                                  u2_age  1969
# 2                    u1_fllwng_cnt_by_age  1870
# 3                                len_toks  1770
# 21                          u2_fllwng_cnt  1694
# 7                             tmdlta_u2u1  1393
# 17                                tm_hour   846
# 16                             num_hshtgs   299
# 34                           tm_dayofweek   268
# 0                          twttyp_Retweet   200
# 15                        has_media_Photo   199
# 26                        twttyp_TopLevel   195
# 32  lang_22C448FF81263D4BAF2A176145EE9EAD   191
# 1                               num_links   163
# 25                        has_media_Video   146
# 19                             u1_fllw_u2   132
# 13  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   129
# 12                               u1_vrfed   126
# 24  lang_06D61DCBBE938971E1EA0C38BD9B5446    97
# 31  lang_ECED8A16BE2A5E8871FD55F4842F16B1    90
# 9   lang_4DC22C3F31C5C43721E6B5815A595ED6    80
# 29  lang_167115458A0DBDFF7E9C0C53A83BAC9B    69
# 35                           twttyp_Quote    62
# 38  lang_B9175601E87101A984A50F8A62A1C374    48
# 27  lang_FA3F382BC409C271E3D6EAF8BE4648DD    45
# 23  lang_125C57F4FA6D4E110983FB11B52EFD4E    43
# 14  lang_022EC308651FACB02794A8147AEE1B78    42
# 22  lang_9BF3403E0EB7EA8A256DA9019C0B0716    42
# 18  lang_975B38F44D65EE42A547283787FF5A21    33
# 33                          has_media_GIF    26
# 36  lang_3820C29CBCA409A33BADF68852057C4A    16
# 37  lang_FF60A88F53E63000266F8B9149E35AD9    14
# 28  lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D    14
# 43  lang_717293301FE296B0B61950D041485825    13
# 30  lang_2996EB2FE8162C076D070A4C8D6532CD    11
# 72  lang_190BA7DA361BC06BC1D7E824C378064D     9
# 42  lang_89616CFF8EC8637092F885C7EFF43D74     9
# 40                               u2_vrfed     9
# 61  lang_0331BF70E606D62D92C96CE9AD71A7CF     8
# 39  lang_AEF22666801F0A5846D853B9CEB2E327     8
# 45  lang_3A85BCEC571C3F5AB1069E4924189177     7
# 46  lang_69C4A33B9AD29AF883D60BA61CC08702     7
# 44  lang_76B8A9C3013AE6414A3E6012413CDC3B     7
# 48  lang_9ECD42BC079C20F156F53CB3B99E600E     6
# 54  lang_1FFD2FE4297F5E70EBC6C3230D95CB9C     6
# 52  lang_B6D90127A09AB1229731898AEF9D4D7C     5
# 59  lang_1BC639981AE88E09129594B11F894A21     5
# 41  lang_A0C7021AD8299ADF0C9EBE326C115F6F     5
# 49  lang_06BEAB41D66CCFF329D1ED8BA120A6C2     5
# 47  lang_60FBA0E834CC59D647C3599AD763FFDF     5
# 51  lang_691890251F2B9FF922BE6D3699ABEFD2     5
# 50  lang_920502FAA080485768AA89BC96A55C47     5
# 58  lang_D413F5FE5236E5650A46FD983AB39212     4
# 53  lang_CB11E9CF42BD0A1BAD5E27BF3422D99D     4
# 57  lang_57ADD4576E2AD6648E9B2DE32F3462A5     4
# 56  lang_C2EF5FABE7619D8A333D5F0FF76E1BFA     4
# 71  lang_AA0254541959271ED3453119B787D0C3     3
# 62  lang_FF7EABB5A382356D54D9C41BA0125E09     3
# 63  lang_A6B70CDF8C7B934D4A218CA9B6B7FDB4     3
# 77  lang_E59EF8BB86A6D815331DDF4C467CE0C7     3
# 55  lang_4249CE88433AEA3F8DCEECF008B3CB95     3
# 69  lang_F3E1016563360F9434FA986CA86C249C     3
# 78  lang_544FA32458C903F1125FE6598300A047     2
# 76  lang_3121F7240D488F74EEED9312E174B217     2
# 73  lang_60A3DB168094D41241E45E0DE3539BC0     2
# 66  lang_C7A400D9AD489ACF673CF12FBB80AAE5     2
# 70  lang_48236EC80FDDDFADE99420ABC9210DDF     2
# 68  lang_54208B51D44E7D91DC2F3DD02ADEDEC2     2
# 67  lang_6431A618DCF7F4CB7F62A95A39BAB77A     2
# 64  lang_DBEEFB80F8A314311E2B4BD593E11DFE     2
# 60  lang_2216D01F7B48554E4211021A46816FCF     2
# 74  lang_AC1F0671A4B0D5B8112F87DE7B490E6D     1
# 75  lang_97F81BD92A1ACA3F1F43C154E689350F     1
# 65  lang_E7BB61D2A87C1E72DF1C7BC292B86A1C     1
# 79  lang_F4FD40A716F1572C9A28E9CAA58BE3A5     1
# RTwCmnt
#                                         0    1
# 3                                  u2_age  309
# 0                           u2_fllwer_cnt  279
# 7                                len_toks  255
# 6                                 twt_age  228
# 15                          u1_fllwng_cnt  226
# 4                             tmdlta_u2u1  217
# 12                   u1_fllwng_cnt_by_age  208
# 13                   u1_fllwer_cnt_by_age  205
# 9                           u2_fllwng_cnt  199
# 19                                 u1_age  191
# 8                           u1_fllwer_cnt  181
# 16                                tm_hour  118
# 2   lang_22C448FF81263D4BAF2A176145EE9EAD   49
# 18                        has_media_Video   42
# 29                           tm_dayofweek   41
# 11  lang_4DC22C3F31C5C43721E6B5815A595ED6   33
# 14                         twttyp_Retweet   32
# 28                             num_hshtgs   32
# 1                              u1_fllw_u2   31
# 17                              num_links   29
# 10                        twttyp_TopLevel   27
# 21                        has_media_Photo   22
# 24                           twttyp_Quote   14
# 38  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   13
# 22  lang_2996EB2FE8162C076D070A4C8D6532CD   12
# 30  lang_FA3F382BC409C271E3D6EAF8BE4648DD   11
# 34  lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D    9
# 26  lang_975B38F44D65EE42A547283787FF5A21    8
# 35  lang_06D61DCBBE938971E1EA0C38BD9B5446    8
# 37                               u1_vrfed    8
# 36  lang_167115458A0DBDFF7E9C0C53A83BAC9B    7
# 33  lang_ECED8A16BE2A5E8871FD55F4842F16B1    7
# 40  lang_125C57F4FA6D4E110983FB11B52EFD4E    7
# 27  lang_022EC308651FACB02794A8147AEE1B78    6
# 41  lang_3820C29CBCA409A33BADF68852057C4A    6
# 39  lang_9BF3403E0EB7EA8A256DA9019C0B0716    5
# 32  lang_B9175601E87101A984A50F8A62A1C374    3
# 43  lang_259A6F6DFD672CB1F883CBEC01B99F2D    3
# 47                          has_media_GIF    3
# 49  lang_FF60A88F53E63000266F8B9149E35AD9    2
# 48  lang_920502FAA080485768AA89BC96A55C47    2
# 25  lang_76B8A9C3013AE6414A3E6012413CDC3B    2
# 42  lang_717293301FE296B0B61950D041485825    1
# 31  lang_48236EC80FDDDFADE99420ABC9210DDF    1
# 44  lang_AEF22666801F0A5846D853B9CEB2E327    1
# 45  lang_9ECD42BC079C20F156F53CB3B99E600E    1
# 46  lang_190BA7DA361BC06BC1D7E824C378064D    1
# 23  lang_691890251F2B9FF922BE6D3699ABEFD2    1
# 20  lang_544FA32458C903F1125FE6598300A047    1
# 5   lang_3A85BCEC571C3F5AB1069E4924189177    1
# 50  lang_06BEAB41D66CCFF329D1ED8BA120A6C2    1

# %% [markdown]
# ## valid

# %%
def validtgt(tgt):
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    dtr = xgb.DMatrix(Xtr, label=tgt2ytr[tgt], feature_names=cols_feat)
    dvl = xgb.DMatrix(Xvl, label=tgt2yvl[tgt], feature_names=cols_feat)
    prdtr = bst.predict(dtr, ntree_limit=bst.best_ntree_limit)
    prdvl = bst.predict(dvl, ntree_limit=bst.best_ntree_limit)
    return prdtr,prdvl

# %%
tgt2prdtr={}
tgt2prdvl={}
for tgt,bst in tgt2bst.items():
    tgt2prdtr[tgt],tgt2prdvl[tgt]=validtgt(tgt)
# Out:
# 2020-03-22 15:56:43 Retweet
# 2020-03-22 15:56:58 Reply
# 2020-03-22 15:57:07 Like
# 2020-03-22 15:57:23 RTwCmnt

# %%
tgt2auc_trn={}
tgt2rce_trn={}
tgt2auc_val={}
tgt2rce_val={}
for tgt in tgt2bst:
    print(tgt)
    prdtr_i, prdvl_i = tgt2prdtr[tgt], tgt2prdvl[tgt]
    ytr_i, yvl_i = tgt2ytr[tgt], tgt2yvl[tgt]
    scr_auc_trn=compute_prauc(prdtr_i, ytr_i)
    scr_rce_trn=compute_rce(prdtr_i, ytr_i)
    scr_auc_val=compute_prauc(prdvl_i, yvl_i)
    scr_rce_val=compute_rce(prdvl_i, yvl_i)

    tgt2auc_trn[tgt]=scr_auc_trn
    tgt2rce_trn[tgt]=scr_rce_trn
    tgt2auc_val[tgt]=scr_auc_val
    tgt2rce_val[tgt]=scr_rce_val
    
    print('train prauc:', f'{scr_auc_trn:.4f}','train rce:', f'{scr_rce_trn:.4f}', )
    print('valid prauc:', f'{scr_auc_val:.4f}','valid rce:', f'{scr_rce_val:.4f}', )
# Out:
# Retweet
# train prauc: 0.3898 train rce: 17.0056
# valid prauc: 0.3174 valid rce: 12.3637
# Reply
# train prauc: 0.1572 train rce: 15.3316
# valid prauc: 0.0923 valid rce: 10.6647
# Like
# train prauc: 0.7651 train rce: 21.9553
# valid prauc: 0.7041 valid rce: 15.7525
# RTwCmnt
# train prauc: 0.0539 train rce: 8.6499
# valid prauc: 0.0181 valid rce: 4.2337

# %%
lsttrn=[]
lstval=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    if tgt not in tgt2bst: continue
    lsttrn+=[(f'PRAUC {tgt}',tgt2auc_trn[tgt]),
          (f'RCE {tgt}',tgt2rce_trn[tgt])]
    lstval+=[(f'PRAUC {tgt}',tgt2auc_val[tgt]),
          (f'RCE {tgt}',tgt2rce_val[tgt])]

dfscrtrn=pd.DataFrame(lsttrn)
dfscrtrn.columns=['metric','scr']
dfscrval=pd.DataFrame(lstval)
dfscrval.columns=['metric','scr']
dfscr = pd.merge(dfscrtrn, dfscrval, on='metric', suffixes=('trn','val'))
dfscr.T
# Out:
#                     0            1            2          3           4  \
# metric  PRAUC Retweet  RCE Retweet  PRAUC Reply  RCE Reply  PRAUC Like
# scrtrn       0.389802      17.0056     0.157204    15.3316    0.765084
# scrval       0.317397      12.3637    0.0923329    10.6647    0.704069
#
#                5              6            7
# metric  RCE Like  PRAUC RTwCmnt  RCE RTwCmnt
# scrtrn   21.9553      0.0538544      8.64992
# scrval   15.7525      0.0181104      4.23373

# %% [markdown]
# # infer

# %% [raw]
# ls -lhS $p_in | grep val

# %%
# %%time
dftst=pd.read_csv(
    f'{p_in}/val_{valtmstmp}.tsv',
#     f'{p_in}/val_259A6F6DFD672CB1F883CBEC01B99F2D_1584405047.tsv',
    sep='\x01', header=None, names=cols_val,)
# Out:
# CPU times: user 1min 28s, sys: 12.6 s, total: 1min 41s
# Wall time: 2min 34s

# %%
# %%time
dftst = prp_df(dftst, istrn=False)
# Out:
# CPU times: user 1min 42s, sys: 13.9 s, total: 1min 56s
# Wall time: 2min 6s

# %%
# %%time
dtst = xgb.DMatrix(dftst[cols_feat], feature_names=cols_feat)
tgt2prdtst={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtst[tgt] = bst.predict(dtst)
# Out:
# 2020-03-22 16:15:47 Retweet
# 2020-03-22 16:16:25 Reply
# 2020-03-22 16:16:41 Like

# %%
dfsub_ids = dftst[['twtid','u2id',]]

tgt2dfsub = {}
for tgt,prdtst in tgt2prdtst.items():
    dfsub = dfsub_ids.copy()
    dfsub['scr'] = prdtst
    tgt2dfsub[tgt]=dfsub

# %%
# %%time
for i,tgt in enumerate(['RTwCmnt','Retweet','Reply','Like',]):
    dfsub = tgt2dfsub[tgt]
    print(dtnow(), tgt)
    dfsub.to_csv(f'{p_out}/{i}_{tgt}__{valtmstmp}__{PRFX}.csv',index=False,header=False)
