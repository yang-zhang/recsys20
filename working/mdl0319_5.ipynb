# %% [markdown]
# # start

# %% [markdown]
# return to four models

# %%
PRFX='0319_5'
trntmstmp=1584412344
valtmstmp=1584626395
import datetime
[datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (trntmstmp, valtmstmp)]
# Out:
# ['2020-03-17 02:32:24', '2020-03-19 13:59:55']

# %%
grand_total=1.5e8

# %% [markdown]
# # setup

# %%
from pathlib import Path
import dask
print('dask.__version__', dask.__version__)
import xgboost as xgb
import dask_xgboost
import dask.dataframe as dd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from dask.distributed import Client
import pickle
import lightgbm as lgb
from tqdm import tqdm

import datetime
def dtnow(): return datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

SEED=101
HOME='/data/git/recsys20'
p_in=f'{HOME}/input'
p_out=f'{HOME}/output/{PRFX}'
Path(p_out).mkdir(exist_ok=True, parents=True)

from sklearn.metrics import precision_recall_curve, auc, log_loss

def compute_prauc(pred, gt):
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return prauc

def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive/float(len(gt))
    return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

cols=[
'toks',
'hshtgs',
'twtid',
'media',
'links',
'domns',
'twttyp',
'lang',
'tm',

'u1id',
'u1_fllwer_cnt',
'u1_fllwing_cnt',
'u1_vrfed',
'u1_create_tm',

'u2id',
'u2_follower_cnt',
'u2_following_cnt',
'u2_vrfed',
'u2_create_tm',

'u1_fllw_u2',
'reply_tm',
'retwt_tm',
'retwt_cmmnt_tm',
'like_tm',
]

cols_val = cols[:-4]
cols_tgt_tmstmp=[
    'retwt_tm',
    'reply_tm',
    'like_tm',
    'retwt_cmmnt_tm',
]
cols_tgt=[o.split('_tm')[0] for o in cols_tgt_tmstmp]
tgts             = ['Retweet','Reply','Like','RTwCmnt',]
assert cols_tgt == ['retwt',  'reply','like','retwt_cmmnt',]
ntgts=len(tgts)
# Out:
# dask.__version__ 2.12.0

# %% [markdown]
# # prepare data

# %% [markdown]
# ## get maps from dfval

# %%
# dfval=dd.read_csv(
#     f'{p_in}/val_{valtmstmp}.tsv',
#     sep='\x01', header=None, names=cols_val,)
# lang2cnt=dict(dfval.lang.value_counts().compute())
# ttl=sum(lang2cnt.values())
# lang2perc={k:v/ttl for k,v in lang2cnt.items()}
langs=['D3164C7FBCF2565DDF915B1B3AEFB1DC', '22C448FF81263D4BAF2A176145EE9EAD', '06D61DCBBE938971E1EA0C38BD9B5446', 'ECED8A16BE2A5E8871FD55F4842F16B1', 'B9175601E87101A984A50F8A62A1C374', '4DC22C3F31C5C43721E6B5815A595ED6', '167115458A0DBDFF7E9C0C53A83BAC9B', '125C57F4FA6D4E110983FB11B52EFD4E', '022EC308651FACB02794A8147AEE1B78', 'FA3F382BC409C271E3D6EAF8BE4648DD', '9BF3403E0EB7EA8A256DA9019C0B0716', '975B38F44D65EE42A547283787FF5A21', '2996EB2FE8162C076D070A4C8D6532CD', 'FF60A88F53E63000266F8B9149E35AD9', '717293301FE296B0B61950D041485825', '3E16B11B7ADE3A22DDFC4423FBCEAD5D', '3820C29CBCA409A33BADF68852057C4A', '9ECD42BC079C20F156F53CB3B99E600E', '76B8A9C3013AE6414A3E6012413CDC3B', 'AEF22666801F0A5846D853B9CEB2E327', '190BA7DA361BC06BC1D7E824C378064D', '1FFD2FE4297F5E70EBC6C3230D95CB9C', 'A0C7021AD8299ADF0C9EBE326C115F6F', 'D413F5FE5236E5650A46FD983AB39212', '48236EC80FDDDFADE99420ABC9210DDF', '691890251F2B9FF922BE6D3699ABEFD2', '920502FAA080485768AA89BC96A55C47', '0331BF70E606D62D92C96CE9AD71A7CF', '89616CFF8EC8637092F885C7EFF43D74', '06BEAB41D66CCFF329D1ED8BA120A6C2', '60FBA0E834CC59D647C3599AD763FFDF', 'C7A400D9AD489ACF673CF12FBB80AAE5', 'E59EF8BB86A6D815331DDF4C467CE0C7', '4249CE88433AEA3F8DCEECF008B3CB95', '544FA32458C903F1125FE6598300A047', 'CB11E9CF42BD0A1BAD5E27BF3422D99D', '3A85BCEC571C3F5AB1069E4924189177', 'FF7EABB5A382356D54D9C41BA0125E09', 'E7BB61D2A87C1E72DF1C7BC292B86A1C', '69C4A33B9AD29AF883D60BA61CC08702', 'F4FD40A716F1572C9A28E9CAA58BE3A5', '259A6F6DFD672CB1F883CBEC01B99F2D', '6431A618DCF7F4CB7F62A95A39BAB77A', '3121F7240D488F74EEED9312E174B217', '54208B51D44E7D91DC2F3DD02ADEDEC2', 'DBEEFB80F8A314311E2B4BD593E11DFE', 'B6D90127A09AB1229731898AEF9D4D7C', 'F3E1016563360F9434FA986CA86C249C', '2216D01F7B48554E4211021A46816FCF', '1BC639981AE88E09129594B11F894A21', 'C942E369C88CE7C56E69A84D04319FF0', '57ADD4576E2AD6648E9B2DE32F3462A5', 'AC1F0671A4B0D5B8112F87DE7B490E6D', 'C2EF5FABE7619D8A333D5F0FF76E1BFA', 'AA0254541959271ED3453119B787D0C3', 'A6B70CDF8C7B934D4A218CA9B6B7FDB4', 'BF477808A37E3E4E9C5D9F1839E8519E', '97F81BD92A1ACA3F1F43C154E689350F', '60A3DB168094D41241E45E0DE3539BC0', '12D8CEB94F89D11D7EB95EAE9689B009', 'F73266A79468BB89C4325FDEDB0B533C', '4690215948DBF6872B8ED1C2BC87B17E', 'D18801336202297E6484F634CAC6592E', '2E18F6F53E3CF073911AF0A93BBE5373', 'B2235C8B73239FDC5780DD132419833A', '515E873C86EE1577E75FA2387B7FA59E',]

# dfval.twttyp.value_counts().compute()
# TopLevel    2932
# Retweet      994
# Quote        213
twttyps=['TopLevel','Retweet','Quote']

# %%
def prp_df(df, istrn=True):
    df['len_toks']=df.toks.apply(len)
    for media in ['Photo', 'Video', 'GIF']:
        df[f'has_media_{media}'] = df.media.fillna('').apply(lambda x: media in x)
    for col in ['hshtgs', 'links', 'domns',]:
        df[f'num_{col}'] = df[col].fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0)
    tm_dt=pd.to_datetime(df.tm, unit='s')
    df['tm_month']=tm_dt.dt.month
    df['tm_dayofweek']=tm_dt.dt.dayofweek
    df['tm_day']=tm_dt.dt.day
    df['tm_hour']=tm_dt.dt.hour
    df['tmdlta_u2u1']  = df.u2_create_tm - df.u1_create_tm
    df['tmdlta_twtu1'] = df.tm - df.u1_create_tm
    df['tmdlta_twtu2'] = df.tm - df.u2_create_tm

    for typ in twttyps:
        df[f'twttyp_{typ}']=(df.twttyp==typ).astype('int8')

    for lang in langs:
        df[f'lang_{lang}']=(df.lang==lang).astype('int8')
    if istrn: 
        df[cols_tgt]=df[cols_tgt_tmstmp].notna().astype('int8')
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 'twtid', 'u1id', 'u2id']+cols_tgt_tmstmp, )
    else:
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 'u1id',])        
    return df

# %% [raw]
# ls -hlS $p_in | grep {trntmstmp}

# %%
grand_total
# Out:
# 150000000.0

# %%
grand_total/1e6
# Out:
# 150.0

# %% [raw]
# chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
#                     header=None,names=cols,
#                         chunksize=1e6
#                        )
# for ichnk,df in enumerate(chnks_trn):
#     print(dtnow(), 'chunk', ichnk, df.tm.max())
# ichnk

# %%
chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                    header=None,names=cols, 
                        chunksize=1e6
                       )

np.random.seed(SEED)
lst_df = []
for ichnk,df in enumerate(chnks_trn):
    print(dtnow(), 'chunk', ichnk)
    df = prp_df(df)    
    lst_df.append(df)
    if ichnk>=9: break
# Out:
# 2020-03-20 03:40:57 chunk 0
# 2020-03-20 03:41:17 chunk 1
# 2020-03-20 03:41:36 chunk 2
# 2020-03-20 03:41:56 chunk 3
# 2020-03-20 03:42:15 chunk 4
# 2020-03-20 03:42:34 chunk 5
# 2020-03-20 03:42:54 chunk 6
# 2020-03-20 03:43:12 chunk 7
# 2020-03-20 03:43:32 chunk 8
# 2020-03-20 03:43:51 chunk 9

# %%
df = pd.concat(lst_df)

# %%
df.shape
# Out:
# (10000000, 97)

# %%
df.columns
# Out:
# Index(['tm', 'u1_fllwer_cnt', 'u1_fllwing_cnt', 'u1_vrfed', 'u1_create_tm',
#        'u2_follower_cnt', 'u2_following_cnt', 'u2_vrfed', 'u2_create_tm',
#        'u1_fllw_u2', 'len_toks', 'has_media_Photo', 'has_media_Video',
#        'has_media_GIF', 'num_hshtgs', 'num_links', 'num_domns', 'tm_month',
#        'tm_dayofweek', 'tm_day', 'tm_hour', 'tmdlta_u2u1', 'tmdlta_twtu1',
#        'tmdlta_twtu2', 'twttyp_TopLevel', 'twttyp_Retweet', 'twttyp_Quote',
#        'lang_D3164C7FBCF2565DDF915B1B3AEFB1DC',
#        'lang_22C448FF81263D4BAF2A176145EE9EAD',
#        'lang_06D61DCBBE938971E1EA0C38BD9B5446',
#        'lang_ECED8A16BE2A5E8871FD55F4842F16B1',
#        'lang_B9175601E87101A984A50F8A62A1C374',
#        'lang_4DC22C3F31C5C43721E6B5815A595ED6',
#        'lang_167115458A0DBDFF7E9C0C53A83BAC9B',
#        'lang_125C57F4FA6D4E110983FB11B52EFD4E',
#        'lang_022EC308651FACB02794A8147AEE1B78',
#        'lang_FA3F382BC409C271E3D6EAF8BE4648DD',
#        'lang_9BF3403E0EB7EA8A256DA9019C0B0716',
#        'lang_975B38F44D65EE42A547283787FF5A21',
#        'lang_2996EB2FE8162C076D070A4C8D6532CD',
#        'lang_FF60A88F53E63000266F8B9149E35AD9',
#        'lang_717293301FE296B0B61950D041485825',
#        'lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D',
#        'lang_3820C29CBCA409A33BADF68852057C4A',
#        'lang_9ECD42BC079C20F156F53CB3B99E600E',
#        'lang_76B8A9C3013AE6414A3E6012413CDC3B',
#        'lang_AEF22666801F0A5846D853B9CEB2E327',
#        'lang_190BA7DA361BC06BC1D7E824C378064D',
#        'lang_1FFD2FE4297F5E70EBC6C3230D95CB9C',
#        'lang_A0C7021AD8299ADF0C9EBE326C115F6F',
#        'lang_D413F5FE5236E5650A46FD983AB39212',
#        'lang_48236EC80FDDDFADE99420ABC9210DDF',
#        'lang_691890251F2B9FF922BE6D3699ABEFD2',
#        'lang_920502FAA080485768AA89BC96A55C47',
#        'lang_0331BF70E606D62D92C96CE9AD71A7CF',
#        'lang_89616CFF8EC8637092F885C7EFF43D74',
#        'lang_06BEAB41D66CCFF329D1ED8BA120A6C2',
#        'lang_60FBA0E834CC59D647C3599AD763FFDF',
#        'lang_C7A400D9AD489ACF673CF12FBB80AAE5',
#        'lang_E59EF8BB86A6D815331DDF4C467CE0C7',
#        'lang_4249CE88433AEA3F8DCEECF008B3CB95',
#        'lang_544FA32458C903F1125FE6598300A047',
#        'lang_CB11E9CF42BD0A1BAD5E27BF3422D99D',
#        'lang_3A85BCEC571C3F5AB1069E4924189177',
#        'lang_FF7EABB5A382356D54D9C41BA0125E09',
#        'lang_E7BB61D2A87C1E72DF1C7BC292B86A1C',
#        'lang_69C4A33B9AD29AF883D60BA61CC08702',
#        'lang_F4FD40A716F1572C9A28E9CAA58BE3A5',
#        'lang_259A6F6DFD672CB1F883CBEC01B99F2D',
#        'lang_6431A618DCF7F4CB7F62A95A39BAB77A',
#        'lang_3121F7240D488F74EEED9312E174B217',
#        'lang_54208B51D44E7D91DC2F3DD02ADEDEC2',
#        'lang_DBEEFB80F8A314311E2B4BD593E11DFE',
#        'lang_B6D90127A09AB1229731898AEF9D4D7C',
#        'lang_F3E1016563360F9434FA986CA86C249C',
#        'lang_2216D01F7B48554E4211021A46816FCF',
#        'lang_1BC639981AE88E09129594B11F894A21',
#        'lang_C942E369C88CE7C56E69A84D04319FF0',
#        'lang_57ADD4576E2AD6648E9B2DE32F3462A5',
#        'lang_AC1F0671A4B0D5B8112F87DE7B490E6D',
#        'lang_C2EF5FABE7619D8A333D5F0FF76E1BFA',
#        'lang_AA0254541959271ED3453119B787D0C3',
#        'lang_A6B70CDF8C7B934D4A218CA9B6B7FDB4',
#        'lang_BF477808A37E3E4E9C5D9F1839E8519E',
#        'lang_97F81BD92A1ACA3F1F43C154E689350F',
#        'lang_60A3DB168094D41241E45E0DE3539BC0',
#        'lang_12D8CEB94F89D11D7EB95EAE9689B009',
#        'lang_F73266A79468BB89C4325FDEDB0B533C',
#        'lang_4690215948DBF6872B8ED1C2BC87B17E',
#        'lang_D18801336202297E6484F634CAC6592E',
#        'lang_2E18F6F53E3CF073911AF0A93BBE5373',
#        'lang_B2235C8B73239FDC5780DD132419833A',
#        'lang_515E873C86EE1577E75FA2387B7FA59E', 'retwt', 'reply', 'like',
#        'retwt_cmmnt'],
#       dtype='object')

# %%
cols_feat=[o for o in df.columns if o not in cols_tgt]

# %%
# %%time
split=int(len(df)*0.85)
Xtr,Xvl=df[cols_feat][:split],df[cols_feat][split:]
ytr,yvl=df[cols_tgt ][:split],df[cols_tgt ][split:]
# Out:
# CPU times: user 2.67 s, sys: 3.71 s, total: 6.38 s
# Wall time: 6.37 s

# %%
Xtr.shape,Xvl.shape,ytr.shape,yvl.shape
# Out:
# ((8500000, 93), (1500000, 93), (8500000, 4), (1500000, 4))

# %% [markdown]
# # model

# %%
params = {
    'objective': 'binary:logistic',
    'verbosity': 2,
    'eval_metric': ['logloss','error'],
#     https://xgboost.readthedocs.io/en/latest/tutorials/param_tuning.html
#     'max_delta_step': 1,
}

num_rounds = 100

# %%
tgt2bst={}
tgt2ytr={}
tgt2yvl={}
for i,tgt in enumerate(tgts):
    print(dtnow(), tgt, '*'*80)
    tgt2ytr[tgt]=ytr.iloc[:,i]
    tgt2yvl[tgt]=yvl.iloc[:,i]
    dtr = xgb.DMatrix(Xtr, label=ytr.iloc[:,i], feature_names=cols_feat)
    dvl = xgb.DMatrix(Xvl, label=yvl.iloc[:,i], feature_names=cols_feat)
    evallist = [(dtr, 'eval'), (dvl, 'train')]
    bst = xgb.train(params=params, dtrain=dtr, num_boost_round=num_rounds, evals=evallist, early_stopping_rounds=10)
    tgt2bst[tgt] = bst
    
pickle.dump(tgt2bst, open(f"{p_out}/tgt2bst.p", "wb"))
# Out:
# 2020-03-20 03:44:09 Retweet ********************************************************************************
# [03:45:41] WARNING: /workspace/src/gbm/gbtree.cc:138: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [03:46:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-logloss:0.53347	eval-error:0.11051	train-logloss:0.53343	train-error:0.11086
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [03:46:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-logloss:0.44839	eval-error:0.11024	train-logloss:0.44839	train-error:0.11057
# [03:46:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-logloss:0.39855	eval-error:0.11016	train-logloss:0.39867	train-error:0.11048
# [03:46:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-logloss:0.36851	eval-error:0.11006	train-logloss:0.36871	train-error:0.11040
# [03:47:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [4]	eval-logloss:0.34987	eval-error:0.10999	train-logloss:0.35015	train-error:0.11031
# [03:47:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [5]	eval-logloss:0.33874	eval-error:0.10994	train-logloss:0.33910	train-error:0.11027
# [03:47:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [6]	eval-logloss:0.33104	eval-error:0.10985	train-logloss:0.33138	train-error:0.11017
# [03:48:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-logloss:0.32615	eval-error:0.10978	train-logloss:0.32654	train-error:0.11011
# [03:48:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	eval-logloss:0.32286	eval-error:0.10972	train-logloss:0.32316	train-error:0.11009
# [03:48:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	eval-logloss:0.32061	eval-error:0.10971	train-logloss:0.32099	train-error:0.11005
# [03:48:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [10]	eval-logloss:0.31919	eval-error:0.10970	train-logloss:0.31959	train-error:0.11006
# [03:49:11] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [11]	eval-logloss:0.31814	eval-error:0.10966	train-logloss:0.31855	train-error:0.11002
# [03:49:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [12]	eval-logloss:0.31747	eval-error:0.10968	train-logloss:0.31789	train-error:0.11004
# [03:49:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [13]	eval-logloss:0.31676	eval-error:0.10962	train-logloss:0.31721	train-error:0.10997
# [03:50:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [14]	eval-logloss:0.31619	eval-error:0.10958	train-logloss:0.31665	train-error:0.10992
# [03:50:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15]	eval-logloss:0.31561	eval-error:0.10957	train-logloss:0.31606	train-error:0.10990
# [03:50:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16]	eval-logloss:0.31493	eval-error:0.10950	train-logloss:0.31542	train-error:0.10985
# [03:50:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17]	eval-logloss:0.31461	eval-error:0.10949	train-logloss:0.31511	train-error:0.10984
# [03:51:09] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [18]	eval-logloss:0.31421	eval-error:0.10941	train-logloss:0.31470	train-error:0.10976
# [03:51:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [19]	eval-logloss:0.31394	eval-error:0.10939	train-logloss:0.31444	train-error:0.10973
# [03:51:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [20]	eval-logloss:0.31364	eval-error:0.10936	train-logloss:0.31414	train-error:0.10970
# [03:52:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [21]	eval-logloss:0.31345	eval-error:0.10936	train-logloss:0.31397	train-error:0.10970
# [03:52:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [22]	eval-logloss:0.31334	eval-error:0.10935	train-logloss:0.31387	train-error:0.10969
# [03:52:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [23]	eval-logloss:0.31315	eval-error:0.10932	train-logloss:0.31371	train-error:0.10967
# [03:52:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [24]	eval-logloss:0.31253	eval-error:0.10926	train-logloss:0.31312	train-error:0.10963
# [03:53:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [25]	eval-logloss:0.31230	eval-error:0.10925	train-logloss:0.31289	train-error:0.10963
# [03:53:25] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [26]	eval-logloss:0.31219	eval-error:0.10925	train-logloss:0.31279	train-error:0.10965
# [03:53:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [27]	eval-logloss:0.31196	eval-error:0.10919	train-logloss:0.31257	train-error:0.10957
# [03:54:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [28]	eval-logloss:0.31189	eval-error:0.10917	train-logloss:0.31250	train-error:0.10956
# [03:54:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [29]	eval-logloss:0.31171	eval-error:0.10917	train-logloss:0.31237	train-error:0.10955
# [03:54:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [30]	eval-logloss:0.31155	eval-error:0.10916	train-logloss:0.31222	train-error:0.10955
# [03:54:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [31]	eval-logloss:0.31149	eval-error:0.10915	train-logloss:0.31217	train-error:0.10955
# [03:55:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [32]	eval-logloss:0.31134	eval-error:0.10914	train-logloss:0.31204	train-error:0.10954
# [03:55:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [33]	eval-logloss:0.31128	eval-error:0.10913	train-logloss:0.31200	train-error:0.10953
# [03:55:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [34]	eval-logloss:0.31114	eval-error:0.10912	train-logloss:0.31186	train-error:0.10952
# [03:56:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [35]	eval-logloss:0.31098	eval-error:0.10911	train-logloss:0.31171	train-error:0.10951
# [03:56:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 108 extra nodes, 0 pruned nodes, max_depth=6
# [36]	eval-logloss:0.31093	eval-error:0.10910	train-logloss:0.31166	train-error:0.10949
# [03:57:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [37]	eval-logloss:0.31085	eval-error:0.10909	train-logloss:0.31160	train-error:0.10948
# [03:57:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [38]	eval-logloss:0.31077	eval-error:0.10908	train-logloss:0.31153	train-error:0.10947
# [03:58:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [39]	eval-logloss:0.31073	eval-error:0.10908	train-logloss:0.31150	train-error:0.10947
# [03:58:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [40]	eval-logloss:0.31060	eval-error:0.10906	train-logloss:0.31138	train-error:0.10946
# [03:59:09] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [41]	eval-logloss:0.31057	eval-error:0.10906	train-logloss:0.31137	train-error:0.10945
# [03:59:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=6
# [42]	eval-logloss:0.31053	eval-error:0.10906	train-logloss:0.31134	train-error:0.10945
# [04:00:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [43]	eval-logloss:0.31033	eval-error:0.10904	train-logloss:0.31114	train-error:0.10942
# [04:00:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [44]	eval-logloss:0.31021	eval-error:0.10901	train-logloss:0.31105	train-error:0.10940
# [04:01:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 104 extra nodes, 0 pruned nodes, max_depth=6
# [45]	eval-logloss:0.31018	eval-error:0.10901	train-logloss:0.31103	train-error:0.10941
# [04:01:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [46]	eval-logloss:0.31012	eval-error:0.10899	train-logloss:0.31098	train-error:0.10940
# [04:02:16] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [47]	eval-logloss:0.30998	eval-error:0.10898	train-logloss:0.31085	train-error:0.10940
# [04:02:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 108 extra nodes, 0 pruned nodes, max_depth=6
# [48]	eval-logloss:0.30994	eval-error:0.10898	train-logloss:0.31082	train-error:0.10938
# [04:03:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [49]	eval-logloss:0.30969	eval-error:0.10896	train-logloss:0.31058	train-error:0.10934
# [04:03:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [50]	eval-logloss:0.30962	eval-error:0.10894	train-logloss:0.31052	train-error:0.10933
# [04:04:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [51]	eval-logloss:0.30958	eval-error:0.10894	train-logloss:0.31049	train-error:0.10934
# [04:04:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [52]	eval-logloss:0.30952	eval-error:0.10892	train-logloss:0.31045	train-error:0.10934
# [04:05:22] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [53]	eval-logloss:0.30941	eval-error:0.10891	train-logloss:0.31035	train-error:0.10934
# [04:05:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [54]	eval-logloss:0.30938	eval-error:0.10891	train-logloss:0.31033	train-error:0.10935
# [04:06:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [55]	eval-logloss:0.30936	eval-error:0.10890	train-logloss:0.31032	train-error:0.10935
# [04:06:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [56]	eval-logloss:0.30930	eval-error:0.10889	train-logloss:0.31026	train-error:0.10936
# [04:07:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [57]	eval-logloss:0.30918	eval-error:0.10889	train-logloss:0.31017	train-error:0.10932
# [04:07:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [58]	eval-logloss:0.30911	eval-error:0.10887	train-logloss:0.31011	train-error:0.10933
# [04:08:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [59]	eval-logloss:0.30899	eval-error:0.10886	train-logloss:0.31001	train-error:0.10933
# [04:08:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [60]	eval-logloss:0.30890	eval-error:0.10885	train-logloss:0.30993	train-error:0.10932
# [04:09:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [61]	eval-logloss:0.30882	eval-error:0.10884	train-logloss:0.30985	train-error:0.10930
# [04:10:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [62]	eval-logloss:0.30879	eval-error:0.10884	train-logloss:0.30983	train-error:0.10930
# [04:10:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [63]	eval-logloss:0.30877	eval-error:0.10884	train-logloss:0.30982	train-error:0.10930
# [04:11:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [64]	eval-logloss:0.30872	eval-error:0.10883	train-logloss:0.30979	train-error:0.10929
# [04:11:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [65]	eval-logloss:0.30865	eval-error:0.10882	train-logloss:0.30973	train-error:0.10929
# [04:12:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [66]	eval-logloss:0.30857	eval-error:0.10882	train-logloss:0.30967	train-error:0.10927
# [04:12:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=6
# [67]	eval-logloss:0.30856	eval-error:0.10882	train-logloss:0.30966	train-error:0.10927
# [04:13:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [68]	eval-logloss:0.30849	eval-error:0.10879	train-logloss:0.30959	train-error:0.10929
# [04:13:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 100 extra nodes, 0 pruned nodes, max_depth=6
# [69]	eval-logloss:0.30847	eval-error:0.10879	train-logloss:0.30958	train-error:0.10927
# [04:14:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=6
# [70]	eval-logloss:0.30845	eval-error:0.10879	train-logloss:0.30958	train-error:0.10929
# [04:14:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [71]	eval-logloss:0.30839	eval-error:0.10878	train-logloss:0.30954	train-error:0.10929
# [04:15:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [72]	eval-logloss:0.30833	eval-error:0.10877	train-logloss:0.30950	train-error:0.10927
# [04:15:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [73]	eval-logloss:0.30826	eval-error:0.10875	train-logloss:0.30942	train-error:0.10927
# [04:16:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [74]	eval-logloss:0.30825	eval-error:0.10874	train-logloss:0.30942	train-error:0.10927
# [04:16:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [75]	eval-logloss:0.30820	eval-error:0.10873	train-logloss:0.30938	train-error:0.10927
# [04:17:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [76]	eval-logloss:0.30817	eval-error:0.10873	train-logloss:0.30936	train-error:0.10927
# [04:17:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [77]	eval-logloss:0.30807	eval-error:0.10872	train-logloss:0.30926	train-error:0.10926
# [04:18:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [78]	eval-logloss:0.30799	eval-error:0.10870	train-logloss:0.30919	train-error:0.10924
# [04:18:41] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [79]	eval-logloss:0.30797	eval-error:0.10870	train-logloss:0.30918	train-error:0.10923
# [04:19:12] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [80]	eval-logloss:0.30796	eval-error:0.10870	train-logloss:0.30918	train-error:0.10923
# [04:19:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [81]	eval-logloss:0.30794	eval-error:0.10870	train-logloss:0.30917	train-error:0.10923
# [04:20:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [82]	eval-logloss:0.30786	eval-error:0.10869	train-logloss:0.30910	train-error:0.10921
# [04:20:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [83]	eval-logloss:0.30774	eval-error:0.10868	train-logloss:0.30899	train-error:0.10921
# [04:21:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [84]	eval-logloss:0.30767	eval-error:0.10866	train-logloss:0.30893	train-error:0.10917
# [04:21:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [85]	eval-logloss:0.30760	eval-error:0.10864	train-logloss:0.30888	train-error:0.10915
# [04:22:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [86]	eval-logloss:0.30751	eval-error:0.10861	train-logloss:0.30882	train-error:0.10912
# [04:22:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [87]	eval-logloss:0.30745	eval-error:0.10860	train-logloss:0.30876	train-error:0.10910
# [04:23:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [88]	eval-logloss:0.30738	eval-error:0.10858	train-logloss:0.30870	train-error:0.10910
# [04:23:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [89]	eval-logloss:0.30731	eval-error:0.10858	train-logloss:0.30863	train-error:0.10910
# [04:24:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [90]	eval-logloss:0.30726	eval-error:0.10857	train-logloss:0.30860	train-error:0.10910
# [04:24:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [91]	eval-logloss:0.30724	eval-error:0.10856	train-logloss:0.30858	train-error:0.10910
# [04:25:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [92]	eval-logloss:0.30715	eval-error:0.10855	train-logloss:0.30853	train-error:0.10909
# [04:26:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [93]	eval-logloss:0.30715	eval-error:0.10855	train-logloss:0.30852	train-error:0.10909
# [04:26:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [94]	eval-logloss:0.30708	eval-error:0.10855	train-logloss:0.30846	train-error:0.10908
# [04:27:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [95]	eval-logloss:0.30700	eval-error:0.10855	train-logloss:0.30840	train-error:0.10907
# [04:27:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=6
# [96]	eval-logloss:0.30699	eval-error:0.10855	train-logloss:0.30839	train-error:0.10907
# [04:28:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [97]	eval-logloss:0.30697	eval-error:0.10854	train-logloss:0.30839	train-error:0.10907
# [04:28:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [98]	eval-logloss:0.30690	eval-error:0.10854	train-logloss:0.30833	train-error:0.10906
# [04:29:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [99]	eval-logloss:0.30685	eval-error:0.10854	train-logloss:0.30828	train-error:0.10904
# 2020-03-20 04:29:10 Reply ********************************************************************************
# [04:31:36] WARNING: /workspace/src/gbm/gbtree.cc:138: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [04:32:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-logloss:0.46296	eval-error:0.02748	train-logloss:0.46418	train-error:0.02749
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [04:32:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-logloss:0.33861	eval-error:0.02748	train-logloss:0.33906	train-error:0.02748
# [04:33:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-logloss:0.26192	eval-error:0.02748	train-logloss:0.26198	train-error:0.02748
# [04:33:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-logloss:0.21208	eval-error:0.02748	train-logloss:0.21224	train-error:0.02748
# [04:34:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [4]	eval-logloss:0.17899	eval-error:0.02748	train-logloss:0.17920	train-error:0.02749
# [04:34:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [5]	eval-logloss:0.15688	eval-error:0.02748	train-logloss:0.15706	train-error:0.02748
# [04:35:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [6]	eval-logloss:0.14218	eval-error:0.02748	train-logloss:0.14218	train-error:0.02748
# [04:35:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-logloss:0.13221	eval-error:0.02748	train-logloss:0.13220	train-error:0.02749
# [04:36:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	eval-logloss:0.12547	eval-error:0.02748	train-logloss:0.12558	train-error:0.02748
# [04:37:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	eval-logloss:0.12099	eval-error:0.02748	train-logloss:0.12120	train-error:0.02748
# [04:37:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [10]	eval-logloss:0.11804	eval-error:0.02748	train-logloss:0.11832	train-error:0.02748
# [04:38:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [11]	eval-logloss:0.11606	eval-error:0.02748	train-logloss:0.11640	train-error:0.02749
# Stopping. Best iteration:
# [1]	eval-logloss:0.33861	eval-error:0.02748	train-logloss:0.33906	train-error:0.02748
#
# 2020-03-20 04:38:04 Like ********************************************************************************
# [04:41:10] WARNING: /workspace/src/gbm/gbtree.cc:138: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [04:41:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-logloss:0.66077	eval-error:0.35514	train-logloss:0.66119	train-error:0.35566
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [04:42:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-logloss:0.64372	eval-error:0.34648	train-logloss:0.64363	train-error:0.34691
# [04:42:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-logloss:0.63333	eval-error:0.34373	train-logloss:0.63336	train-error:0.34431
# [04:43:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-logloss:0.62698	eval-error:0.34215	train-logloss:0.62705	train-error:0.34276
# [04:44:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [4]	eval-logloss:0.62230	eval-error:0.34085	train-logloss:0.62256	train-error:0.34151
# [04:44:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [5]	eval-logloss:0.61926	eval-error:0.33896	train-logloss:0.61957	train-error:0.33952
# [04:45:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [6]	eval-logloss:0.61647	eval-error:0.33630	train-logloss:0.61689	train-error:0.33664
# [04:45:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-logloss:0.61467	eval-error:0.33493	train-logloss:0.61506	train-error:0.33553
# [04:46:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	eval-logloss:0.61331	eval-error:0.33377	train-logloss:0.61381	train-error:0.33417
# [04:46:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	eval-logloss:0.61140	eval-error:0.33201	train-logloss:0.61189	train-error:0.33250
# [04:47:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [10]	eval-logloss:0.61053	eval-error:0.33155	train-logloss:0.61104	train-error:0.33203
# [04:47:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [11]	eval-logloss:0.60928	eval-error:0.33066	train-logloss:0.60979	train-error:0.33113
# [04:48:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [12]	eval-logloss:0.60865	eval-error:0.33032	train-logloss:0.60919	train-error:0.33082
# [04:48:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [13]	eval-logloss:0.60762	eval-error:0.32923	train-logloss:0.60813	train-error:0.32968
# [04:49:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [14]	eval-logloss:0.60652	eval-error:0.32821	train-logloss:0.60708	train-error:0.32870
# [04:49:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15]	eval-logloss:0.60569	eval-error:0.32755	train-logloss:0.60625	train-error:0.32798
# [04:50:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16]	eval-logloss:0.60501	eval-error:0.32717	train-logloss:0.60560	train-error:0.32755
# [04:50:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17]	eval-logloss:0.60449	eval-error:0.32673	train-logloss:0.60508	train-error:0.32712
# [04:51:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [18]	eval-logloss:0.60396	eval-error:0.32623	train-logloss:0.60454	train-error:0.32681
# [04:51:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [19]	eval-logloss:0.60318	eval-error:0.32555	train-logloss:0.60377	train-error:0.32599
# [04:52:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [20]	eval-logloss:0.60252	eval-error:0.32487	train-logloss:0.60315	train-error:0.32532
# [04:52:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [21]	eval-logloss:0.60222	eval-error:0.32458	train-logloss:0.60286	train-error:0.32515
# [04:53:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [22]	eval-logloss:0.60189	eval-error:0.32433	train-logloss:0.60252	train-error:0.32487
# [04:53:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [23]	eval-logloss:0.60168	eval-error:0.32421	train-logloss:0.60233	train-error:0.32478
# [04:54:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [24]	eval-logloss:0.60124	eval-error:0.32382	train-logloss:0.60190	train-error:0.32438
# [04:55:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [25]	eval-logloss:0.60062	eval-error:0.32333	train-logloss:0.60129	train-error:0.32385
# [04:55:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [26]	eval-logloss:0.60023	eval-error:0.32307	train-logloss:0.60092	train-error:0.32349
# [04:56:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [27]	eval-logloss:0.59998	eval-error:0.32281	train-logloss:0.60068	train-error:0.32324
# [04:56:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [28]	eval-logloss:0.59979	eval-error:0.32260	train-logloss:0.60051	train-error:0.32316
# [04:57:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [29]	eval-logloss:0.59959	eval-error:0.32249	train-logloss:0.60031	train-error:0.32307
# [04:57:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [30]	eval-logloss:0.59945	eval-error:0.32240	train-logloss:0.60018	train-error:0.32304
# [04:58:11] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [31]	eval-logloss:0.59917	eval-error:0.32211	train-logloss:0.59992	train-error:0.32283
# [04:58:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [32]	eval-logloss:0.59894	eval-error:0.32189	train-logloss:0.59970	train-error:0.32265
# [04:59:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [33]	eval-logloss:0.59850	eval-error:0.32148	train-logloss:0.59925	train-error:0.32217
# [04:59:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [34]	eval-logloss:0.59841	eval-error:0.32139	train-logloss:0.59917	train-error:0.32205
# [05:00:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [35]	eval-logloss:0.59797	eval-error:0.32096	train-logloss:0.59873	train-error:0.32158
# [05:00:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [36]	eval-logloss:0.59783	eval-error:0.32085	train-logloss:0.59860	train-error:0.32149
# [05:01:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=6
# [37]	eval-logloss:0.59776	eval-error:0.32082	train-logloss:0.59854	train-error:0.32155
# [05:01:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [38]	eval-logloss:0.59748	eval-error:0.32054	train-logloss:0.59828	train-error:0.32127
# [05:02:19] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [39]	eval-logloss:0.59743	eval-error:0.32048	train-logloss:0.59824	train-error:0.32126
# [05:02:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [40]	eval-logloss:0.59706	eval-error:0.32013	train-logloss:0.59787	train-error:0.32083
# [05:03:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [41]	eval-logloss:0.59678	eval-error:0.31978	train-logloss:0.59759	train-error:0.32050
# [05:03:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [42]	eval-logloss:0.59666	eval-error:0.31967	train-logloss:0.59749	train-error:0.32040
# [05:04:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [43]	eval-logloss:0.59654	eval-error:0.31956	train-logloss:0.59737	train-error:0.32032
# [05:04:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [44]	eval-logloss:0.59617	eval-error:0.31924	train-logloss:0.59700	train-error:0.32000
# [05:05:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [45]	eval-logloss:0.59605	eval-error:0.31916	train-logloss:0.59690	train-error:0.31995
# [05:05:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [46]	eval-logloss:0.59598	eval-error:0.31911	train-logloss:0.59683	train-error:0.31982
# [05:06:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [47]	eval-logloss:0.59591	eval-error:0.31901	train-logloss:0.59678	train-error:0.31983
# [05:06:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [48]	eval-logloss:0.59582	eval-error:0.31895	train-logloss:0.59671	train-error:0.31977
# [05:07:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 100 extra nodes, 0 pruned nodes, max_depth=6
# [49]	eval-logloss:0.59576	eval-error:0.31888	train-logloss:0.59665	train-error:0.31977
# [05:08:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=6
# [50]	eval-logloss:0.59571	eval-error:0.31886	train-logloss:0.59661	train-error:0.31973
# [05:08:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [51]	eval-logloss:0.59553	eval-error:0.31868	train-logloss:0.59643	train-error:0.31956
# [05:09:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [52]	eval-logloss:0.59542	eval-error:0.31860	train-logloss:0.59633	train-error:0.31944
# [05:09:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [53]	eval-logloss:0.59538	eval-error:0.31854	train-logloss:0.59630	train-error:0.31943
# [05:10:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [54]	eval-logloss:0.59535	eval-error:0.31852	train-logloss:0.59628	train-error:0.31940
# [05:10:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [55]	eval-logloss:0.59528	eval-error:0.31847	train-logloss:0.59621	train-error:0.31935
# [05:11:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [56]	eval-logloss:0.59504	eval-error:0.31826	train-logloss:0.59598	train-error:0.31911
# [05:11:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [57]	eval-logloss:0.59493	eval-error:0.31817	train-logloss:0.59589	train-error:0.31904
# [05:12:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [58]	eval-logloss:0.59474	eval-error:0.31797	train-logloss:0.59572	train-error:0.31894
# [05:12:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [59]	eval-logloss:0.59467	eval-error:0.31795	train-logloss:0.59567	train-error:0.31889
# [05:13:11] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [60]	eval-logloss:0.59459	eval-error:0.31784	train-logloss:0.59560	train-error:0.31876
# [05:13:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [61]	eval-logloss:0.59418	eval-error:0.31746	train-logloss:0.59519	train-error:0.31839
# [05:14:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [62]	eval-logloss:0.59399	eval-error:0.31730	train-logloss:0.59501	train-error:0.31819
# [05:14:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [63]	eval-logloss:0.59380	eval-error:0.31711	train-logloss:0.59484	train-error:0.31810
# [05:15:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [64]	eval-logloss:0.59378	eval-error:0.31708	train-logloss:0.59482	train-error:0.31808
# [05:15:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [65]	eval-logloss:0.59357	eval-error:0.31691	train-logloss:0.59461	train-error:0.31787
# [05:16:16] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [66]	eval-logloss:0.59319	eval-error:0.31657	train-logloss:0.59424	train-error:0.31740
# [05:16:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [67]	eval-logloss:0.59313	eval-error:0.31651	train-logloss:0.59419	train-error:0.31734
# [05:17:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [68]	eval-logloss:0.59310	eval-error:0.31648	train-logloss:0.59417	train-error:0.31735
# [05:17:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [69]	eval-logloss:0.59295	eval-error:0.31640	train-logloss:0.59403	train-error:0.31726
# [05:18:22] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [70]	eval-logloss:0.59284	eval-error:0.31631	train-logloss:0.59394	train-error:0.31721
# [05:18:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [71]	eval-logloss:0.59272	eval-error:0.31618	train-logloss:0.59381	train-error:0.31709
# [05:19:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [72]	eval-logloss:0.59255	eval-error:0.31608	train-logloss:0.59366	train-error:0.31702
# [05:19:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [73]	eval-logloss:0.59248	eval-error:0.31603	train-logloss:0.59360	train-error:0.31704
# [05:20:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [74]	eval-logloss:0.59240	eval-error:0.31598	train-logloss:0.59354	train-error:0.31695
# [05:20:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [75]	eval-logloss:0.59215	eval-error:0.31577	train-logloss:0.59330	train-error:0.31674
# [05:21:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [76]	eval-logloss:0.59204	eval-error:0.31566	train-logloss:0.59321	train-error:0.31670
# [05:22:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [77]	eval-logloss:0.59203	eval-error:0.31565	train-logloss:0.59320	train-error:0.31669
# [05:22:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [78]	eval-logloss:0.59196	eval-error:0.31560	train-logloss:0.59315	train-error:0.31663
# [05:23:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [79]	eval-logloss:0.59193	eval-error:0.31560	train-logloss:0.59313	train-error:0.31659
# [05:23:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [80]	eval-logloss:0.59181	eval-error:0.31543	train-logloss:0.59303	train-error:0.31649
# [05:24:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [81]	eval-logloss:0.59171	eval-error:0.31535	train-logloss:0.59292	train-error:0.31637
# [05:24:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [82]	eval-logloss:0.59163	eval-error:0.31528	train-logloss:0.59286	train-error:0.31623
# [05:25:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [83]	eval-logloss:0.59160	eval-error:0.31524	train-logloss:0.59284	train-error:0.31625
# [05:25:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [84]	eval-logloss:0.59154	eval-error:0.31521	train-logloss:0.59279	train-error:0.31624
# [05:26:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [85]	eval-logloss:0.59147	eval-error:0.31517	train-logloss:0.59271	train-error:0.31618
# [05:26:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 108 extra nodes, 0 pruned nodes, max_depth=6
# [86]	eval-logloss:0.59145	eval-error:0.31516	train-logloss:0.59270	train-error:0.31617
# [05:27:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [87]	eval-logloss:0.59143	eval-error:0.31514	train-logloss:0.59269	train-error:0.31618
# [05:27:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [88]	eval-logloss:0.59137	eval-error:0.31510	train-logloss:0.59265	train-error:0.31608
# [05:28:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [89]	eval-logloss:0.59118	eval-error:0.31493	train-logloss:0.59246	train-error:0.31598
# [05:28:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [90]	eval-logloss:0.59106	eval-error:0.31482	train-logloss:0.59235	train-error:0.31590
# [05:29:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [91]	eval-logloss:0.59093	eval-error:0.31466	train-logloss:0.59223	train-error:0.31578
# [05:29:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [92]	eval-logloss:0.59077	eval-error:0.31452	train-logloss:0.59209	train-error:0.31570
# [05:30:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [93]	eval-logloss:0.59066	eval-error:0.31440	train-logloss:0.59200	train-error:0.31560
# [05:31:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [94]	eval-logloss:0.59060	eval-error:0.31435	train-logloss:0.59195	train-error:0.31557
# [05:31:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [95]	eval-logloss:0.59051	eval-error:0.31430	train-logloss:0.59187	train-error:0.31549
# [05:32:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [96]	eval-logloss:0.59048	eval-error:0.31427	train-logloss:0.59184	train-error:0.31546
# [05:32:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 100 extra nodes, 0 pruned nodes, max_depth=6
# [97]	eval-logloss:0.59047	eval-error:0.31426	train-logloss:0.59184	train-error:0.31547
# [05:33:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [98]	eval-logloss:0.59043	eval-error:0.31422	train-logloss:0.59182	train-error:0.31545
# [05:33:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [99]	eval-logloss:0.59038	eval-error:0.31419	train-logloss:0.59178	train-error:0.31537
# 2020-03-20 05:33:39 RTwCmnt ********************************************************************************
# [05:37:36] WARNING: /workspace/src/gbm/gbtree.cc:138: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [05:38:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-logloss:0.44398	eval-error:0.00776	train-logloss:0.44533	train-error:0.00778
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [05:39:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-logloss:0.30825	eval-error:0.00776	train-logloss:0.30905	train-error:0.00778
# [05:39:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 84 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-logloss:0.22387	eval-error:0.00776	train-logloss:0.22374	train-error:0.00778
# [05:39:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-logloss:0.16724	eval-error:0.00776	train-logloss:0.16737	train-error:0.00778
# [05:40:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=6
# [4]	eval-logloss:0.12899	eval-error:0.00776	train-logloss:0.12899	train-error:0.00778
# [05:40:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [5]	eval-logloss:0.10238	eval-error:0.00776	train-logloss:0.10246	train-error:0.00778
# [05:40:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [6]	eval-logloss:0.08385	eval-error:0.00776	train-logloss:0.08395	train-error:0.00778
# [05:41:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-logloss:0.07095	eval-error:0.00776	train-logloss:0.07106	train-error:0.00778
# [05:41:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	eval-logloss:0.06199	eval-error:0.00776	train-logloss:0.06209	train-error:0.00778
# [05:41:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	eval-logloss:0.05584	eval-error:0.00776	train-logloss:0.05590	train-error:0.00778
# [05:42:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [10]	eval-logloss:0.05159	eval-error:0.00776	train-logloss:0.05169	train-error:0.00778
# Stopping. Best iteration:
# [0]	eval-logloss:0.44398	eval-error:0.00776	train-logloss:0.44533	train-error:0.00778

# %%
def show_feat_importance(bst):
    ax = xgb.plot_importance(bst, height=0.8, max_num_features=9)
    ax.grid(False, axis="y")
    ax.set_title('Estimated feature importance')
    plt.show()
    feat2importance=bst.get_fscore()
    display(pd.DataFrame([feat2importance.keys(), feat2importance.values()]).T.sort_values(1, ascending=False).head(20))

# %%
for tgt,bst in tgt2bst.items():
    print(tgt)
    show_feat_importance(bst)
# Out:
# Retweet
#                                         0    1
# 6                           u1_fllwer_cnt  652
# 15                         u1_fllwing_cnt  528
# 7                                len_toks  494
# 1                         u2_follower_cnt  474
# 11                       u2_following_cnt  422
# 16                           u1_create_tm  297
# 5                              num_hshtgs  262
# 13                           u2_create_tm  246
# 26                                     tm  213
# 17                           tmdlta_twtu2  183
# 21                                tm_hour  180
# 4                          twttyp_Retweet  178
# 19                           tmdlta_twtu1  150
# 9                         has_media_Photo  133
# 12  lang_22C448FF81263D4BAF2A176145EE9EAD  129
# 18                              num_links  125
# 24                            tmdlta_u2u1  114
# 10                             u1_fllw_u2   89
# 8                         has_media_Video   88
# 20  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   86
# Reply
#                                         0   1
# 5                          u1_fllwing_cnt  71
# 7                        u2_following_cnt  61
# 2                            u2_create_tm  59
# 16                           tmdlta_twtu2  51
# 4                           u1_fllwer_cnt  51
# 9                         u2_follower_cnt  50
# 3   lang_167115458A0DBDFF7E9C0C53A83BAC9B  42
# 23  lang_22C448FF81263D4BAF2A176145EE9EAD  28
# 25                               len_toks  27
# 10                             num_hshtgs  25
# 11  lang_9BF3403E0EB7EA8A256DA9019C0B0716  24
# 20                           u1_create_tm  23
# 15                              num_links  19
# 18                            tmdlta_u2u1  18
# 12  lang_4DC22C3F31C5C43721E6B5815A595ED6  15
# 19  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC  15
# 1                              u1_fllw_u2  13
# 0                          twttyp_Retweet  12
# 14                        twttyp_TopLevel  11
# 21                                tm_hour  11
# Like
#                                         0    1
# 7                           u1_fllwer_cnt  741
# 19                         u1_fllwing_cnt  572
# 2                                len_toks  494
# 5                        u2_following_cnt  448
# 6                         u2_follower_cnt  448
# 11                           u1_create_tm  326
# 3                            u2_create_tm  261
# 17                                     tm  249
# 28                                tm_hour  203
# 14                        has_media_Photo  172
# 8                            tmdlta_twtu1  170
# 20                             num_hshtgs  163
# 26  lang_22C448FF81263D4BAF2A176145EE9EAD  162
# 0                          twttyp_Retweet  157
# 1                               num_links  139
# 9                            tmdlta_twtu2  138
# 21                            tmdlta_u2u1  131
# 24                        twttyp_TopLevel  120
# 16                             u1_fllw_u2  120
# 12                               u1_vrfed  108
# RTwCmnt
#                                         0   1
# 0                         u2_follower_cnt  73
# 2                            u2_create_tm  64
# 7                            tmdlta_twtu2  62
# 4                         has_media_Video  41
# 13                               len_toks  36
# 1                              u1_fllw_u2  32
# 8   lang_4DC22C3F31C5C43721E6B5815A595ED6  32
# 6   lang_22C448FF81263D4BAF2A176145EE9EAD  27
# 9                          twttyp_Retweet  27
# 5                         twttyp_TopLevel  22
# 19                          u1_fllwer_cnt  18
# 14                              num_links  16
# 18                         u1_fllwing_cnt  16
# 3                        u2_following_cnt  13
# 21                           u1_create_tm  12
# 15  lang_ECED8A16BE2A5E8871FD55F4842F16B1  10
# 12                           twttyp_Quote   9
# 22                           tmdlta_twtu1   7
# 10                        has_media_Photo   7
# 24                               u2_vrfed   6

# %%
tgt2prdtr={}
tgt2prdvl={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtr[tgt] = bst.predict(dtr)
    tgt2prdvl[tgt] = bst.predict(dvl)
# Out:
# 2020-03-20 05:42:18 Retweet
# 2020-03-20 05:42:24 Reply
# 2020-03-20 05:42:25 Like
# 2020-03-20 05:42:31 RTwCmnt

# %%
tgt2auc_trn={}
tgt2rce_trn={}
tgt2auc_val={}
tgt2rce_val={}
for itgt, tgt in enumerate(tgts):
    print(tgt)
    prdtr_i, prdvl_i = tgt2prdtr[tgt], tgt2prdvl[tgt]
    ytr_i, yvl_i = tgt2ytr[tgt], tgt2yvl[tgt]
    scr_rocauc_trn = roc_auc_score(ytr_i, prdtr_i)
    scr_rocauc_val = roc_auc_score(yvl_i, prdvl_i)
    scr_auc_trn=compute_prauc(prdtr_i, ytr_i)
    scr_rce_trn=compute_rce(prdtr_i, ytr_i)
    scr_auc_val=compute_prauc(prdvl_i, yvl_i)
    scr_rce_val=compute_rce(prdvl_i, yvl_i)

    tgt2auc_trn[tgt]=scr_auc_trn
    tgt2rce_trn[tgt]=scr_rce_trn
    tgt2auc_val[tgt]=scr_auc_val
    tgt2rce_val[tgt]=scr_rce_val
    
    print('train rocauc:', f'{scr_rocauc_trn:.4f}', 'valid auc:', f'{scr_rocauc_val:.4f}', )
    print('train prauc:', f'{scr_auc_trn:.4f}', 'valid auc:', f'{scr_auc_val:.4f}', )
    print('train rce:', f'{scr_rce_trn:.4f}', 'valid rce:', f'{scr_rce_val:.4f}', )
# Out:
# Retweet
# train rocauc: 0.7497 valid auc: 0.7472
# train prauc: 0.3282 valid auc: 0.3239
# train rce: 13.0399 valid rce: 12.7589
# Reply
# train rocauc: 0.7611 valid auc: 0.7594
# train prauc: 0.0937 valid auc: 0.0911
# train rce: 7.6768 valid rce: 7.5359
# Like
# train rocauc: 0.7433 valid auc: 0.7419
# train prauc: 0.6879 valid auc: 0.6863
# train rce: 13.9050 valid rce: 13.7268
# RTwCmnt
# train rocauc: 0.6884 valid auc: 0.6874
# train prauc: 0.0180 valid auc: 0.0175
# train rce: -13.5798 valid rce: -13.5220

# %%
lsttrn=[]
lstval=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    lsttrn+=[(f'PRAUC {tgt}',tgt2auc_trn[tgt]),
          (f'RCE {tgt}',tgt2rce_trn[tgt])]
    lstval+=[(f'PRAUC {tgt}',tgt2auc_val[tgt]),
          (f'RCE {tgt}',tgt2rce_val[tgt])]

dfscrtrn=pd.DataFrame(lsttrn)
dfscrtrn.columns=['metric','scr']
dfscrval=pd.DataFrame(lstval)
dfscrval.columns=['metric','scr']
dfscr = pd.merge(dfscrtrn, dfscrval, on='metric', suffixes=('trn','val'))
dfscr.T
# Out:
#                     0            1            2          3           4  \
# metric  PRAUC Retweet  RCE Retweet  PRAUC Reply  RCE Reply  PRAUC Like
# scrtrn       0.328199      13.0399    0.0937089    7.67678    0.687926
# scrval        0.32389      12.7589    0.0911448     7.5359    0.686266
#
#                5              6            7
# metric  RCE Like  PRAUC RTwCmnt  RCE RTwCmnt
# scrtrn    13.905      0.0180101     -13.5798
# scrval   13.7268      0.0175032      -13.522

# %% [markdown]
# # infer

# %% [raw]
# ls -lhS $p_in | grep val

# %%
# %%time
dftst=pd.read_csv(
    f'{p_in}/val_{valtmstmp}.tsv',
#     f'{p_in}/val_259A6F6DFD672CB1F883CBEC01B99F2D_1584405047.tsv',
    sep='\x01', header=None, names=cols_val,)
# Out:
# CPU times: user 2min 47s, sys: 59.7 s, total: 3min 47s
# Wall time: 6min 14s

# %%
# %%time
dftst = prp_df(dftst, istrn=False)
# Out:
# CPU times: user 2min 13s, sys: 18.3 s, total: 2min 32s
# Wall time: 3min 43s

# %%
# %%time
dtst = xgb.DMatrix(dftst[cols_feat], feature_names=cols_feat)
tgt2prdtst={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtst[tgt] = bst.predict(dtst)
# Out:
# 2020-03-20 05:57:58 Retweet
# 2020-03-20 05:58:06 Reply
# 2020-03-20 05:58:08 Like
# 2020-03-20 05:58:16 RTwCmnt
# CPU times: user 6min 25s, sys: 51.8 s, total: 7min 17s
# Wall time: 4min 29s

# %%
dfsub_ids = dftst[['twtid','u2id',]]

tgt2dfsub = {}
for tgt,prdtst in tgt2prdtst.items():
    dfsub = dfsub_ids.copy()
    dfsub['scr'] = prdtst
    tgt2dfsub[tgt]=dfsub

# %%
# %%time
for tgt, dfsub in tgt2dfsub.items():
    print(dtnow(), tgt)
    dfsub.to_csv(f'{p_out}/{tgt}__{valtmstmp}__{PRFX}.csv',index=False,header=False)
# Out:
# 2020-03-20 05:58:20 Retweet
# 2020-03-20 05:59:21 Reply
# 2020-03-20 06:00:22 Like
# 2020-03-20 06:01:54 RTwCmnt
# CPU times: user 4min 56s, sys: 8.58 s, total: 5min 4s
# Wall time: 5min 30s
