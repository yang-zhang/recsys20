# %% [markdown]
# # start

# %% [markdown]
# from 0320_6; on gpubox

# %%
PRFX='0322_4'
trntmstmp=1584412344
valtmstmp=1584979040
import datetime
print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (trntmstmp, valtmstmp)])

grand_total=1.5e8
MIN_TM_TRN=1580947200
MIN_TM_TST=1581552000
print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (MIN_TM_TRN, MIN_TM_TST)])
# Out:
# ['2020-03-17 02:32:24', '2020-03-23 15:57:20']
# ['2020-02-06 00:00:00', '2020-02-13 00:00:00']

# %% [markdown]
# # setup

# %%
from pathlib import Path
import dask
print('dask.__version__', dask.__version__)
import xgboost as xgb
import dask_xgboost
import dask.dataframe as dd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from sklearn.feature_extraction.text import TfidfVectorizer
from dask.distributed import Client
import pickle
import lightgbm as lgb
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
pd.set_option('display.max_rows', 500)

import datetime
def dtnow(): return datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

SEED=101
HOME='/data/git/recsys20'
p_in=f'{HOME}/input'
p_out=f'{HOME}/output/{PRFX}'
Path(p_out).mkdir(exist_ok=True, parents=True)

from sklearn.metrics import precision_recall_curve, auc, log_loss

def compute_prauc(pred, gt):
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return prauc

def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive/float(len(gt))
    return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

cols=[
'toks',
'hshtgs',
'twtid',
'media',
'links',
'domns',
'twttyp',
'lang',
'tm',

'u1id',
'u1_fllwer_cnt',
'u1_fllwng_cnt',
'u1_vrfed',
'u1_create_tm',

'u2id',
'u2_fllwer_cnt',
'u2_fllwng_cnt',
'u2_vrfed',
'u2_create_tm',

'u1_fllw_u2',
'reply_tm',
'retwt_tm',
'retwt_cmmnt_tm',
'like_tm',
]

cols_val = cols[:-4]
cols_tgt_tmstmp=[
    'retwt_tm',
    'reply_tm',
    'like_tm',
    'retwt_cmmnt_tm',
]
cols_tgt=[o.split('_tm')[0] for o in cols_tgt_tmstmp]
tgts             = ['Retweet','Reply','Like','RTwCmnt',]
assert cols_tgt == ['retwt',  'reply','like','retwt_cmmnt',]
ntgts=len(tgts)
# Out:
# dask.__version__ 2.12.0

# %% [markdown]
# # prepare data

# %% [markdown]
# ## get maps from dfval

# %%
# dfval=dd.read_csv(
#     f'{p_in}/val_{valtmstmp}.tsv',
#     sep='\x01', header=None, names=cols_val,)
# lang2cnt=dict(dfval.lang.value_counts().compute())
# ttl=sum(lang2cnt.values())
# lang2perc={k:v/ttl for k,v in lang2cnt.items()}
langs=['D3164C7FBCF2565DDF915B1B3AEFB1DC', '22C448FF81263D4BAF2A176145EE9EAD', '06D61DCBBE938971E1EA0C38BD9B5446', 'ECED8A16BE2A5E8871FD55F4842F16B1', 'B9175601E87101A984A50F8A62A1C374', '4DC22C3F31C5C43721E6B5815A595ED6', '167115458A0DBDFF7E9C0C53A83BAC9B', '125C57F4FA6D4E110983FB11B52EFD4E', '022EC308651FACB02794A8147AEE1B78', 'FA3F382BC409C271E3D6EAF8BE4648DD', '9BF3403E0EB7EA8A256DA9019C0B0716', '975B38F44D65EE42A547283787FF5A21', '2996EB2FE8162C076D070A4C8D6532CD', 'FF60A88F53E63000266F8B9149E35AD9', '717293301FE296B0B61950D041485825', '3E16B11B7ADE3A22DDFC4423FBCEAD5D', '3820C29CBCA409A33BADF68852057C4A', '9ECD42BC079C20F156F53CB3B99E600E', '76B8A9C3013AE6414A3E6012413CDC3B', 'AEF22666801F0A5846D853B9CEB2E327', '190BA7DA361BC06BC1D7E824C378064D', '1FFD2FE4297F5E70EBC6C3230D95CB9C', 'A0C7021AD8299ADF0C9EBE326C115F6F', 'D413F5FE5236E5650A46FD983AB39212', '48236EC80FDDDFADE99420ABC9210DDF', '691890251F2B9FF922BE6D3699ABEFD2', '920502FAA080485768AA89BC96A55C47', '0331BF70E606D62D92C96CE9AD71A7CF', '89616CFF8EC8637092F885C7EFF43D74', '06BEAB41D66CCFF329D1ED8BA120A6C2', '60FBA0E834CC59D647C3599AD763FFDF', 'C7A400D9AD489ACF673CF12FBB80AAE5', 'E59EF8BB86A6D815331DDF4C467CE0C7', '4249CE88433AEA3F8DCEECF008B3CB95', '544FA32458C903F1125FE6598300A047', 'CB11E9CF42BD0A1BAD5E27BF3422D99D', '3A85BCEC571C3F5AB1069E4924189177', 'FF7EABB5A382356D54D9C41BA0125E09', 'E7BB61D2A87C1E72DF1C7BC292B86A1C', '69C4A33B9AD29AF883D60BA61CC08702', 'F4FD40A716F1572C9A28E9CAA58BE3A5', '259A6F6DFD672CB1F883CBEC01B99F2D', '6431A618DCF7F4CB7F62A95A39BAB77A', '3121F7240D488F74EEED9312E174B217', '54208B51D44E7D91DC2F3DD02ADEDEC2', 'DBEEFB80F8A314311E2B4BD593E11DFE', 'B6D90127A09AB1229731898AEF9D4D7C', 'F3E1016563360F9434FA986CA86C249C', '2216D01F7B48554E4211021A46816FCF', '1BC639981AE88E09129594B11F894A21', 'C942E369C88CE7C56E69A84D04319FF0', '57ADD4576E2AD6648E9B2DE32F3462A5', 'AC1F0671A4B0D5B8112F87DE7B490E6D', 'C2EF5FABE7619D8A333D5F0FF76E1BFA', 'AA0254541959271ED3453119B787D0C3', 'A6B70CDF8C7B934D4A218CA9B6B7FDB4', 'BF477808A37E3E4E9C5D9F1839E8519E', '97F81BD92A1ACA3F1F43C154E689350F', '60A3DB168094D41241E45E0DE3539BC0', '12D8CEB94F89D11D7EB95EAE9689B009', 'F73266A79468BB89C4325FDEDB0B533C', '4690215948DBF6872B8ED1C2BC87B17E', 'D18801336202297E6484F634CAC6592E', '2E18F6F53E3CF073911AF0A93BBE5373', 'B2235C8B73239FDC5780DD132419833A', '515E873C86EE1577E75FA2387B7FA59E',]

# dfval.twttyp.value_counts().compute()
# TopLevel    2932
# Retweet      994
# Quote        213
twttyps=['TopLevel','Retweet','Quote']

# %%
def prp_df(df, istrn=True):
    tm_min = MIN_TM_TRN if istrn else MIN_TM_TST
    df['len_toks'] = df.toks.apply(len)
    for media in ['Photo', 'Video', 'GIF']:
        df[f'has_media_{media}'] = df.media.fillna('').apply(lambda x: media in x)
    for col in ['hshtgs', 'links', 'domns',]:
        df[f'num_{col}'] = df[col].fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0)
    
    df['twt_age'] = df.tm - tm_min
    df['u1_age']  = df.tm - df.u1_create_tm
    df['u2_age']  = df.tm - df.u2_create_tm
        
    tm_dt=pd.to_datetime(df.tm, unit='s')
    df['tm_dayofweek']=tm_dt.dt.dayofweek
    df['tm_hour']=tm_dt.dt.hour
    
    df['tmdlta_u2u1']  = df.u2_create_tm - df.u1_create_tm
    
    df['u1_fllwer_cnt_by_age'] = df.u1_fllwer_cnt / df.u1_age
    df['u1_fllwng_cnt_by_age'] = df.u2_fllwng_cnt / df.u2_age
    
    for typ in twttyps:
        df[f'twttyp_{typ}']=(df.twttyp==typ).astype('int8')

    for lang in langs:
        df[f'lang_{lang}']=(df.lang==lang).astype('int8')
    if istrn: 
        df[cols_tgt]=df[cols_tgt_tmstmp].notna().astype('int8')
        df.drop(inplace=True, columns=['hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 
                                       'tm', 'u1_create_tm','u2_create_tm', 'u1id', 'u2id', 'twtid', ]+cols_tgt_tmstmp, )
    else:
        df.drop(inplace=True, columns=['hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 
                                       'tm', 'u1_create_tm','u2_create_tm', 'u1id', ])        
    return df

# %% [raw]
# ls -hlS $p_in | grep {trntmstmp}

# %%
grand_total
# Out:
# 150000000.0

# %%
grand_total/1e6
# Out:
# 150.0

# %% [raw]
# chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
#                     header=None,names=cols,
#                         chunksize=1e6
#                        )
# for ichnk,df in enumerate(chnks_trn):
#     print(dtnow(), 'chunk', ichnk, df.tm.max())
# ichnk

# %%
chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                    header=None,names=cols, 
                        chunksize=1e6
                       )

np.random.seed(SEED)
lst_df = []
for ichnk,df in enumerate(chnks_trn):
    print(dtnow(), 'chunk', ichnk)
    print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') 
           for o in (df.tm.min(), df.tm.max())])
    df = prp_df(df)    
    lst_df.append(df)
    if ichnk>=0: break
# Out:
# 2020-03-22 16:18:52 chunk 0
# ['2020-02-06 00:00:00', '2020-02-12 23:59:59']

# %%
df = pd.concat(lst_df)

# %%
df.shape
# Out:
# (1000000, 96)

# %%
vec = TfidfVectorizer(ngram_range=(1,1),
                      min_df=100, max_df=0.5, 
                      strip_accents='unicode', use_idf=1,
                      smooth_idf=1, sublinear_tf=1)

# %%
# %%time
Xtk = vec.fit_transform(df.toks)
# Out:
# CPU times: user 44.1 s, sys: 1.36 s, total: 45.4 s
# Wall time: 45.4 s

# %%
# %%time
pca = TruncatedSVD(n_components=300)
Xtk = pca.fit_transform(Xtk)
print(sum(pca.explained_variance_ratio_))
# Out:
# 0.24631076155144954
# CPU times: user 5min 22s, sys: 42.7 s, total: 6min 4s
# Wall time: 4min 8s

# %%
df.drop(columns=['toks'], inplace=True)

# %%
cols_feat=[o for o in df.columns if o not in cols_tgt]

# %%
X,y=df[cols_feat].values,df[cols_tgt ].values

# %%
cols_tk = [f't{i}' for i in range(Xtk.shape[1])]
print(len(cols_tk), cols_tk[:10])

cols_feat += cols_tk
# Out:
# 300 ['t0', 't1', 't2', 't3', 't4', 't5', 't6', 't7', 't8', 't9']

# %%
# %%time
X=np.concatenate([X,Xtk],1)
# Out:
# CPU times: user 5.78 s, sys: 5.72 s, total: 11.5 s
# Wall time: 11.4 s

# %%
# %%time
split=int(len(df)*0.85)
Xtr,Xvl=X[:split],X[split:]
ytr,yvl=y[:split],y[split:]
# Out:
# CPU times: user 23 µs, sys: 0 ns, total: 23 µs
# Wall time: 27.4 µs

# %%
Xtr.shape,Xvl.shape,ytr.shape,yvl.shape
# Out:
# ((850000, 391), (150000, 391), (850000, 4), (150000, 4))

# %%
tgt2ytr={tgt:ytr[:,i] for i,tgt in enumerate(tgts)}
tgt2yvl={tgt:yvl[:,i] for i,tgt in enumerate(tgts)}

# %% [markdown]
# # model

# %%
tgt2bst={}
tgt2evalres={}

tgt2params = {k:{'objective': 'binary:logistic',
    'verbosity': 1,
    'eval_metric': ['aucpr', 'logloss', ],
} for k in tgts}
tgt2params
# Out:
# {'Retweet': {'objective': 'binary:logistic',
#   'verbosity': 1,
#   'eval_metric': ['aucpr', 'logloss']},
#  'Reply': {'objective': 'binary:logistic',
#   'verbosity': 1,
#   'eval_metric': ['aucpr', 'logloss']},
#  'Like': {'objective': 'binary:logistic',
#   'verbosity': 1,
#   'eval_metric': ['aucpr', 'logloss']},
#  'RTwCmnt': {'objective': 'binary:logistic',
#   'verbosity': 1,
#   'eval_metric': ['aucpr', 'logloss']}}

# %%
def traintgt(tgt):
    evals_result = {}
    i=tgts.index(tgt)
    params = tgt2params[tgt]
    print(tgt, params)
    dtr = xgb.DMatrix(Xtr, label=tgt2ytr[tgt], feature_names=cols_feat)
    dvl = xgb.DMatrix(Xvl, label=tgt2yvl[tgt], feature_names=cols_feat)
    evallist = [(dtr, 'train'), (dvl, 'eval')]
    bst = xgb.train(params=params, dtrain=dtr, num_boost_round=1000, 
                    evals=evallist, evals_result=evals_result, 
                    verbose_eval=20,
                    early_stopping_rounds=50)
    tgt2bst[tgt] = bst
    tgt2evalres[tgt] = evals_result
    return bst,evals_result

# %%
tgts
# Out:
# ['Retweet', 'Reply', 'Like', 'RTwCmnt']

# %%
for i,tgt in enumerate(tgts):
    print(dtnow(), tgt, '*'*80)
    tgt2bst[tgt],tgt2evalres[tgt] = traintgt(tgt)
pickle.dump(tgt2bst, open(f"{p_out}/tgt2bst.p", "wb"))
# Out:
# 2020-03-22 16:24:15 Retweet ********************************************************************************
# Retweet {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['aucpr', 'logloss']}
# [0]	train-aucpr:0.26058	train-logloss:0.53318	eval-aucpr:0.25695	eval-logloss:0.53335
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [20]	train-aucpr:0.33144	train-logloss:0.30844	eval-aucpr:0.31050	eval-logloss:0.31345
# [40]	train-aucpr:0.35744	train-logloss:0.30081	eval-aucpr:0.31712	eval-logloss:0.31081
# [60]	train-aucpr:0.37604	train-logloss:0.29585	eval-aucpr:0.31866	eval-logloss:0.31024
# [80]	train-aucpr:0.39008	train-logloss:0.29199	eval-aucpr:0.31819	eval-logloss:0.31020
# [100]	train-aucpr:0.40376	train-logloss:0.28843	eval-aucpr:0.31772	eval-logloss:0.31026
# Stopping. Best iteration:
# [68]	train-aucpr:0.38218	train-logloss:0.29415	eval-aucpr:0.31866	eval-logloss:0.31017
#
# 2020-03-22 16:47:40 Reply ********************************************************************************
# Reply {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['aucpr', 'logloss']}
# [0]	train-aucpr:0.09219	train-logloss:0.46439	eval-aucpr:0.08128	eval-logloss:0.46403
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [20]	train-aucpr:0.14935	train-logloss:0.10906	eval-aucpr:0.10453	eval-logloss:0.11115
# [40]	train-aucpr:0.19780	train-logloss:0.10444	eval-aucpr:0.10165	eval-logloss:0.11118
# [60]	train-aucpr:0.24615	train-logloss:0.10065	eval-aucpr:0.09868	eval-logloss:0.11147
# Stopping. Best iteration:
# [25]	train-aucpr:0.16144	train-logloss:0.10769	eval-aucpr:0.10512	eval-logloss:0.11098
#
# 2020-03-22 17:01:42 Like ********************************************************************************
# Like {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['aucpr', 'logloss']}
# [0]	train-aucpr:0.62506	train-logloss:0.65999	eval-aucpr:0.62021	eval-logloss:0.66056
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [20]	train-aucpr:0.67848	train-logloss:0.59728	eval-aucpr:0.66770	eval-logloss:0.60276
# [40]	train-aucpr:0.69283	train-logloss:0.58756	eval-aucpr:0.67465	eval-logloss:0.59772
# [60]	train-aucpr:0.70356	train-logloss:0.58014	eval-aucpr:0.67935	eval-logloss:0.59461
# [80]	train-aucpr:0.71217	train-logloss:0.57417	eval-aucpr:0.68185	eval-logloss:0.59280
# [100]	train-aucpr:0.71841	train-logloss:0.56973	eval-aucpr:0.68279	eval-logloss:0.59195
# [120]	train-aucpr:0.72498	train-logloss:0.56528	eval-aucpr:0.68293	eval-logloss:0.59174
# [140]	train-aucpr:0.73083	train-logloss:0.56120	eval-aucpr:0.68385	eval-logloss:0.59105
# [160]	train-aucpr:0.73717	train-logloss:0.55679	eval-aucpr:0.68473	eval-logloss:0.59042
# [180]	train-aucpr:0.74278	train-logloss:0.55303	eval-aucpr:0.68478	eval-logloss:0.59029
# [200]	train-aucpr:0.74862	train-logloss:0.54883	eval-aucpr:0.68482	eval-logloss:0.59021
# [220]	train-aucpr:0.75290	train-logloss:0.54588	eval-aucpr:0.68467	eval-logloss:0.59039
# Stopping. Best iteration:
# [189]	train-aucpr:0.74562	train-logloss:0.55086	eval-aucpr:0.68516	eval-logloss:0.59002
#
# 2020-03-22 17:45:44 RTwCmnt ********************************************************************************
# RTwCmnt {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['aucpr', 'logloss']}
# [0]	train-aucpr:0.01487	train-logloss:0.44555	eval-aucpr:0.01239	eval-logloss:0.44527
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [20]	train-aucpr:0.07783	train-logloss:0.04131	eval-aucpr:0.01571	eval-logloss:0.04310
# [40]	train-aucpr:0.16952	train-logloss:0.03756	eval-aucpr:0.01642	eval-logloss:0.04328
# [60]	train-aucpr:0.26991	train-logloss:0.03438	eval-aucpr:0.01604	eval-logloss:0.04372
# Stopping. Best iteration:
# [24]	train-aucpr:0.09469	train-logloss:0.04036	eval-aucpr:0.01731	eval-logloss:0.04298

# %%
for tgt in tgt2evalres:
    evalres=tgt2evalres[tgt]
    plt.plot(evalres['train']['logloss'])
    plt.plot(evalres['eval']['logloss'])
    plt.title(f"{tgt} logloss {len(evalres['train']['logloss'])} rounds")
    plt.show()
    plt.plot(evalres['train']['aucpr'])
    plt.plot(evalres['eval']['aucpr'])
    plt.title(f"{tgt} aucpr {len(evalres['train']['aucpr'])} rounds")
    plt.show()

# %%
def show_feat_importance(tgt):
    bst=tgt2bst[tgt]
    ax = xgb.plot_importance(bst, height=0.8, max_num_features=9)
    ax.grid(False, axis="y")
    ax.set_title(f'{tgt} Estimated feature importance')
    plt.show()
    feat2importance=bst.get_fscore()
    print(tgt)
    display(pd.DataFrame([feat2importance.keys(), feat2importance.values()]).T.sort_values(1, ascending=False))

for tgt in tgt2bst:
    show_feat_importance(tgt)
# Out:
# Retweet
#                                          0    1
# 17                                  u2_age  132
# 1                            u2_fllwer_cnt  129
# 13                           u2_fllwng_cnt  110
# 8                                 len_toks  105
# 6                            u1_fllwer_cnt  104
# 22                           u1_fllwng_cnt   94
# 18                    u1_fllwer_cnt_by_age   83
# 31                                  u1_age   83
# 16                    u1_fllwng_cnt_by_age   74
# 11                                      t0   69
# 32                                      t7   48
# 14                                      t2   43
# 49                             tmdlta_u2u1   42
# 9                                       t8   40
# 51                                      t3   39
# 19                                      t9   38
# 25                                      t4   38
# 53                                      t1   37
# 113                                twt_age   37
# 103                                     t5   34
# 125                                    t26   33
# 4                           twttyp_Retweet   33
# 68                                      t6   32
# 21                                     t13   31
# 81                                     t17   31
# 7                                     t286   30
# 102                                    t54   29
# 23                                     t15   28
# 174                                    t12   26
# 29                                     t64   25
# 238                                   t204   25
# 34                                    t200   25
# 159                                    t16   25
# 52                                    t158   24
# 55                                     t10   24
# 244                                   t202   24
# 124                                    t14   24
# 136                                    t28   24
# 295                                   t119   24
# 73                                    t124   23
# 208                                    t93   23
# 259                                   t279   23
# 177                                    t49   23
# 12                                     t86   23
# 118                                   t278   23
# 225                                   t271   23
# 157                                   t128   23
# 105                                   t102   23
# 227                                    t53   23
# 33                                    t136   23
# 79                                    t230   22
# 249                                    t23   22
# 321                                    t34   22
# 133                                    t52   22
# 128                                   t298   22
# 43                              num_hshtgs   22
# 36                                    t106   21
# 215                                   t207   21
# 78                                    t108   21
# 59                                    t152   21
# 96                                     t40   21
# 139                                   t107   21
# 141                                   t295   20
# 127                                   t237   20
# 334                                    t37   20
# 74                                     t96   20
# 221                                    t89   20
# 87                                    t138   20
# 115                                   t210   20
# 185                                    t90   20
# 198                                   t223   20
# 138                                    t88   20
# 106                                   t282   20
# 109                                    t95   20
# 175                                   t184   20
# 48                                    t183   20
# 2    lang_125C57F4FA6D4E110983FB11B52EFD4E   20
# 100                                   t235   19
# 299                                   t244   19
# 274                                   t225   19
# 15   lang_22C448FF81263D4BAF2A176145EE9EAD   19
# 183                                   t118   19
# 232                                   t139   19
# 50                                     t22   19
# 160                                   t117   19
# 39                                    t127   19
# 162                                   t162   19
# 47                               num_links   19
# 223                                   t191   19
# 291                                   t214   19
# 3                                 u1_vrfed   19
# 209                                    t20   18
# 46                                    t297   18
# 201                                    t74   18
# 230                                   t253   13
# 256                                   t249   13
# 142                                    t71   13
# 337                                   t294   13
# 121                                    t73   13
# 197                                   t105   13
# 210                                   t259   13
# 285                                    t46   13
# 289                                   t185   13
# 217                                   t145   13
# 131                                    t76   13
# 148                                   t240   13
# 294                                   t170   12
# 287                                   t217   12
# 305                                   t101   12
# 75                                    t203   12
# 303                                   t143   12
# 280                                   t288   12
# 341                                   t238   12
# 57                                    t177   12
# 63                                    t114   12
# 279                                   t281   12
# 290                                   t112   12
# 37                                    t219   12
# 56                                     t98   12
# 58                                    t133   12
# 41                                     t31   12
# 90                                    t155   12
# 132                                   t135   12
# 254                                    t56   12
# 214                                   t212   12
# 211                                   t179   12
# 203                                   t165   12
# 122                                   t175   12
# 202                                   t157   12
# 228                                   t257   12
# 200                                   t187   12
# 331                                   t111   12
# 325                                   t173   12
# 170                                   t277   12
# 182                                   t254   12
# 88                                    t196   12
# 176                                   t146   12
# 247                                    t50   12
# 167                                   t194   12
# 339                                   t232   12
# 310                                    t39   11
# 188                                    t62   11
# 154                                   t182   11
# 300                                   t154   11
# 196                                   t172   11
# 336                                   t166   11
# 307                                   t125   11
# 284                                   t255   11
# 320                                    t38   11
# 171                                   t116   11
# 65                                     t97   11
# 126                                   t256   11
# 241                                    t30   11
# 268                                    t70   11
# 234                                   t140   11
# 84                                    t239   10
# 311                                   t222   10
# 163                                   t216   10
# 313                                   t193   10
# 266                                   t192   10
# 213                                   t280   10
# 153                                   t215   10
# 292                                   t263   10
# 338                                   t251   10
# 226                                   t180   10
# 191                                   t109    9
# 216                                   t248    9
# 108                                   t224    9
# 199                                   t164    9
# 275                                   t246    9
# 265                                   t122    9
# 204                                    t44    9
# 260                                    t61    9
# 237                                   t245    9
# 319                                   t241    8
# 0    lang_022EC308651FACB02794A8147AEE1B78    8
# 236                                    t77    8
# 219                                   t265    8
# 80                                    t163    8
# 54                                     t48    8
# 276                                    t36    8
# 257                                   t234    8
# 207  lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D    7
# 323                                   t159    7
# 263                                    t87    7
# 327                                   t149    7
# 165                                   t167    6
# 151  lang_975B38F44D65EE42A547283787FF5A21    6
# 168                           twttyp_Quote    5
# 312                                   t283    5
# 269  lang_ECED8A16BE2A5E8871FD55F4842F16B1    5
# 343                                   t110    5
# 186  lang_FA3F382BC409C271E3D6EAF8BE4648DD    4
# 150  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC    4
# 240  lang_3820C29CBCA409A33BADF68852057C4A    4
# 242  lang_B9175601E87101A984A50F8A62A1C374    4
# 297  lang_2996EB2FE8162C076D070A4C8D6532CD    4
# 329                               u2_vrfed    3
# 330  lang_E7BB61D2A87C1E72DF1C7BC292B86A1C    3
# 332  lang_06BEAB41D66CCFF329D1ED8BA120A6C2    3
# 318  lang_167115458A0DBDFF7E9C0C53A83BAC9B    3
# 306                        has_media_Photo    3
# 340  lang_0331BF70E606D62D92C96CE9AD71A7CF    2
# 346  lang_9BF3403E0EB7EA8A256DA9019C0B0716    2
# 193  lang_06D61DCBBE938971E1EA0C38BD9B5446    2
# 335  lang_1BC639981AE88E09129594B11F894A21    2
# 167                                   t170    8
# 81                                    t199    8
# 72                                     t33    8
# 288                                   t249    8
# 279                                   t284    8
# 191                                   t187    8
# 193                                    t36    8
# 202                                   t273    8
# 273                                   t283    8
# 109                                    t56    8
# 321                                   t233    7
# 289                                   t272    7
# 309                                   t180    7
# 301                                   t241    7
# 315                                    t64    7
# 267                                   t115    7
# 214                                   t189    7
# 169                                    t35    7
# 63                                    t144    7
# 135                                    t47    7
# 186                                    t89    7
# 93                                    t198    7
# 217                                    t65    7
# 221                                    t69    7
# 88                                    t285    7
# 330                                   t281    7
# 174                                   t164    7
# 249                                    t77    7
# 152                                   t103    6
# 299                                   t244    6
# 71                                     t70    6
# 182                                   t193    6
# 282                                    t58    6
# 83                                     t55    6
# 166                                   t143    6
# 184                                    t25    6
# 320                                   t178    6
# 172                                   t131    6
# 307                                   t188    6
# 58                                     t61    6
# 228                                   t120    6
# 118                             num_hshtgs    6
# 328                                    t79    6
# 308                                   t185    6
# 213                                    t67    6
# 324                                   t279    6
# 253                                   t183    6
# 265                                   t206    6
# 51                                    t217    6
# 263                                   t232    6
# 314                                   t104    6
# 261                                   t213    6
# 229                                   t113    6
# 110                                   t230    5
# 171                                   t294    5
# 311                                   t215    5
# 318                                   t277    5
# 131                                   t151    5
# 90                                    t165    5
# 284                                   t269    5
# 316                                   t208    5
# 66   lang_022EC308651FACB02794A8147AEE1B78    5
# 178                                   t261    5
# 180  lang_76B8A9C3013AE6414A3E6012413CDC3B    5
# 254                                   t229    5
# 281                                   t231    5
# 256                                   t216    5
# 70                                    t219    5
# 278                                   t167    5
# 192                                    t94    5
# 270                                   t174    5
# 327                                   t221    4
# 111                                   t242    4
# 242                                   t197    4
# 234                                   t159    4
# 293                                    t31    4
# 200                                   t263    4
# 76                                    t202    4
# 148                                   t176    4
# 286                                   t239    4
# 251                                   t168    4
# 322                                    t60    3
# 326                                tm_hour    3
# 335                                   t246    3
# 215                                    t88    3
# 57                                    t209    3
# 143  lang_22C448FF81263D4BAF2A176145EE9EAD    3
# 310                                   t155    2
# 298  lang_B9175601E87101A984A50F8A62A1C374    2
# 325                        has_media_Video    2
# 168                               u1_vrfed    2
# 238                                   t287    2
# 323  lang_717293301FE296B0B61950D041485825    1
# 268  lang_125C57F4FA6D4E110983FB11B52EFD4E    1
# 291  lang_1FFD2FE4297F5E70EBC6C3230D95CB9C    1
# 329  lang_FA3F382BC409C271E3D6EAF8BE4648DD    1
# 32   lang_12D8CEB94F89D11D7EB95EAE9689B009    1
# 331  lang_190BA7DA361BC06BC1D7E824C378064D    1
# 332                           tm_dayofweek    1
# 333  lang_ECED8A16BE2A5E8871FD55F4842F16B1    1
# 334  lang_2996EB2FE8162C076D070A4C8D6532CD    1
# 100  lang_AEF22666801F0A5846D853B9CEB2E327    1
# Like
#                                          0    1
# 5                            u1_fllwer_cnt  382
# 4                     u1_fllwer_cnt_by_age  376
# 45                           u1_fllwng_cnt  264
# 11                           u2_fllwer_cnt  223
# 8                                   u2_age  216
# 6                                   u1_age  212
# 2                     u1_fllwng_cnt_by_age  173
# 3                                 len_toks  162
# 34                                 twt_age  157
# 39                           u2_fllwng_cnt  144
# 7                              tmdlta_u2u1  103
# 33                                      t8   92
# 37                                      t0   82
# 14                                      t2   80
# 20                                      t3   79
# 32                                      t5   70
# 24                                      t1   67
# 74                                      t7   64
# 22                                      t4   62
# 98                                     t15   57
# 119                                     t6   57
# 66                                      t9   56
# 212                                   t108   53
# 95                                     t10   52
# 173                                   t298   51
# 69                                     t13   50
# 42                                     t17   49
# 157                                    t11   49
# 239                                    t84   48
# 52                                     t49   47
# 160                                    t26   47
# 65                                    t126   47
# 202                                   t124   47
# 116                                   t209   46
# 183                                    t98   46
# 93                                     t19   46
# 35                              u1_fllw_u2   46
# 216                                   t122   46
# 155                                    t16   46
# 143                                   t165   46
# 77                                     t18   45
# 223                                   t157   45
# 294                                   t130   44
# 188                                   t192   44
# 117                                    t63   44
# 141                                   t286   43
# 76                                    t160   43
# 124                                   t107   43
# 169                                   t271   43
# 289                                   t299   42
# 120                                    t90   42
# 9                                     t188   42
# 249                                   t229   42
# 123                                    t44   42
# 235                                    t32   42
# 18                                    t260   42
# 213                                    t30   42
# 100                                    t29   42
# 227                                    t46   41
# 118                                    t86   41
# 280                                    t61   41
# 28                                     t41   41
# 137                                    t47   41
# 196                                    t34   41
# 110                                   t158   41
# 145                                   t176   40
# 89                                    t261   40
# 83                                    t173   40
# 136                                    t96   40
# 75                                    t202   40
# 159                                   t169   40
# 315                                   t235   40
# 12                                    t172   40
# 57                                     t81   40
# 27                                    t285   40
# 0                           twttyp_Retweet   39
# 163                                    t65   39
# 208                                   t284   39
# 186                                   t118   39
# 209                                   t281   39
# 86                                     t35   39
# 51                                     t93   39
# 191                                    t28   39
# 230                                    t36   38
# 104                                   t123   38
# 142                                   t292   38
# 248                                tm_hour   38
# 281                                    t95   38
# 240                                   t127   38
# 293                                   t288   38
# 250                                    t56   38
# 205                                   t262   38
# 60                                    t204   38
# 211                                    t20   38
# 19                                u1_vrfed   38
# 46                                     t12   37
# 135                                    t76   37
# 134                                   t289   37
# 154                                    t14   37
# 270                                   t206   37
# 243                                   t268   37
# 276                                    t57   37
# 53                                     t23   37
# 198                                    t94   37
# 94                                    t222   37
# 291                                    t54   37
# 203                                   t116   37
# 122                                   t121   36
# 58                                    t240   36
# 21                                     t27   36
# 296                                   t231   36
# 138                                    t92   36
# 226                                   t132   36
# 175                                    t22   36
# 150                                   t228   36
# 161                                    t50   36
# 43                                     t99   36
# 23                                     t85   36
# 285                                    t53   36
# 297                                   t138   36
# 114                                   t175   36
# 284                                   t114   36
# 238                                   t111   36
# 55                                    t106   36
# 79                                    t212   35
# 181                                   t251   35
# 13                                    t146   35
# 192                                   t249   35
# 302                                    t82   35
# 295                                   t216   35
# 221                                    t73   35
# 171                                   t295   35
# 206                                   t101   35
# 172                                   t201   35
# 258                                    t64   35
# 199                                   t194   35
# 148                                   t154   35
# 15                                     t51   35
# 305                                   t139   35
# 92                                    t187   35
# 337                                   t217   25
# 323                                   t232   25
# 254                                   t196   25
# 317                                   t170   25
# 36                              num_hshtgs   25
# 61                                    t291   25
# 73                                    t207   24
# 165                                   t148   24
# 339                                   t234   24
# 321                                   t210   24
# 245                                   t218   24
# 242                                   t183   24
# 277                                    t48   24
# 273                                   t238   24
# 153                                    t67   23
# 182                                   t199   23
# 152                                   t186   23
# 329                                   t256   23
# 320                                   t274   23
# 328                                   t294   23
# 197                                    t66   23
# 41                         has_media_Photo   23
# 108                                   t161   23
# 263                                   t223   23
# 261                                   t100   23
# 44                                    t239   22
# 26                                    t257   22
# 286                                   t265   22
# 194                                   t143   22
# 246                                   t224   22
# 274                                   t227   22
# ...
# 349  lang_B6D90127A09AB1229731898AEF9D4D7C    1
# 351  lang_920502FAA080485768AA89BC96A55C47    1
# 350  lang_60FBA0E834CC59D647C3599AD763FFDF    1
# 344  lang_69C4A33B9AD29AF883D60BA61CC08702    1
# 348  lang_3A85BCEC571C3F5AB1069E4924189177    1
# 347  lang_691890251F2B9FF922BE6D3699ABEFD2    1
# 343  lang_76B8A9C3013AE6414A3E6012413CDC3B    1
# 352  lang_2216D01F7B48554E4211021A46816FCF    1
# RTwCmnt
#                                          0   1
# 0                            u2_fllwer_cnt  98
# 10                                  u2_age  71
# 26                             tmdlta_u2u1  37
# 7    lang_22C448FF81263D4BAF2A176145EE9EAD  37
# 20                                len_toks  34
# 24                           u2_fllwng_cnt  29
# 39                           u1_fllwng_cnt  27
# 16                                  u1_age  25
# 12                                     t12  25
# 83                                      t8  25
# 138                   u1_fllwer_cnt_by_age  21
# 2                                       t3  21
# 78                         has_media_Video  19
# 126                                     t6  19
# 18                           u1_fllwer_cnt  19
# 23                                     t40  19
# 1                               u1_fllw_u2  18
# 38                                     t64  18
# 220                                   t208  18
# 84                                    t276  18
# 86   lang_4DC22C3F31C5C43721E6B5815A595ED6  17
# 88                                     t28  17
# 32                                    t108  17
# 53                                    t268  17
# 237                                   t213  16
# 45                    u1_fllwng_cnt_by_age  16
# 145                                    t23  16
# 133                                    t30  16
# 179                                     t0  16
# 167                                   t158  16
# 124                                    t94  15
# 251                                twt_age  15
# 93                                    t278  15
# 14                                     t96  15
# 75                                    t129  15
# 155                                    t61  15
# 81                                     t25  15
# 34                                    t223  15
# 85                                    t293  15
# 108                                   t226  14
# 258                                    t19  14
# 98                                     t21  14
# 141                                   t103  14
# 142                                   t288  14
# 65                                    t128  14
# 260                                   t261  14
# 21                                     t68  14
# 19                                    t151  14
# 232                                   t247  14
# 48                                    t249  14
# 119                                    t63  14
# 162                                   t146  14
# 25                                     t48  14
# 77                                    t130  14
# 195                                   t100  14
# 80                                     t20  14
# 29                                     t56  14
# 99                                    t210  13
# 94                                      t7  13
# 227                                   t192  13
# 104                                    t26  13
# 67                                     t73  13
# 114                                   t122  13
# 137                                   t142  13
# 159                                   t216  13
# 15                                     t17  13
# 185                                   t253  13
# 193                                    t83  13
# 149                                    t41  13
# 201                                    t95  13
# 298                                    t18  13
# 87                                     t98  12
# 188                                   t220   8
# 112                                   t126   8
# 306                                   t266   8
# 204                                   t245   8
# 203                                   t254   8
# 22                                    t190   8
# 236                                   t244   8
# 35                                    t232   8
# 301                                   t117   8
# 272                                tm_hour   8
# 252                                   t196   8
# 90                                    t273   8
# 103                                   t141   8
# 31                                    t136   8
# 189                                   t200   8
# 326                                   t183   8
# 264                                   t275   7
# 289                                   t155   7
# 256                                   t156   7
# 6                                     t239   7
# 273                                   t162   7
# 280                                   t193   7
# 284                                   t145   7
# 279                                   t202   7
# 253                                   t230   7
# 263                                   t228   7
# 247                                   t115   7
# 271                                   t235   7
# 176                                   t160   7
# 183                                   t262   7
# 134                                   t107   7
# 318                                    t87   7
# 58                                     t77   7
# 153                                   t152   7
# 158                                   t269   7
# 169                                   t263   7
# 171                                   t127   7
# 175                                   t291   7
# 292                                    t35   7
# 181                                    t67   7
# 305                                   t286   7
# 60                                    t167   7
# 139                                   t172   7
# 118                                   t241   7
# 187                                   t123   7
# 102                                   t132   7
# 212                                   t175   7
# 215                                   t106   7
# 97                                    t214   7
# 96                                    t242   7
# 62                                     t88   7
# 230                                   t157   7
# 231                                   t279   7
# 11                                     t32   7
# 321                                   t134   7
# 291                                   t274   6
# 322                                    t38   6
# 319                                   t233   6
# 315                                   t194   6
# 282                                   t255   6
# 304                                   t113   6
# 294                                    t97   6
# 120                                   t290   6
# 226                                   t283   6
# 66                                    t243   6
# 92                                    t139   6
# 223                                    t52   6
# 268                                   t137   6
# 235                                    t47   6
# 238                                   t204   6
# 239                                   t272   6
# 174                                    t13   6
# 246                                   t224   6
# 209                                   t169   6
# 91                                     t49   6
# 166                                   t109   6
# 267                                   t238   6
# 151                                    t89   6
# 54                                    t289   6
# 109                           twttyp_Quote   5
# 299                                   t195   5
# 308                                   t221   5
# 116                                   t177   5
# 182                                   t131   5
# 154                                   t227   5
# 184                                    t70   5
# 197                                    t79   5
# 309                                   t217   5
# 222                                   t171   5
# 285                                   t198   5
# 259                                   t135   5
# 327                                   t296   5
# 293                                   t211   5
# 277                                    t62   5
# 266                                   t143   5
# 287                                   t170   5
# 135                                   t201   5
# 316                                   t257   4
# 161                                    t81   4
# 218                                   t205   4
# 307                                    t27   4
# 324                                    t90   4
# 303                                    t66   4
# 245                              num_links   3
# 276  lang_9BF3403E0EB7EA8A256DA9019C0B0716   3
# 95                                    t168   3
# 317                                   t188   3
# 323                                   t186   2
# 325                                     t9   2
# 144                               u1_vrfed   2
# 270                           tm_dayofweek   2
# 302                                   t181   2
# 150                                   t102   2
# 110                        has_media_Photo   2
# 297  lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D   2
# 233  lang_FA3F382BC409C271E3D6EAF8BE4648DD   2
# 261  lang_2996EB2FE8162C076D070A4C8D6532CD   2
# 275  lang_ECED8A16BE2A5E8871FD55F4842F16B1   2
# 240                                    t80   1
# 328  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   1
# 329  lang_259A6F6DFD672CB1F883CBEC01B99F2D   1
# 330                          has_media_GIF   1

# %% [markdown]
# ## valid

# %%
def validtgt(tgt):
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    dtr = xgb.DMatrix(Xtr, label=tgt2ytr[tgt], feature_names=cols_feat)
    dvl = xgb.DMatrix(Xvl, label=tgt2yvl[tgt], feature_names=cols_feat)
    prdtr = bst.predict(dtr, ntree_limit=bst.best_ntree_limit)
    prdvl = bst.predict(dvl, ntree_limit=bst.best_ntree_limit)
    return prdtr,prdvl

# %%
tgt2prdtr={}
tgt2prdvl={}
for tgt,bst in tgt2bst.items():
    tgt2prdtr[tgt],tgt2prdvl[tgt]=validtgt(tgt)
# Out:
# 2020-03-22 17:59:47 Retweet
# 2020-03-22 18:00:03 Reply
# 2020-03-22 18:00:19 Like
# 2020-03-22 18:00:37 RTwCmnt

# %%
tgt2auc_trn={}
tgt2rce_trn={}
tgt2auc_val={}
tgt2rce_val={}
for tgt in tgt2bst:
    print(tgt)
    prdtr_i, prdvl_i = tgt2prdtr[tgt], tgt2prdvl[tgt]
    ytr_i, yvl_i = tgt2ytr[tgt], tgt2yvl[tgt]
    scr_auc_trn=compute_prauc(prdtr_i, ytr_i)
    scr_rce_trn=compute_rce(prdtr_i, ytr_i)
    scr_auc_val=compute_prauc(prdvl_i, yvl_i)
    scr_rce_val=compute_rce(prdvl_i, yvl_i)

    tgt2auc_trn[tgt]=scr_auc_trn
    tgt2rce_trn[tgt]=scr_rce_trn
    tgt2auc_val[tgt]=scr_auc_val
    tgt2rce_val[tgt]=scr_rce_val
    
    print('train prauc:', f'{scr_auc_trn:.4f}','train rce:', f'{scr_rce_trn:.4f}', )
    print('valid prauc:', f'{scr_auc_val:.4f}','valid rce:', f'{scr_rce_val:.4f}', )
# Out:
# Retweet
# train prauc: 0.3822 train rce: 16.6446
# valid prauc: 0.3187 valid rce: 12.3199
# Reply
# train prauc: 0.1614 train rce: 15.1678
# valid prauc: 0.1051 valid rce: 10.9846
# Like
# train prauc: 0.7456 train rce: 19.6661
# valid prauc: 0.6852 valid rce: 13.8928
# RTwCmnt
# train prauc: 0.0947 train rce: 11.3452
# valid prauc: 0.0173 valid rce: 3.6917

# %%
lsttrn=[]
lstval=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    if tgt not in tgt2bst: continue
    lsttrn+=[(f'PRAUC {tgt}',tgt2auc_trn[tgt]),
          (f'RCE {tgt}',tgt2rce_trn[tgt])]
    lstval+=[(f'PRAUC {tgt}',tgt2auc_val[tgt]),
          (f'RCE {tgt}',tgt2rce_val[tgt])]

dfscrtrn=pd.DataFrame(lsttrn)
dfscrtrn.columns=['metric','scr']
dfscrval=pd.DataFrame(lstval)
dfscrval.columns=['metric','scr']
dfscr = pd.merge(dfscrtrn, dfscrval, on='metric', suffixes=('trn','val'))
dfscr.T
# Out:
#                     0            1            2          3           4  \
# metric  PRAUC Retweet  RCE Retweet  PRAUC Reply  RCE Reply  PRAUC Like
# scrtrn       0.382176      16.6446     0.161441    15.1678    0.745624
# scrval       0.318656      12.3199     0.105112    10.9846    0.685157
#
#                5              6            7
# metric  RCE Like  PRAUC RTwCmnt  RCE RTwCmnt
# scrtrn   19.6661      0.0946863      11.3452
# scrval   13.8928      0.0173095      3.69168

# %% [markdown]
# # infer

# %% [raw]
# ls -lhS $p_in | grep val

# %%
# %%time
dftst=pd.read_csv(
    f'{p_in}/val_{valtmstmp}.tsv',
#     f'{p_in}/val_259A6F6DFD672CB1F883CBEC01B99F2D_1584405047.tsv',
    sep='\x01', header=None, names=cols_val,)
# Out:
# CPU times: user 1min 37s, sys: 8.76 s, total: 1min 46s
# Wall time: 1min 46s

# %%
# %%time
dftst = prp_df(dftst, istrn=False)
# Out:
# CPU times: user 47.1 s, sys: 8.17 s, total: 55.3 s
# Wall time: 55.3 s

# %%
# %%time
dtst = xgb.DMatrix(dftst[cols_feat], feature_names=cols_feat)
tgt2prdtst={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtst[tgt] = bst.predict(dtst)
# Out:
# 2020-03-20 16:28:21 Retweet
# 2020-03-20 16:28:34 Reply
# 2020-03-20 16:28:39 Like
# 2020-03-20 16:29:33 RTwCmnt
# CPU times: user 19min 49s, sys: 12.8 s, total: 20min 2s
# Wall time: 1min 53s

# %%
dfsub_ids = dftst[['twtid','u2id',]]

tgt2dfsub = {}
for tgt,prdtst in tgt2prdtst.items():
    dfsub = dfsub_ids.copy()
    dfsub['scr'] = prdtst
    tgt2dfsub[tgt]=dfsub

# %%
# %%time
for tgt, dfsub in tgt2dfsub.items():
    print(dtnow(), tgt)
    dfsub.to_csv(f'{p_out}/{tgt}__{valtmstmp}__{PRFX}.csv',index=False,header=False)
# Out:
# 2020-03-20 16:29:38 Retweet
# 2020-03-20 16:30:34 Reply
# 2020-03-20 16:31:31 Like
# 2020-03-20 16:32:26 RTwCmnt
# CPU times: user 3min 37s, sys: 6.78 s, total: 3min 44s
# Wall time: 3min 45s
