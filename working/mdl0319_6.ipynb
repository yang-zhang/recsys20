# %% [markdown]
# # start

# %% [markdown]
# return to four models

# %%
PRFX='0319_6'
trntmstmp=1584412344
valtmstmp=1584626395
import datetime
[datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (trntmstmp, valtmstmp)]
# Out:
# ['2020-03-17 02:32:24', '2020-03-19 13:59:55']

# %%
grand_total=1.5e8

# %% [markdown]
# # setup

# %%
from pathlib import Path
import dask
print('dask.__version__', dask.__version__)
import xgboost as xgb
import dask_xgboost
import dask.dataframe as dd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from dask.distributed import Client
import pickle
import lightgbm as lgb
from tqdm import tqdm

import datetime
def dtnow(): return datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

SEED=101
HOME='/data/git/recsys20'
p_in=f'{HOME}/input'
p_out=f'{HOME}/output/{PRFX}'
Path(p_out).mkdir(exist_ok=True, parents=True)

from sklearn.metrics import precision_recall_curve, auc, log_loss

def compute_prauc(pred, gt):
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return prauc

def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive/float(len(gt))
    return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

cols=[
'toks',
'hshtgs',
'twtid',
'media',
'links',
'domns',
'twttyp',
'lang',
'tm',

'u1id',
'u1_fllwer_cnt',
'u1_fllwing_cnt',
'u1_vrfed',
'u1_create_tm',

'u2id',
'u2_follower_cnt',
'u2_following_cnt',
'u2_vrfed',
'u2_create_tm',

'u1_fllw_u2',
'reply_tm',
'retwt_tm',
'retwt_cmmnt_tm',
'like_tm',
]

cols_val = cols[:-4]
cols_tgt_tmstmp=[
    'retwt_tm',
    'reply_tm',
    'like_tm',
    'retwt_cmmnt_tm',
]
cols_tgt=[o.split('_tm')[0] for o in cols_tgt_tmstmp]
tgts             = ['Retweet','Reply','Like','RTwCmnt',]
assert cols_tgt == ['retwt',  'reply','like','retwt_cmmnt',]
ntgts=len(tgts)
# Out:
# dask.__version__ 2.12.0

# %% [markdown]
# # prepare data

# %% [markdown]
# ## get maps from dfval

# %%
# dfval=dd.read_csv(
#     f'{p_in}/val_{valtmstmp}.tsv',
#     sep='\x01', header=None, names=cols_val,)
# lang2cnt=dict(dfval.lang.value_counts().compute())
# ttl=sum(lang2cnt.values())
# lang2perc={k:v/ttl for k,v in lang2cnt.items()}
langs=['D3164C7FBCF2565DDF915B1B3AEFB1DC', '22C448FF81263D4BAF2A176145EE9EAD', '06D61DCBBE938971E1EA0C38BD9B5446', 'ECED8A16BE2A5E8871FD55F4842F16B1', 'B9175601E87101A984A50F8A62A1C374', '4DC22C3F31C5C43721E6B5815A595ED6', '167115458A0DBDFF7E9C0C53A83BAC9B', '125C57F4FA6D4E110983FB11B52EFD4E', '022EC308651FACB02794A8147AEE1B78', 'FA3F382BC409C271E3D6EAF8BE4648DD', '9BF3403E0EB7EA8A256DA9019C0B0716', '975B38F44D65EE42A547283787FF5A21', '2996EB2FE8162C076D070A4C8D6532CD', 'FF60A88F53E63000266F8B9149E35AD9', '717293301FE296B0B61950D041485825', '3E16B11B7ADE3A22DDFC4423FBCEAD5D', '3820C29CBCA409A33BADF68852057C4A', '9ECD42BC079C20F156F53CB3B99E600E', '76B8A9C3013AE6414A3E6012413CDC3B', 'AEF22666801F0A5846D853B9CEB2E327', '190BA7DA361BC06BC1D7E824C378064D', '1FFD2FE4297F5E70EBC6C3230D95CB9C', 'A0C7021AD8299ADF0C9EBE326C115F6F', 'D413F5FE5236E5650A46FD983AB39212', '48236EC80FDDDFADE99420ABC9210DDF', '691890251F2B9FF922BE6D3699ABEFD2', '920502FAA080485768AA89BC96A55C47', '0331BF70E606D62D92C96CE9AD71A7CF', '89616CFF8EC8637092F885C7EFF43D74', '06BEAB41D66CCFF329D1ED8BA120A6C2', '60FBA0E834CC59D647C3599AD763FFDF', 'C7A400D9AD489ACF673CF12FBB80AAE5', 'E59EF8BB86A6D815331DDF4C467CE0C7', '4249CE88433AEA3F8DCEECF008B3CB95', '544FA32458C903F1125FE6598300A047', 'CB11E9CF42BD0A1BAD5E27BF3422D99D', '3A85BCEC571C3F5AB1069E4924189177', 'FF7EABB5A382356D54D9C41BA0125E09', 'E7BB61D2A87C1E72DF1C7BC292B86A1C', '69C4A33B9AD29AF883D60BA61CC08702', 'F4FD40A716F1572C9A28E9CAA58BE3A5', '259A6F6DFD672CB1F883CBEC01B99F2D', '6431A618DCF7F4CB7F62A95A39BAB77A', '3121F7240D488F74EEED9312E174B217', '54208B51D44E7D91DC2F3DD02ADEDEC2', 'DBEEFB80F8A314311E2B4BD593E11DFE', 'B6D90127A09AB1229731898AEF9D4D7C', 'F3E1016563360F9434FA986CA86C249C', '2216D01F7B48554E4211021A46816FCF', '1BC639981AE88E09129594B11F894A21', 'C942E369C88CE7C56E69A84D04319FF0', '57ADD4576E2AD6648E9B2DE32F3462A5', 'AC1F0671A4B0D5B8112F87DE7B490E6D', 'C2EF5FABE7619D8A333D5F0FF76E1BFA', 'AA0254541959271ED3453119B787D0C3', 'A6B70CDF8C7B934D4A218CA9B6B7FDB4', 'BF477808A37E3E4E9C5D9F1839E8519E', '97F81BD92A1ACA3F1F43C154E689350F', '60A3DB168094D41241E45E0DE3539BC0', '12D8CEB94F89D11D7EB95EAE9689B009', 'F73266A79468BB89C4325FDEDB0B533C', '4690215948DBF6872B8ED1C2BC87B17E', 'D18801336202297E6484F634CAC6592E', '2E18F6F53E3CF073911AF0A93BBE5373', 'B2235C8B73239FDC5780DD132419833A', '515E873C86EE1577E75FA2387B7FA59E',]

# dfval.twttyp.value_counts().compute()
# TopLevel    2932
# Retweet      994
# Quote        213
twttyps=['TopLevel','Retweet','Quote']

# %%
def prp_df(df, istrn=True):
    df['len_toks']=df.toks.apply(len)
    for media in ['Photo', 'Video', 'GIF']:
        df[f'has_media_{media}'] = df.media.fillna('').apply(lambda x: media in x)
    for col in ['hshtgs', 'links', 'domns',]:
        df[f'num_{col}'] = df[col].fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0)
    tm_dt=pd.to_datetime(df.tm, unit='s')
    df['tm_month']=tm_dt.dt.month
    df['tm_dayofweek']=tm_dt.dt.dayofweek
    df['tm_day']=tm_dt.dt.day
    df['tm_hour']=tm_dt.dt.hour
    df['tmdlta_u2u1']  = df.u2_create_tm - df.u1_create_tm
    df['tmdlta_twtu1'] = df.tm - df.u1_create_tm
    df['tmdlta_twtu2'] = df.tm - df.u2_create_tm

    for typ in twttyps:
        df[f'twttyp_{typ}']=(df.twttyp==typ).astype('int8')

    for lang in langs:
        df[f'lang_{lang}']=(df.lang==lang).astype('int8')
    if istrn: 
        df[cols_tgt]=df[cols_tgt_tmstmp].notna().astype('int8')
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 'twtid', 'u1id', 'u2id']+cols_tgt_tmstmp, )
    else:
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 'u1id',])        
    return df

# %% [raw]
# ls -hlS $p_in | grep {trntmstmp}

# %%
grand_total
# Out:
# 150000000.0

# %%
grand_total/1e6
# Out:
# 150.0

# %% [raw]
# chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
#                     header=None,names=cols,
#                         chunksize=1e6
#                        )
# for ichnk,df in enumerate(chnks_trn):
#     print(dtnow(), 'chunk', ichnk, df.tm.max())
# ichnk

# %%
chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                    header=None,names=cols, 
                        chunksize=1e6
                       )

np.random.seed(SEED)
lst_df = []
for ichnk,df in enumerate(chnks_trn):
    print(dtnow(), 'chunk', ichnk)
    df = prp_df(df)    
    lst_df.append(df)
    if ichnk>=19: break
# Out:
# 2020-03-20 03:42:41 chunk 0
# 2020-03-20 03:42:57 chunk 1
# 2020-03-20 03:43:13 chunk 2
# 2020-03-20 03:43:29 chunk 3
# 2020-03-20 03:43:45 chunk 4
# 2020-03-20 03:44:00 chunk 5
# 2020-03-20 03:44:16 chunk 6
# 2020-03-20 03:44:32 chunk 7
# 2020-03-20 03:44:48 chunk 8
# 2020-03-20 03:45:04 chunk 9
# 2020-03-20 03:45:23 chunk 10
# 2020-03-20 03:45:43 chunk 11
# 2020-03-20 03:46:17 chunk 12
# 2020-03-20 03:46:53 chunk 13
# 2020-03-20 03:47:28 chunk 14
# 2020-03-20 03:48:04 chunk 15
# 2020-03-20 03:48:40 chunk 16
# 2020-03-20 03:49:16 chunk 17
# 2020-03-20 03:49:53 chunk 18
# 2020-03-20 03:50:29 chunk 19

# %%
df = pd.concat(lst_df)

# %%
df.shape
# Out:
# (20000000, 97)

# %%
df.columns
# Out:
# Index(['tm', 'u1_fllwer_cnt', 'u1_fllwing_cnt', 'u1_vrfed', 'u1_create_tm',
#        'u2_follower_cnt', 'u2_following_cnt', 'u2_vrfed', 'u2_create_tm',
#        'u1_fllw_u2', 'len_toks', 'has_media_Photo', 'has_media_Video',
#        'has_media_GIF', 'num_hshtgs', 'num_links', 'num_domns', 'tm_month',
#        'tm_dayofweek', 'tm_day', 'tm_hour', 'tmdlta_u2u1', 'tmdlta_twtu1',
#        'tmdlta_twtu2', 'twttyp_TopLevel', 'twttyp_Retweet', 'twttyp_Quote',
#        'lang_D3164C7FBCF2565DDF915B1B3AEFB1DC',
#        'lang_22C448FF81263D4BAF2A176145EE9EAD',
#        'lang_06D61DCBBE938971E1EA0C38BD9B5446',
#        'lang_ECED8A16BE2A5E8871FD55F4842F16B1',
#        'lang_B9175601E87101A984A50F8A62A1C374',
#        'lang_4DC22C3F31C5C43721E6B5815A595ED6',
#        'lang_167115458A0DBDFF7E9C0C53A83BAC9B',
#        'lang_125C57F4FA6D4E110983FB11B52EFD4E',
#        'lang_022EC308651FACB02794A8147AEE1B78',
#        'lang_FA3F382BC409C271E3D6EAF8BE4648DD',
#        'lang_9BF3403E0EB7EA8A256DA9019C0B0716',
#        'lang_975B38F44D65EE42A547283787FF5A21',
#        'lang_2996EB2FE8162C076D070A4C8D6532CD',
#        'lang_FF60A88F53E63000266F8B9149E35AD9',
#        'lang_717293301FE296B0B61950D041485825',
#        'lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D',
#        'lang_3820C29CBCA409A33BADF68852057C4A',
#        'lang_9ECD42BC079C20F156F53CB3B99E600E',
#        'lang_76B8A9C3013AE6414A3E6012413CDC3B',
#        'lang_AEF22666801F0A5846D853B9CEB2E327',
#        'lang_190BA7DA361BC06BC1D7E824C378064D',
#        'lang_1FFD2FE4297F5E70EBC6C3230D95CB9C',
#        'lang_A0C7021AD8299ADF0C9EBE326C115F6F',
#        'lang_D413F5FE5236E5650A46FD983AB39212',
#        'lang_48236EC80FDDDFADE99420ABC9210DDF',
#        'lang_691890251F2B9FF922BE6D3699ABEFD2',
#        'lang_920502FAA080485768AA89BC96A55C47',
#        'lang_0331BF70E606D62D92C96CE9AD71A7CF',
#        'lang_89616CFF8EC8637092F885C7EFF43D74',
#        'lang_06BEAB41D66CCFF329D1ED8BA120A6C2',
#        'lang_60FBA0E834CC59D647C3599AD763FFDF',
#        'lang_C7A400D9AD489ACF673CF12FBB80AAE5',
#        'lang_E59EF8BB86A6D815331DDF4C467CE0C7',
#        'lang_4249CE88433AEA3F8DCEECF008B3CB95',
#        'lang_544FA32458C903F1125FE6598300A047',
#        'lang_CB11E9CF42BD0A1BAD5E27BF3422D99D',
#        'lang_3A85BCEC571C3F5AB1069E4924189177',
#        'lang_FF7EABB5A382356D54D9C41BA0125E09',
#        'lang_E7BB61D2A87C1E72DF1C7BC292B86A1C',
#        'lang_69C4A33B9AD29AF883D60BA61CC08702',
#        'lang_F4FD40A716F1572C9A28E9CAA58BE3A5',
#        'lang_259A6F6DFD672CB1F883CBEC01B99F2D',
#        'lang_6431A618DCF7F4CB7F62A95A39BAB77A',
#        'lang_3121F7240D488F74EEED9312E174B217',
#        'lang_54208B51D44E7D91DC2F3DD02ADEDEC2',
#        'lang_DBEEFB80F8A314311E2B4BD593E11DFE',
#        'lang_B6D90127A09AB1229731898AEF9D4D7C',
#        'lang_F3E1016563360F9434FA986CA86C249C',
#        'lang_2216D01F7B48554E4211021A46816FCF',
#        'lang_1BC639981AE88E09129594B11F894A21',
#        'lang_C942E369C88CE7C56E69A84D04319FF0',
#        'lang_57ADD4576E2AD6648E9B2DE32F3462A5',
#        'lang_AC1F0671A4B0D5B8112F87DE7B490E6D',
#        'lang_C2EF5FABE7619D8A333D5F0FF76E1BFA',
#        'lang_AA0254541959271ED3453119B787D0C3',
#        'lang_A6B70CDF8C7B934D4A218CA9B6B7FDB4',
#        'lang_BF477808A37E3E4E9C5D9F1839E8519E',
#        'lang_97F81BD92A1ACA3F1F43C154E689350F',
#        'lang_60A3DB168094D41241E45E0DE3539BC0',
#        'lang_12D8CEB94F89D11D7EB95EAE9689B009',
#        'lang_F73266A79468BB89C4325FDEDB0B533C',
#        'lang_4690215948DBF6872B8ED1C2BC87B17E',
#        'lang_D18801336202297E6484F634CAC6592E',
#        'lang_2E18F6F53E3CF073911AF0A93BBE5373',
#        'lang_B2235C8B73239FDC5780DD132419833A',
#        'lang_515E873C86EE1577E75FA2387B7FA59E', 'retwt', 'reply', 'like',
#        'retwt_cmmnt'],
#       dtype='object')

# %%
cols_feat=[o for o in df.columns if o not in cols_tgt]

# %%
# %%time
split=int(len(df)*0.85)
Xtr,Xvl=df[cols_feat][:split],df[cols_feat][split:]
ytr,yvl=df[cols_tgt ][:split],df[cols_tgt ][split:]
# Out:
# CPU times: user 8.05 s, sys: 8.61 s, total: 16.7 s
# Wall time: 17.9 s

# %%
Xtr.shape,Xvl.shape,ytr.shape,yvl.shape
# Out:
# ((17000000, 93), (3000000, 93), (17000000, 4), (3000000, 4))

# %% [markdown]
# # model

# %%
params = {
    'objective': 'binary:logistic',
    'verbosity': 2,
    'eval_metric': ['logloss','error'],
#     https://xgboost.readthedocs.io/en/latest/tutorials/param_tuning.html
#     'max_delta_step': 1,
}

num_rounds = 100

# %%
tgt2bst={}
tgt2ytr={}
tgt2yvl={}
for i,tgt in enumerate(tgts):
    print(dtnow(), tgt, '*'*80)
    tgt2ytr[tgt]=ytr.iloc[:,i]
    tgt2yvl[tgt]=yvl.iloc[:,i]
    dtr = xgb.DMatrix(Xtr, label=ytr.iloc[:,i], feature_names=cols_feat)
    dvl = xgb.DMatrix(Xvl, label=yvl.iloc[:,i], feature_names=cols_feat)
    evallist = [(dtr, 'eval'), (dvl, 'train')]
    bst = xgb.train(params=params, dtrain=dtr, num_boost_round=num_rounds, evals=evallist, early_stopping_rounds=10)
    tgt2bst[tgt] = bst
    
pickle.dump(tgt2bst, open(f"{p_out}/tgt2bst.p", "wb"))
# Out:
# 2020-03-20 03:51:11 Retweet ********************************************************************************
# [03:55:51] WARNING: /workspace/src/gbm/gbtree.cc:138: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [03:57:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-logloss:0.53412	eval-error:0.11054	train-logloss:0.53317	train-error:0.11033
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [03:58:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-logloss:0.44750	eval-error:0.11030	train-logloss:0.44793	train-error:0.11005
# [03:59:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-logloss:0.39839	eval-error:0.11019	train-logloss:0.39809	train-error:0.10998
# [04:00:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-logloss:0.36800	eval-error:0.11008	train-logloss:0.36797	train-error:0.10982
# [04:01:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [4]	eval-logloss:0.35007	eval-error:0.11003	train-logloss:0.34943	train-error:0.10977
# [04:02:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [5]	eval-logloss:0.33837	eval-error:0.10991	train-logloss:0.33803	train-error:0.10967
# [04:03:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [6]	eval-logloss:0.33122	eval-error:0.10988	train-logloss:0.33074	train-error:0.10965
# [04:04:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-logloss:0.32622	eval-error:0.10981	train-logloss:0.32569	train-error:0.10958
# [04:05:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	eval-logloss:0.32288	eval-error:0.10973	train-logloss:0.32241	train-error:0.10952
# [04:06:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	eval-logloss:0.32102	eval-error:0.10968	train-logloss:0.32046	train-error:0.10950
# [04:07:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [10]	eval-logloss:0.31928	eval-error:0.10964	train-logloss:0.31870	train-error:0.10945
# [04:08:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [11]	eval-logloss:0.31809	eval-error:0.10963	train-logloss:0.31757	train-error:0.10942
# [04:10:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [12]	eval-logloss:0.31711	eval-error:0.10960	train-logloss:0.31662	train-error:0.10937
# [04:11:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [13]	eval-logloss:0.31642	eval-error:0.10958	train-logloss:0.31593	train-error:0.10936
# [04:12:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [14]	eval-logloss:0.31571	eval-error:0.10953	train-logloss:0.31526	train-error:0.10930
# [04:13:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15]	eval-logloss:0.31541	eval-error:0.10950	train-logloss:0.31496	train-error:0.10928
# [04:14:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16]	eval-logloss:0.31486	eval-error:0.10947	train-logloss:0.31439	train-error:0.10927
# [04:15:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17]	eval-logloss:0.31447	eval-error:0.10944	train-logloss:0.31400	train-error:0.10924
# [04:16:19] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [18]	eval-logloss:0.31425	eval-error:0.10942	train-logloss:0.31379	train-error:0.10921
# [04:17:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [19]	eval-logloss:0.31402	eval-error:0.10939	train-logloss:0.31355	train-error:0.10920
# [04:18:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [20]	eval-logloss:0.31354	eval-error:0.10937	train-logloss:0.31307	train-error:0.10916
# [04:19:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [21]	eval-logloss:0.31316	eval-error:0.10934	train-logloss:0.31269	train-error:0.10914
# [04:20:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [22]	eval-logloss:0.31287	eval-error:0.10929	train-logloss:0.31243	train-error:0.10909
# [04:21:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [23]	eval-logloss:0.31276	eval-error:0.10928	train-logloss:0.31232	train-error:0.10909
# [04:22:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [24]	eval-logloss:0.31258	eval-error:0.10927	train-logloss:0.31214	train-error:0.10907
# [04:23:52] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [25]	eval-logloss:0.31225	eval-error:0.10925	train-logloss:0.31182	train-error:0.10908
# [04:24:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [26]	eval-logloss:0.31217	eval-error:0.10924	train-logloss:0.31175	train-error:0.10906
# [04:26:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [27]	eval-logloss:0.31205	eval-error:0.10923	train-logloss:0.31164	train-error:0.10905
# [04:27:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [28]	eval-logloss:0.31180	eval-error:0.10918	train-logloss:0.31139	train-error:0.10902
# [04:28:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [29]	eval-logloss:0.31174	eval-error:0.10918	train-logloss:0.31134	train-error:0.10901
# [04:29:11] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [30]	eval-logloss:0.31161	eval-error:0.10918	train-logloss:0.31122	train-error:0.10901
# [04:29:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [31]	eval-logloss:0.31156	eval-error:0.10918	train-logloss:0.31117	train-error:0.10901
# [04:30:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [32]	eval-logloss:0.31147	eval-error:0.10916	train-logloss:0.31109	train-error:0.10900
# [04:30:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [33]	eval-logloss:0.31126	eval-error:0.10915	train-logloss:0.31089	train-error:0.10900
# [04:31:34] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [34]	eval-logloss:0.31107	eval-error:0.10913	train-logloss:0.31070	train-error:0.10897
# [04:32:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [35]	eval-logloss:0.31092	eval-error:0.10911	train-logloss:0.31056	train-error:0.10895
# [04:33:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [36]	eval-logloss:0.31073	eval-error:0.10910	train-logloss:0.31036	train-error:0.10894
# [04:34:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [37]	eval-logloss:0.31068	eval-error:0.10910	train-logloss:0.31033	train-error:0.10894
# [04:35:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [38]	eval-logloss:0.31061	eval-error:0.10908	train-logloss:0.31027	train-error:0.10893
# [04:36:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [39]	eval-logloss:0.31053	eval-error:0.10908	train-logloss:0.31018	train-error:0.10892
# [04:37:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [40]	eval-logloss:0.31045	eval-error:0.10907	train-logloss:0.31011	train-error:0.10892
# [04:38:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [41]	eval-logloss:0.31040	eval-error:0.10907	train-logloss:0.31007	train-error:0.10892
# [04:39:09] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [42]	eval-logloss:0.31038	eval-error:0.10907	train-logloss:0.31004	train-error:0.10892
# [04:39:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [43]	eval-logloss:0.31036	eval-error:0.10907	train-logloss:0.31003	train-error:0.10892
# [04:40:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [44]	eval-logloss:0.31024	eval-error:0.10906	train-logloss:0.30993	train-error:0.10892
# [04:41:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [45]	eval-logloss:0.31022	eval-error:0.10906	train-logloss:0.30991	train-error:0.10892
# [04:41:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [46]	eval-logloss:0.31013	eval-error:0.10904	train-logloss:0.30983	train-error:0.10890
# [04:43:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [47]	eval-logloss:0.31009	eval-error:0.10903	train-logloss:0.30979	train-error:0.10889
# [04:44:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [48]	eval-logloss:0.31001	eval-error:0.10903	train-logloss:0.30972	train-error:0.10889
# [04:45:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [49]	eval-logloss:0.30985	eval-error:0.10902	train-logloss:0.30957	train-error:0.10888
# [04:46:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [50]	eval-logloss:0.30980	eval-error:0.10901	train-logloss:0.30953	train-error:0.10887
# [04:47:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [51]	eval-logloss:0.30968	eval-error:0.10900	train-logloss:0.30942	train-error:0.10887
# [04:48:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [52]	eval-logloss:0.30964	eval-error:0.10899	train-logloss:0.30938	train-error:0.10887
# [04:49:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [53]	eval-logloss:0.30962	eval-error:0.10899	train-logloss:0.30937	train-error:0.10886
# [04:50:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 112 extra nodes, 0 pruned nodes, max_depth=6
# [54]	eval-logloss:0.30956	eval-error:0.10896	train-logloss:0.30931	train-error:0.10885
# [04:51:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [55]	eval-logloss:0.30953	eval-error:0.10895	train-logloss:0.30929	train-error:0.10885
# [04:52:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [56]	eval-logloss:0.30950	eval-error:0.10895	train-logloss:0.30927	train-error:0.10884
# [04:53:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [57]	eval-logloss:0.30941	eval-error:0.10894	train-logloss:0.30918	train-error:0.10884
# [04:54:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [58]	eval-logloss:0.30936	eval-error:0.10894	train-logloss:0.30913	train-error:0.10884
# [04:55:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [59]	eval-logloss:0.30934	eval-error:0.10893	train-logloss:0.30912	train-error:0.10883
# [04:56:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [60]	eval-logloss:0.30925	eval-error:0.10892	train-logloss:0.30904	train-error:0.10881
# [04:57:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [61]	eval-logloss:0.30919	eval-error:0.10891	train-logloss:0.30899	train-error:0.10880
# [04:58:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [62]	eval-logloss:0.30917	eval-error:0.10890	train-logloss:0.30897	train-error:0.10879
# [04:59:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [63]	eval-logloss:0.30915	eval-error:0.10890	train-logloss:0.30896	train-error:0.10878
# [05:01:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [64]	eval-logloss:0.30913	eval-error:0.10890	train-logloss:0.30894	train-error:0.10878
# [05:02:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [65]	eval-logloss:0.30911	eval-error:0.10890	train-logloss:0.30893	train-error:0.10878
# [05:03:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [66]	eval-logloss:0.30898	eval-error:0.10888	train-logloss:0.30880	train-error:0.10878
# [05:04:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [67]	eval-logloss:0.30898	eval-error:0.10888	train-logloss:0.30880	train-error:0.10878
# [05:05:12] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [68]	eval-logloss:0.30885	eval-error:0.10886	train-logloss:0.30869	train-error:0.10877
# [05:06:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 110 extra nodes, 0 pruned nodes, max_depth=6
# [69]	eval-logloss:0.30884	eval-error:0.10886	train-logloss:0.30867	train-error:0.10877
# [05:07:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [70]	eval-logloss:0.30876	eval-error:0.10884	train-logloss:0.30861	train-error:0.10875
# [05:08:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [71]	eval-logloss:0.30872	eval-error:0.10883	train-logloss:0.30858	train-error:0.10873
# [05:09:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [72]	eval-logloss:0.30867	eval-error:0.10883	train-logloss:0.30853	train-error:0.10872
# [05:10:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [73]	eval-logloss:0.30866	eval-error:0.10882	train-logloss:0.30852	train-error:0.10872
# [05:11:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [74]	eval-logloss:0.30856	eval-error:0.10880	train-logloss:0.30844	train-error:0.10871
# [05:12:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [75]	eval-logloss:0.30851	eval-error:0.10880	train-logloss:0.30839	train-error:0.10871
# [05:13:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [76]	eval-logloss:0.30840	eval-error:0.10879	train-logloss:0.30829	train-error:0.10869
# [05:14:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=6
# [77]	eval-logloss:0.30839	eval-error:0.10879	train-logloss:0.30828	train-error:0.10869
# [05:15:38] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [78]	eval-logloss:0.30838	eval-error:0.10878	train-logloss:0.30827	train-error:0.10869
# [05:16:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [79]	eval-logloss:0.30834	eval-error:0.10878	train-logloss:0.30825	train-error:0.10867
# [05:17:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [80]	eval-logloss:0.30826	eval-error:0.10876	train-logloss:0.30818	train-error:0.10867
# [05:18:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [81]	eval-logloss:0.30823	eval-error:0.10876	train-logloss:0.30816	train-error:0.10866
# [05:19:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=6
# [82]	eval-logloss:0.30822	eval-error:0.10876	train-logloss:0.30815	train-error:0.10867
# [05:20:58] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [83]	eval-logloss:0.30810	eval-error:0.10874	train-logloss:0.30804	train-error:0.10865
# [05:22:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [84]	eval-logloss:0.30802	eval-error:0.10873	train-logloss:0.30796	train-error:0.10865
# [05:23:07] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [85]	eval-logloss:0.30796	eval-error:0.10873	train-logloss:0.30791	train-error:0.10864
# [05:24:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [86]	eval-logloss:0.30789	eval-error:0.10872	train-logloss:0.30784	train-error:0.10864
# [05:25:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [87]	eval-logloss:0.30785	eval-error:0.10871	train-logloss:0.30780	train-error:0.10863
# [05:26:19] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [88]	eval-logloss:0.30782	eval-error:0.10870	train-logloss:0.30778	train-error:0.10863
# [05:27:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [89]	eval-logloss:0.30779	eval-error:0.10869	train-logloss:0.30777	train-error:0.10862
# [05:28:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=6
# [90]	eval-logloss:0.30778	eval-error:0.10869	train-logloss:0.30776	train-error:0.10862
# [05:29:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [91]	eval-logloss:0.30777	eval-error:0.10869	train-logloss:0.30776	train-error:0.10862
# [05:30:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [92]	eval-logloss:0.30777	eval-error:0.10869	train-logloss:0.30775	train-error:0.10862
# [05:31:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [93]	eval-logloss:0.30774	eval-error:0.10869	train-logloss:0.30773	train-error:0.10862
# [05:32:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [94]	eval-logloss:0.30768	eval-error:0.10868	train-logloss:0.30768	train-error:0.10860
# [05:33:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [95]	eval-logloss:0.30764	eval-error:0.10866	train-logloss:0.30765	train-error:0.10859
# [05:34:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [96]	eval-logloss:0.30761	eval-error:0.10865	train-logloss:0.30763	train-error:0.10858
# [05:35:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [97]	eval-logloss:0.30758	eval-error:0.10865	train-logloss:0.30761	train-error:0.10858
# [05:35:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [98]	eval-logloss:0.30752	eval-error:0.10864	train-logloss:0.30756	train-error:0.10857
# [05:36:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [99]	eval-logloss:0.30746	eval-error:0.10863	train-logloss:0.30751	train-error:0.10857
# 2020-03-20 05:36:21 Reply ********************************************************************************
# [05:43:25] WARNING: /workspace/src/gbm/gbtree.cc:138: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [05:44:16] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 108 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-logloss:0.46108	eval-error:0.02744	train-logloss:0.46409	train-error:0.02733
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [05:44:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-logloss:0.34019	eval-error:0.02744	train-logloss:0.33902	train-error:0.02734
# [05:45:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-logloss:0.26238	eval-error:0.02744	train-logloss:0.26166	train-error:0.02734
# [05:46:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-logloss:0.21218	eval-error:0.02744	train-logloss:0.21182	train-error:0.02734
# [05:46:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [4]	eval-logloss:0.17881	eval-error:0.02744	train-logloss:0.17889	train-error:0.02734
# [05:47:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [5]	eval-logloss:0.15670	eval-error:0.02744	train-logloss:0.15666	train-error:0.02734
# [05:47:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [6]	eval-logloss:0.14235	eval-error:0.02744	train-logloss:0.14177	train-error:0.02734
# [05:48:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-logloss:0.13206	eval-error:0.02744	train-logloss:0.13174	train-error:0.02734
# [05:49:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	eval-logloss:0.12527	eval-error:0.02744	train-logloss:0.12511	train-error:0.02734
# [05:50:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	eval-logloss:0.12075	eval-error:0.02744	train-logloss:0.12068	train-error:0.02734
# [05:50:41] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [10]	eval-logloss:0.11805	eval-error:0.02744	train-logloss:0.11776	train-error:0.02734
# Stopping. Best iteration:
# [0]	eval-logloss:0.46108	eval-error:0.02744	train-logloss:0.46409	train-error:0.02733
#
# 2020-03-20 05:50:43 Like ********************************************************************************
# [06:00:39] WARNING: /workspace/src/gbm/gbtree.cc:138: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [06:01:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-logloss:0.66079	eval-error:0.35486	train-logloss:0.66114	train-error:0.35562
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
# Will train until train-error hasn't improved in 10 rounds.
# [06:02:09] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-logloss:0.64307	eval-error:0.34700	train-logloss:0.64377	train-error:0.34756
# [06:02:45] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-logloss:0.63358	eval-error:0.34598	train-logloss:0.63361	train-error:0.34661
# [06:03:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-logloss:0.62698	eval-error:0.34389	train-logloss:0.62748	train-error:0.34423
# [06:03:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [4]	eval-logloss:0.62252	eval-error:0.34077	train-logloss:0.62287	train-error:0.34118
# [06:04:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [5]	eval-logloss:0.61985	eval-error:0.33925	train-logloss:0.62012	train-error:0.33964
# [06:05:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [6]	eval-logloss:0.61720	eval-error:0.33716	train-logloss:0.61764	train-error:0.33764
# [06:05:41] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-logloss:0.61521	eval-error:0.33606	train-logloss:0.61568	train-error:0.33646
# [06:06:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	eval-logloss:0.61382	eval-error:0.33522	train-logloss:0.61423	train-error:0.33558
# [06:06:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	eval-logloss:0.61223	eval-error:0.33394	train-logloss:0.61270	train-error:0.33430
# [06:07:24] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [10]	eval-logloss:0.61128	eval-error:0.33327	train-logloss:0.61179	train-error:0.33368
# [06:07:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [11]	eval-logloss:0.60999	eval-error:0.33200	train-logloss:0.61045	train-error:0.33248
# [06:08:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [12]	eval-logloss:0.60901	eval-error:0.33113	train-logloss:0.60951	train-error:0.33168
# [06:09:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [13]	eval-logloss:0.60834	eval-error:0.33065	train-logloss:0.60882	train-error:0.33119
# [06:09:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [14]	eval-logloss:0.60733	eval-error:0.32939	train-logloss:0.60780	train-error:0.32987
# [06:10:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15]	eval-logloss:0.60673	eval-error:0.32913	train-logloss:0.60721	train-error:0.32962
# [06:10:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16]	eval-logloss:0.60591	eval-error:0.32825	train-logloss:0.60642	train-error:0.32870
# [06:11:22] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [17]	eval-logloss:0.60539	eval-error:0.32785	train-logloss:0.60588	train-error:0.32829
# [06:11:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [18]	eval-logloss:0.60477	eval-error:0.32725	train-logloss:0.60526	train-error:0.32766
# [06:12:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [19]	eval-logloss:0.60424	eval-error:0.32688	train-logloss:0.60475	train-error:0.32729
# [06:13:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [20]	eval-logloss:0.60386	eval-error:0.32656	train-logloss:0.60437	train-error:0.32695
# [06:13:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [21]	eval-logloss:0.60301	eval-error:0.32573	train-logloss:0.60352	train-error:0.32612
# [06:14:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [22]	eval-logloss:0.60258	eval-error:0.32527	train-logloss:0.60308	train-error:0.32568
# [06:14:46] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [23]	eval-logloss:0.60235	eval-error:0.32510	train-logloss:0.60286	train-error:0.32552
# [06:15:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [24]	eval-logloss:0.60206	eval-error:0.32492	train-logloss:0.60258	train-error:0.32531
# [06:15:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [25]	eval-logloss:0.60162	eval-error:0.32451	train-logloss:0.60214	train-error:0.32494
# [06:16:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [26]	eval-logloss:0.60103	eval-error:0.32397	train-logloss:0.60155	train-error:0.32443
# [06:17:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [27]	eval-logloss:0.60058	eval-error:0.32344	train-logloss:0.60112	train-error:0.32396
# [06:17:35] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [28]	eval-logloss:0.60033	eval-error:0.32322	train-logloss:0.60087	train-error:0.32369
# [06:18:08] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [29]	eval-logloss:0.60002	eval-error:0.32300	train-logloss:0.60057	train-error:0.32345
# [06:18:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [30]	eval-logloss:0.59978	eval-error:0.32282	train-logloss:0.60032	train-error:0.32326
# [06:19:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [31]	eval-logloss:0.59960	eval-error:0.32271	train-logloss:0.60016	train-error:0.32311
# [06:19:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [32]	eval-logloss:0.59948	eval-error:0.32262	train-logloss:0.60004	train-error:0.32299
# [06:20:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [33]	eval-logloss:0.59933	eval-error:0.32244	train-logloss:0.59990	train-error:0.32286
# [06:20:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [34]	eval-logloss:0.59889	eval-error:0.32204	train-logloss:0.59946	train-error:0.32249
# [06:21:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [35]	eval-logloss:0.59861	eval-error:0.32175	train-logloss:0.59918	train-error:0.32218
# [06:22:00] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [36]	eval-logloss:0.59833	eval-error:0.32145	train-logloss:0.59891	train-error:0.32182
# [06:22:33] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [37]	eval-logloss:0.59815	eval-error:0.32130	train-logloss:0.59874	train-error:0.32171
# [06:23:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [38]	eval-logloss:0.59790	eval-error:0.32105	train-logloss:0.59849	train-error:0.32141
# [06:23:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [39]	eval-logloss:0.59779	eval-error:0.32093	train-logloss:0.59839	train-error:0.32133
# [06:24:13] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [40]	eval-logloss:0.59741	eval-error:0.32045	train-logloss:0.59800	train-error:0.32084
# [06:24:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [41]	eval-logloss:0.59729	eval-error:0.32036	train-logloss:0.59788	train-error:0.32076
# [06:25:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [42]	eval-logloss:0.59710	eval-error:0.32028	train-logloss:0.59771	train-error:0.32069
# [06:25:56] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [43]	eval-logloss:0.59700	eval-error:0.32016	train-logloss:0.59762	train-error:0.32057
# [06:26:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [44]	eval-logloss:0.59683	eval-error:0.32001	train-logloss:0.59744	train-error:0.32049
# [06:27:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [45]	eval-logloss:0.59674	eval-error:0.31992	train-logloss:0.59736	train-error:0.32039
# [06:27:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [46]	eval-logloss:0.59641	eval-error:0.31970	train-logloss:0.59703	train-error:0.32017
# [06:28:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [47]	eval-logloss:0.59632	eval-error:0.31963	train-logloss:0.59693	train-error:0.32007
# [06:28:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [48]	eval-logloss:0.59615	eval-error:0.31942	train-logloss:0.59676	train-error:0.31989
# [06:29:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [49]	eval-logloss:0.59598	eval-error:0.31929	train-logloss:0.59661	train-error:0.31972
# [06:29:51] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [50]	eval-logloss:0.59593	eval-error:0.31924	train-logloss:0.59655	train-error:0.31972
# [06:30:25] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=6
# [51]	eval-logloss:0.59574	eval-error:0.31906	train-logloss:0.59636	train-error:0.31951
# [06:30:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [52]	eval-logloss:0.59561	eval-error:0.31898	train-logloss:0.59623	train-error:0.31940
# [06:31:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [53]	eval-logloss:0.59540	eval-error:0.31872	train-logloss:0.59603	train-error:0.31914
# [06:32:03] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [54]	eval-logloss:0.59537	eval-error:0.31869	train-logloss:0.59600	train-error:0.31915
# [06:32:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [55]	eval-logloss:0.59534	eval-error:0.31867	train-logloss:0.59597	train-error:0.31912
# [06:33:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [56]	eval-logloss:0.59527	eval-error:0.31861	train-logloss:0.59592	train-error:0.31909
# [06:33:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [57]	eval-logloss:0.59511	eval-error:0.31845	train-logloss:0.59576	train-error:0.31890
# [06:34:18] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [58]	eval-logloss:0.59498	eval-error:0.31834	train-logloss:0.59563	train-error:0.31879
# [06:34:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [59]	eval-logloss:0.59479	eval-error:0.31823	train-logloss:0.59545	train-error:0.31869
# [06:35:30] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [60]	eval-logloss:0.59467	eval-error:0.31814	train-logloss:0.59533	train-error:0.31859
# [06:36:04] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [61]	eval-logloss:0.59455	eval-error:0.31804	train-logloss:0.59522	train-error:0.31842
# [06:36:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [62]	eval-logloss:0.59448	eval-error:0.31800	train-logloss:0.59516	train-error:0.31836
# [06:37:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [63]	eval-logloss:0.59442	eval-error:0.31795	train-logloss:0.59511	train-error:0.31833
# [06:37:43] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [64]	eval-logloss:0.59427	eval-error:0.31783	train-logloss:0.59496	train-error:0.31819
# [06:38:16] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [65]	eval-logloss:0.59422	eval-error:0.31777	train-logloss:0.59492	train-error:0.31815
# [06:38:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [66]	eval-logloss:0.59419	eval-error:0.31775	train-logloss:0.59490	train-error:0.31815
# [06:39:22] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [67]	eval-logloss:0.59401	eval-error:0.31765	train-logloss:0.59472	train-error:0.31806
# [06:39:54] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [68]	eval-logloss:0.59374	eval-error:0.31734	train-logloss:0.59445	train-error:0.31778
# [06:40:27] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [69]	eval-logloss:0.59365	eval-error:0.31728	train-logloss:0.59436	train-error:0.31774
# [06:41:01] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [70]	eval-logloss:0.59358	eval-error:0.31721	train-logloss:0.59430	train-error:0.31767
# [06:41:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [71]	eval-logloss:0.59357	eval-error:0.31721	train-logloss:0.59429	train-error:0.31767
# [06:42:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [72]	eval-logloss:0.59352	eval-error:0.31716	train-logloss:0.59424	train-error:0.31764
# [06:42:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [73]	eval-logloss:0.59340	eval-error:0.31705	train-logloss:0.59412	train-error:0.31753
# [06:43:11] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [74]	eval-logloss:0.59333	eval-error:0.31701	train-logloss:0.59407	train-error:0.31749
# [06:43:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [75]	eval-logloss:0.59327	eval-error:0.31694	train-logloss:0.59401	train-error:0.31743
# [06:44:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [76]	eval-logloss:0.59311	eval-error:0.31683	train-logloss:0.59384	train-error:0.31733
# [06:44:50] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [77]	eval-logloss:0.59303	eval-error:0.31675	train-logloss:0.59378	train-error:0.31727
# [06:45:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [78]	eval-logloss:0.59301	eval-error:0.31673	train-logloss:0.59376	train-error:0.31726
# [06:45:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=6
# [79]	eval-logloss:0.59298	eval-error:0.31668	train-logloss:0.59373	train-error:0.31724
# [06:46:29] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [80]	eval-logloss:0.59278	eval-error:0.31646	train-logloss:0.59354	train-error:0.31705
# [06:47:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [81]	eval-logloss:0.59259	eval-error:0.31629	train-logloss:0.59337	train-error:0.31692
# [06:47:36] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [82]	eval-logloss:0.59244	eval-error:0.31616	train-logloss:0.59321	train-error:0.31682
# [06:48:09] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [83]	eval-logloss:0.59224	eval-error:0.31597	train-logloss:0.59302	train-error:0.31663
# [06:48:42] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [84]	eval-logloss:0.59201	eval-error:0.31576	train-logloss:0.59279	train-error:0.31635
# [06:49:15] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [85]	eval-logloss:0.59193	eval-error:0.31572	train-logloss:0.59271	train-error:0.31631
# [06:49:49] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [86]	eval-logloss:0.59187	eval-error:0.31566	train-logloss:0.59265	train-error:0.31623
# [06:50:23] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [87]	eval-logloss:0.59177	eval-error:0.31555	train-logloss:0.59256	train-error:0.31615
# [06:50:57] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [88]	eval-logloss:0.59175	eval-error:0.31553	train-logloss:0.59254	train-error:0.31614
# [06:51:31] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [89]	eval-logloss:0.59168	eval-error:0.31546	train-logloss:0.59247	train-error:0.31604
# [06:52:06] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [90]	eval-logloss:0.59157	eval-error:0.31538	train-logloss:0.59237	train-error:0.31597
# [06:52:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [91]	eval-logloss:0.59154	eval-error:0.31535	train-logloss:0.59235	train-error:0.31597
# [06:53:14] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [92]	eval-logloss:0.59153	eval-error:0.31535	train-logloss:0.59234	train-error:0.31597
# [06:53:47] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=6
# [93]	eval-logloss:0.59150	eval-error:0.31532	train-logloss:0.59232	train-error:0.31595
# [06:54:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [94]	eval-logloss:0.59145	eval-error:0.31528	train-logloss:0.59226	train-error:0.31590
# [06:54:55] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [95]	eval-logloss:0.59132	eval-error:0.31522	train-logloss:0.59214	train-error:0.31582
# [06:55:28] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [96]	eval-logloss:0.59117	eval-error:0.31508	train-logloss:0.59199	train-error:0.31567
# [06:56:02] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [97]	eval-logloss:0.59112	eval-error:0.31503	train-logloss:0.59194	train-error:0.31565
# [06:56:37] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [98]	eval-logloss:0.59109	eval-error:0.31499	train-logloss:0.59192	train-error:0.31562
# [06:57:10] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [99]	eval-logloss:0.59107	eval-error:0.31499	train-logloss:0.59191	train-error:0.31561
# 2020-03-20 06:57:11 RTwCmnt ********************************************************************************
# [07:01:22] WARNING: /workspace/src/gbm/gbtree.cc:138: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [07:02:12] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-logloss:0.44309	eval-error:0.00778	train-logloss:0.44519	train-error:0.00782
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [07:02:44] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 86 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-logloss:0.31024	eval-error:0.00778	train-logloss:0.30898	train-error:0.00782
# [07:03:17] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-logloss:0.22368	eval-error:0.00778	train-logloss:0.22390	train-error:0.00782
# [07:03:48] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 106 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-logloss:0.16782	eval-error:0.00778	train-logloss:0.16756	train-error:0.00782
# [07:04:21] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [4]	eval-logloss:0.12892	eval-error:0.00778	train-logloss:0.12915	train-error:0.00782
# [07:04:53] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 118 extra nodes, 0 pruned nodes, max_depth=6
# [5]	eval-logloss:0.10230	eval-error:0.00778	train-logloss:0.10257	train-error:0.00782
# [07:05:26] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [6]	eval-logloss:0.08415	eval-error:0.00778	train-logloss:0.08410	train-error:0.00782
# [07:05:59] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-logloss:0.07120	eval-error:0.00778	train-logloss:0.07123	train-error:0.00782
# [07:06:32] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [8]	eval-logloss:0.06213	eval-error:0.00778	train-logloss:0.06225	train-error:0.00782
# [07:07:05] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [9]	eval-logloss:0.05599	eval-error:0.00778	train-logloss:0.05607	train-error:0.00782
# [07:07:40] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [10]	eval-logloss:0.05177	eval-error:0.00778	train-logloss:0.05186	train-error:0.00782
# Stopping. Best iteration:
# [0]	eval-logloss:0.44309	eval-error:0.00778	train-logloss:0.44519	train-error:0.00782

# %%
def show_feat_importance(bst):
    ax = xgb.plot_importance(bst, height=0.8, max_num_features=9)
    ax.grid(False, axis="y")
    ax.set_title('Estimated feature importance')
    plt.show()
    feat2importance=bst.get_fscore()
    display(pd.DataFrame([feat2importance.keys(), feat2importance.values()]).T.sort_values(1, ascending=False).head(20))

# %%
for tgt,bst in tgt2bst.items():
    print(tgt)
    show_feat_importance(bst)
# Out:
# Retweet
#                                         0    1
# 6                           u1_fllwer_cnt  677
# 10                         u1_fllwing_cnt  512
# 7                                len_toks  504
# 1                         u2_follower_cnt  469
# 11                       u2_following_cnt  400
# 16                           u1_create_tm  287
# 5                              num_hshtgs  287
# 14                           u2_create_tm  258
# 4                          twttyp_Retweet  218
# 13                           tmdlta_twtu2  194
# 26                                     tm  176
# 27                                tm_hour  164
# 21                           tmdlta_twtu1  148
# 17                              num_links  141
# 9                         has_media_Photo  137
# 12  lang_22C448FF81263D4BAF2A176145EE9EAD  121
# 18                        twttyp_TopLevel  118
# 25                            tmdlta_u2u1  116
# 23                             u1_fllw_u2  113
# 8                         has_media_Video   92
# Reply
#                                         0   1
# 5                          u1_fllwing_cnt  77
# 7                        u2_following_cnt  63
# 9                         u2_follower_cnt  56
# 4                           u1_fllwer_cnt  51
# 2                            u2_create_tm  47
# 3   lang_167115458A0DBDFF7E9C0C53A83BAC9B  46
# 16                           tmdlta_twtu2  39
# 19  lang_22C448FF81263D4BAF2A176145EE9EAD  30
# 10                             num_hshtgs  24
# 23                               len_toks  22
# 11  lang_9BF3403E0EB7EA8A256DA9019C0B0716  19
# 15                              num_links  19
# 18                           u1_create_tm  18
# 22  lang_125C57F4FA6D4E110983FB11B52EFD4E  17
# 12  lang_4DC22C3F31C5C43721E6B5815A595ED6  14
# 24                           tmdlta_twtu1  14
# 20  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC  13
# 1                              u1_fllw_u2  12
# 0                          twttyp_Retweet  11
# 17                            tmdlta_u2u1   9
# Like
#                                         0    1
# 7                           u1_fllwer_cnt  852
# 23                         u1_fllwing_cnt  564
# 8                         u2_follower_cnt  487
# 2                                len_toks  455
# 5                        u2_following_cnt  400
# 12                           u1_create_tm  332
# 3                            u2_create_tm  219
# 13                                     tm  209
# 16                        has_media_Photo  187
# 9                            tmdlta_twtu1  184
# 17                             num_hshtgs  181
# 10                           tmdlta_twtu2  167
# 27                                tm_hour  164
# 22  lang_22C448FF81263D4BAF2A176145EE9EAD  157
# 0                          twttyp_Retweet  155
# 6                              u1_fllw_u2  140
# 1                               num_links  139
# 14                               u1_vrfed  136
# 20                        has_media_Video  133
# 28                        twttyp_TopLevel  111
# RTwCmnt
#                                         0   1
# 2                            u2_create_tm  80
# 0                         u2_follower_cnt  79
# 6                            tmdlta_twtu2  57
# 14                               len_toks  45
# 3                         has_media_Video  42
# 7   lang_4DC22C3F31C5C43721E6B5815A595ED6  40
# 1                              u1_fllw_u2  37
# 9                         twttyp_TopLevel  36
# 5   lang_22C448FF81263D4BAF2A176145EE9EAD  31
# 18                         u1_fllwing_cnt  27
# 10                              num_links  19
# 8                          twttyp_Retweet  18
# 22                       u2_following_cnt  16
# 15                          u1_fllwer_cnt  13
# 4   lang_ECED8A16BE2A5E8871FD55F4842F16B1  13
# 12                           twttyp_Quote   8
# 13                        has_media_Photo   7
# 29  lang_022EC308651FACB02794A8147AEE1B78   4
# 23                            tmdlta_u2u1   4
# 17  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   4

# %%
tgt2prdtr={}
tgt2prdvl={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtr[tgt] = bst.predict(dtr)
    tgt2prdvl[tgt] = bst.predict(dvl)
# Out:
# 2020-03-20 07:07:51 Retweet
# 2020-03-20 07:08:01 Reply
# 2020-03-20 07:08:03 Like
# 2020-03-20 07:08:14 RTwCmnt

# %%
tgt2auc_trn={}
tgt2rce_trn={}
tgt2auc_val={}
tgt2rce_val={}
for itgt, tgt in enumerate(tgts):
    print(tgt)
    prdtr_i, prdvl_i = tgt2prdtr[tgt], tgt2prdvl[tgt]
    ytr_i, yvl_i = tgt2ytr[tgt], tgt2yvl[tgt]
    scr_rocauc_trn = roc_auc_score(ytr_i, prdtr_i)
    scr_rocauc_val = roc_auc_score(yvl_i, prdvl_i)
    scr_auc_trn=compute_prauc(prdtr_i, ytr_i)
    scr_rce_trn=compute_rce(prdtr_i, ytr_i)
    scr_auc_val=compute_prauc(prdvl_i, yvl_i)
    scr_rce_val=compute_rce(prdvl_i, yvl_i)

    tgt2auc_trn[tgt]=scr_auc_trn
    tgt2rce_trn[tgt]=scr_rce_trn
    tgt2auc_val[tgt]=scr_auc_val
    tgt2rce_val[tgt]=scr_rce_val
    
    print('train rocauc:', f'{scr_rocauc_trn:.4f}', 'valid auc:', f'{scr_rocauc_val:.4f}', )
    print('train prauc:', f'{scr_auc_trn:.4f}', 'valid auc:', f'{scr_auc_val:.4f}', )
    print('train rce:', f'{scr_rce_trn:.4f}', 'valid rce:', f'{scr_rce_val:.4f}', )
# Out:
# Retweet
# train rocauc: 0.7482 valid auc: 0.7465
# train prauc: 0.3258 valid auc: 0.3216
# train rce: 12.8771 valid rce: 12.6610
# Reply
# train rocauc: 0.7588 valid auc: 0.7590
# train prauc: 0.0917 valid auc: 0.0915
# train rce: 6.1133 valid rce: 6.0680
# Like
# train rocauc: 0.7424 valid auc: 0.7414
# train prauc: 0.6865 valid auc: 0.6850
# train rce: 13.8028 valid rce: 13.6786
# RTwCmnt
# train rocauc: 0.6871 valid auc: 0.6856
# train prauc: 0.0174 valid auc: 0.0172
# train rce: -13.5275 valid rce: -13.4030

# %%
lsttrn=[]
lstval=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    lsttrn+=[(f'PRAUC {tgt}',tgt2auc_trn[tgt]),
          (f'RCE {tgt}',tgt2rce_trn[tgt])]
    lstval+=[(f'PRAUC {tgt}',tgt2auc_val[tgt]),
          (f'RCE {tgt}',tgt2rce_val[tgt])]

dfscrtrn=pd.DataFrame(lsttrn)
dfscrtrn.columns=['metric','scr']
dfscrval=pd.DataFrame(lstval)
dfscrval.columns=['metric','scr']
dfscr = pd.merge(dfscrtrn, dfscrval, on='metric', suffixes=('trn','val'))
dfscr.T
# Out:
#                     0            1            2          3           4  \
# metric  PRAUC Retweet  RCE Retweet  PRAUC Reply  RCE Reply  PRAUC Like
# scrtrn       0.325842      12.8771    0.0917129    6.11329    0.686462
# scrval       0.321565       12.661    0.0914761    6.06796    0.685036
#
#                5              6            7
# metric  RCE Like  PRAUC RTwCmnt  RCE RTwCmnt
# scrtrn   13.8028      0.0173908     -13.5275
# scrval   13.6786      0.0171695      -13.403

# %% [markdown]
# # infer

# %% [raw]
# ls -lhS $p_in | grep val

# %%
# %%time
dftst=pd.read_csv(
    f'{p_in}/val_{valtmstmp}.tsv',
#     f'{p_in}/val_259A6F6DFD672CB1F883CBEC01B99F2D_1584405047.tsv',
    sep='\x01', header=None, names=cols_val,)
# Out:
# CPU times: user 1min 44s, sys: 12.6 s, total: 1min 57s
# Wall time: 4min 11s

# %%
# %%time
dftst = prp_df(dftst, istrn=False)
# Out:
# CPU times: user 1min 57s, sys: 14.1 s, total: 2min 11s
# Wall time: 2min 31s

# %%
# %%time
dtst = xgb.DMatrix(dftst[cols_feat], feature_names=cols_feat)
tgt2prdtst={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtst[tgt] = bst.predict(dtst)
# Out:
# 2020-03-20 07:20:44 Retweet
# 2020-03-20 07:20:51 Reply
# 2020-03-20 07:20:52 Like
# 2020-03-20 07:21:00 RTwCmnt
# CPU times: user 6min 13s, sys: 51.3 s, total: 7min 4s
# Wall time: 3min 50s

# %%
dfsub_ids = dftst[['twtid','u2id',]]

tgt2dfsub = {}
for tgt,prdtst in tgt2prdtst.items():
    dfsub = dfsub_ids.copy()
    dfsub['scr'] = prdtst
    tgt2dfsub[tgt]=dfsub

# %%
# %%time
for tgt, dfsub in tgt2dfsub.items():
    print(dtnow(), tgt)
    dfsub.to_csv(f'{p_out}/{tgt}__{valtmstmp}__{PRFX}.csv',index=False,header=False)
# Out:
# 2020-03-20 07:21:04 Retweet
# 2020-03-20 07:22:02 Reply
# 2020-03-20 07:23:00 Like
# 2020-03-20 07:23:57 RTwCmnt
# CPU times: user 3min 43s, sys: 6.89 s, total: 3min 49s
# Wall time: 3min 50s
