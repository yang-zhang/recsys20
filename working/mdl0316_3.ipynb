# %%
PRFX='0316_3'

# %% [markdown]
# # setup

# %%
from pathlib import Path
import dask.dataframe as dd
import dask.array as da
import pandas as pd
from dask_ml.model_selection import train_test_split
import dask
print('dask.__version__', dask.__version__)
import xgboost
import dask_xgboost
from dask.distributed import Client,LocalCluster
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_curve, auc
import glob
import pickle
import datetime
def dtnow(): return datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')


SEED=101
HOME='/data/git/recsys20'
p_in=f'{HOME}/input'
p_out=f'{HOME}/output/{PRFX}'
Path(p_out).mkdir(exist_ok=True, parents=True)

cols=[
'text_tokens',
'hashtags',
'tweet_id',
'present_media',
'present_links',
'present_domains',
'tweet_type',
'language',
'timestamp',

'engaged_user_id',
'engaged_follower_count',
'engaged_following_count',
'engaged_is_verified',
'engaged_account_creation_time',

'engaging_user_id',
'engaging_follower_count',
'engaging_following_count',
'engaging_is_verified',
'engaging_account_creation_time',

'engagee_follows_engager',
'reply_engagement_timestamp',
'retweet_engagement_timestamp',
'retweet_with_comment_engagement_timestamp',
'like_engagement_timestamp',
]

cols_val = cols[:-4]

tgts=['Retweet','Reply','Like','RTwCmnt',]
cols_tgt_tmstmp=[
    'retweet_engagement_timestamp',
    'reply_engagement_timestamp',
    'like_engagement_timestamp',
    'retweet_with_comment_engagement_timestamp',
]
# Out:
# dask.__version__ 2.12.0

# %%
from sklearn.metrics import precision_recall_curve, auc, log_loss

def compute_prauc(pred, gt):
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return prauc

def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive/float(len(gt))
    return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

# %%
cluster = LocalCluster()
client = Client(cluster)

# %% [markdown]
# # prepare data

# %%
# (rcss20) ➜  recsys20 git:(master) ✗ wc -l input/trn.tsv
#  148,075,238 data/trn.tsv
# (rcss20) ➜  recsys20 git:(master) ✗ wc -l input/val.tsv
#  15,127,684 data/val.tsv

# %%
trntmstmp=1584412344
datetime.datetime.fromtimestamp(trntmstmp).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-03-17 02:32:24'

# %% [raw]
# !head -50000000 {p_in}/trn_{trntmstmp}.tsv > {p_in}/trn_{trntmstmp}_5e7.tsv

# %%
df=dd.read_csv(
    f'{p_in}/trn_{trntmstmp}.tsv',
#     f'{p_in}/trn_{trntmstmp}_1e7.tsv',
    sep='\x01',
    header=None,
    names=cols,)

# %%
# %%time
ys=~df[cols_tgt_tmstmp].isna().to_dask_array(lengths=True)
# Out:
# CPU times: user 1min 12s, sys: 12.9 s, total: 1min 25s
# Wall time: 5min 37s

# %% [raw]
# %%time
# ys.to_zarr(f'{p_out}/ys_{trntmstmp}.zarr')

# %% [raw]
# da.to_hdf5(f'ys_{trntmstmp}.hdf5', f'{p_out}', ys)

# %%
def makeX(df):
    df['len_toks']=df.text_tokens.apply(len, meta=('text_tokens', 'int64'))
    for media in ['Photo', 'Video', 'GIF']:
        df[f'has_media_{media}'] = df.present_media.fillna('').apply(lambda x: media in x, 
                                                                     meta=('present_media', 'string'))
    df['num_hashtags'] = df.hashtags.fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0,
                                                      meta=('hashtags', 'string'))
    df['num_links'] = df.present_links.fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0,
                                                      meta=('hashtags', 'string'))
    df['num_domains'] = df.present_domains.fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0,
                                                      meta=('hashtags', 'string'))
    df['tmdelta_engng_enged'] = df.engaging_account_creation_time - df.engaged_account_creation_time
    df['tmdelta_enged_tweet'] = df.engaged_account_creation_time - df.timestamp
    df['tmdelta_engng_tweet'] = df.engaging_account_creation_time - df.timestamp
    cols_cat0 = [
        'tweet_type',
#         'language',
    ]
    cols_num = ['timestamp', 'engaged_follower_count', 'engaged_following_count',
                'engaged_is_verified', 'engaged_account_creation_time', 'engaging_follower_count',
                'engaging_following_count', 'engaging_is_verified',
                'engaging_account_creation_time', 'engagee_follows_engager',
                'len_toks', 'has_media_Photo', 'has_media_Video', 'has_media_GIF', 
                'num_hashtags', 'num_links', 'num_domains', 
                'tmdelta_engng_enged', 'tmdelta_enged_tweet','tmdelta_engng_tweet']
    df_cat = dd.get_dummies(df[cols_cat0].categorize())
    cols_cat = list(df_cat.columns)
    cols_feat = cols_num+cols_cat
    Xcat=df_cat.to_dask_array(lengths=True)
    Xnum=df[cols_num].to_dask_array(lengths=True)
    X=da.concatenate([Xnum,Xcat],axis=1)
    X=X.rechunk({1: X.shape[1]})
    return X, cols_feat

# %%
# %%time
X, cols_feat = makeX(df)

# %%
X
# Out:
# dask.array<rechunk-merge, shape=(148075238, 23), dtype=object, chunksize=(128996, 23), chunktype=numpy.ndarray>

# %%
import h5py

# %%
f=h5py.File(f'ys_{trntmstmp}.hdf5', 'w')

# %%
d = f.require_dataset(f'{p_out}', shape=ys.shape, dtype=ys.dtype)

# %%
da.store(ys, d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/distributed/protocol/pickle.py in dumps(x)
#      37     try:
# ---> 38         result = pickle.dumps(x, protocol=pickle.HIGHEST_PROTOCOL)
#      39         if len(result) < 1000:
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/h5py/_hl/base.py in __getnewargs__(self)
#     307         """
# --> 308         raise TypeError("h5py objects cannot be pickled")
#     309
#
# TypeError: h5py objects cannot be pickled
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-d69350980122> in <module>
# ----> 1 da.store(ys, d)
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/dask/array/core.py in store(sources, targets, lock, regions, compute, return_stored, **kwargs)
#     949
#     950         if compute:
# --> 951             result.compute(**kwargs)
#     952             return None
#     953         else:
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     435     keys = [x.__dask_keys__() for x in collections]
#     436     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 437     results = schedule(dsk, keys, **kwargs)
#     438     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     439
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2582             retries=retries,
#    2583             user_priority=priority,
# -> 2584             actors=actors,
#    2585         )
#    2586         packed = pack_data(keys, futures)
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/distributed/client.py in _graph_to_futures(self, dsk, keys, restrictions, loose_restrictions, priority, user_priority, resources, retries, fifo_timeout, actors)
#    2509                 {
#    2510                     "op": "update-graph",
# -> 2511                     "tasks": valmap(dumps_task, dsk3),
#    2512                     "dependencies": dependencies,
#    2513                     "keys": list(flatkeys),
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/cytoolz/dicttoolz.pyx in cytoolz.dicttoolz.valmap()
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/cytoolz/dicttoolz.pyx in cytoolz.dicttoolz.valmap()
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/distributed/worker.py in dumps_task(task)
#    3313             return d
#    3314         elif not any(map(_maybe_complex, task[1:])):
# -> 3315             return {"function": dumps_function(task[0]), "args": warn_dumps(task[1:])}
#    3316     return to_serialize(task)
#    3317
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/distributed/worker.py in warn_dumps(obj, dumps, limit)
#    3322 def warn_dumps(obj, dumps=pickle.dumps, limit=1e6):
#    3323     """ Dump an object to bytes, warn if those bytes are large """
# -> 3324     b = dumps(obj)
#    3325     if not _warn_dumps_warned[0] and len(b) > limit:
#    3326         _warn_dumps_warned[0] = True
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/distributed/protocol/pickle.py in dumps(x)
#      49     except Exception:
#      50         try:
# ---> 51             return cloudpickle.dumps(x, protocol=pickle.HIGHEST_PROTOCOL)
#      52         except Exception as e:
#      53             logger.info("Failed to serialize %s. Exception: %s", x, e)
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/cloudpickle/cloudpickle.py in dumps(obj, protocol)
#    1146     try:
#    1147         cp = CloudPickler(file, protocol=protocol)
# -> 1148         cp.dump(obj)
#    1149         return file.getvalue()
#    1150     finally:
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/cloudpickle/cloudpickle.py in dump(self, obj)
#     489         self.inject_addons()
#     490         try:
# --> 491             return Pickler.dump(self, obj)
#     492         except RuntimeError as e:
#     493             if 'recursion' in e.args[0]:
#
# /data/anaconda3/envs/rcss20/lib/python3.7/pickle.py in dump(self, obj)
#     435         if self.proto >= 4:
#     436             self.framer.start_framing()
# --> 437         self.save(obj)
#     438         self.write(STOP)
#     439         self.framer.end_framing()
#
# /data/anaconda3/envs/rcss20/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# /data/anaconda3/envs/rcss20/lib/python3.7/pickle.py in save_tuple(self, obj)
#     787         write(MARK)
#     788         for element in obj:
# --> 789             save(element)
#     790
#     791         if id(obj) in memo:
#
# /data/anaconda3/envs/rcss20/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     522             reduce = getattr(obj, "__reduce_ex__", None)
#     523             if reduce is not None:
# --> 524                 rv = reduce(self.proto)
#     525             else:
#     526                 reduce = getattr(obj, "__reduce__", None)
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/h5py/_hl/base.py in __getnewargs__(self)
#     306         limitations, look at the h5pickle project on PyPI.
#     307         """
# --> 308         raise TypeError("h5py objects cannot be pickled")
#     309
#     310     def __getstate__(self):
#
# TypeError: h5py objects cannot be pickled

# %%
# %%time
Xtrn, Xval, ystrn, ysval = train_test_split(X, ys, test_size=0.15, random_state=SEED)

# %% [markdown]
# # train

# %%
# %%time
params = {'objective': 'binary:logistic'}

tgt2bst={}
tgt2col2fscr={}
for i,tgt in enumerate(tgts):
    print(dtnow(), tgt)
    bst = dask_xgboost.train(client, params,
                             Xtrn, ystrn[:,i],
                             num_boost_round=20)
    tgt2bst[tgt]=bst
    
    fi2col=dict(zip(bst.feature_names, cols_feat))
    col2fi=dict(zip(cols_feat, bst.feature_names))
    fi2fscr=bst.get_fscore()
    col2fscr={col:fi2fscr.get(fi,0) for col,fi in col2fi.items()}
    tgt2col2fscr[tgt]=col2fscr

pickle.dump(tgt2bst, open(f"{p_out}/tgt2bst.p", "wb"))
# Out:
# 2020-03-16 19:03:12 Retweet
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/dask_xgboost/core.py in train(client, params, data, labels, dmatrix_kwargs, evals_result, **kwargs)
#     286         dmatrix_kwargs,
#     287         evals_result,
# --> 288         **kwargs
#     289     )
#     290
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     778         else:
#     779             return sync(
# --> 780                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     781             )
#     782
#
# /data/anaconda3/envs/rcss20/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     343     else:
#     344         while not e.is_set():
# --> 345             e.wait(10)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
#
# /data/anaconda3/envs/rcss20/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /data/anaconda3/envs/rcss20/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
tgt2bst=pickle.load(open(f"{p_out}/tgt2bst.p", "rb"))

# %%
def show_feat_importance(bst):
    ax = xgboost.plot_importance(bst, height=0.8, max_num_features=9)
    ax.grid(False, axis="y")
    ax.set_title('Estimated feature importance')
    plt.show()

for i,tgt in enumerate(tgts):
    print(tgt)
#     show_feat_importance(tgt2bst[tgt])
    col2fscr=tgt2col2fscr[tgt]
    display(pd.DataFrame(col2fscr.items()).sort_values(1, ascending=False))

# %% [markdown]
# # validate

# %%
tgt2yval={}
tgt2prdval={}
for i,tgt in enumerate(tgts):
    print(dtnow(), tgt)
    prdval = dask_xgboost.predict(client, tgt2bst[tgt], Xval).persist()
    yval, prdval = dask.compute(ysval[:,i], prdval)
    tgt2yval[tgt]=yval
    tgt2prdval[tgt]=prdval

# %%
def show_roc(prd,y):
    fpr, tpr, _ = roc_curve(y,prd)
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.plot(fpr, tpr, lw=3,
            label='ROC Curve (area = {:.2f})'.format(auc(fpr, tpr)))
    ax.plot([0, 1], [0, 1], 'k--', lw=2)
    ax.set(
        xlim=(0, 1),
        ylim=(0, 1),
        title="ROC Curve",
        xlabel="False Positive Rate",
        ylabel="True Positive Rate",
    )
    ax.legend();
    plt.show()

# %%
tgt2auc={}
tgt2rce={}
for i,tgt in enumerate(tgts):
    print(tgt)
    yval = tgt2yval[tgt]
    prdval = tgt2prdval[tgt]
    scr_auc=compute_prauc(prdval, yval)
    scr_rce=compute_rce(prdval, yval)
    tgt2auc[tgt]=scr_auc
    tgt2rce[tgt]=scr_rce
    print('auc:',scr_auc)
    print('rce:', scr_rce)
    show_roc(prdval, yval)

# %%
lst=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    lst+=[(f'PRAUC {tgt}',tgt2auc[tgt]),
          (f'RCE {tgt}',tgt2rce[tgt])]

# %%
pd.DataFrame(lst).T

# %% [markdown]
# # infer

# %%
ls {p_in} | grep val

# %%
valtmstmp=1584405047
datetime.datetime.fromtimestamp(valtmstmp).strftime('%Y-%m-%d %H:%M:%S')

# %%
dftst=dd.read_csv(
    f'{p_in}/val_{valtmstmp}.tsv',
#     f'{p_in}/val1e4.tsv',
    sep='\x01',
    header=None,
    names=cols_val,
    encoding='utf8')

# %%
# %%time
Xtst, cols_feat = makeX(dftst)

# %%
# %%time
tgt2prdtst={}
for i,tgt in enumerate(tgts):
    prdtst = dask_xgboost.predict(client, tgt2bst[tgt], Xtst)
    prdtst = prdtst
    tgt2prdtst[tgt]=prdtst

# %%
dfsub_ids = dftst[['tweet_id','engaging_user_id',]]

tgt2dfsub = {}
for tgt,prdtst in tgt2prdtst.items():
    dfsub = dfsub_ids.copy()
    dfsub['scr'] = prdtst
    tgt2dfsub[tgt]=dfsub

# %%
# %%time
for tgt, dfsub in tgt2dfsub.items():
    print(dtnow(), tgt)
    dfsub.to_csv(f'{p_out}/{tgt}__{valtmstmp}__{PRFX}.csv',index=False,header=False,single_file=True)

# %%
# %%time
# for tgt in tgts:
#     print(dtnow(), tgt)
#     dfsub = pd.concat(pd.read_csv(o, header=None) for o in sorted(glob.glob(f'{p_out}/{tgt}__{PRFX}_*.csv')))
#     dfsub.to_csv(f'{p_out}/{tgt}__{PRFX}.csv', 
#                           index=False, 
#                           header=False)
# Out:
# distributed.nanny - WARNING - Restarting worker

# %%
# !head -n 2 {p_in}/val_{valtmstmp}.tsv

# %%
for tgt in tgts:
    # !head -n 2 {p_out}/{tgt}__{valtmstmp}__{PRFX}.csv
