# %% [markdown]
# # start

# %% [markdown]
# from 0322_6; oversample pos cases

# %%
PRFX='0322_7'
trntmstmp=1584412344
valtmstmp=1584979040
import datetime
print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (trntmstmp, valtmstmp)])

grand_total=1.5e8
MIN_TM_TRN=1580947200
MIN_TM_TST=1581552000
print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') for o in (MIN_TM_TRN, MIN_TM_TST)])
# Out:
# ['2020-03-17 02:32:24', '2020-03-23 15:57:20']
# ['2020-02-06 00:00:00', '2020-02-13 00:00:00']

# %% [markdown]
# # setup

# %%
from pathlib import Path
# import dask
# print('dask.__version__', dask.__version__)
import xgboost as xgb
# import dask_xgboost
# import dask.dataframe as dd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from dask.distributed import Client
import pickle
import lightgbm as lgb
from tqdm import tqdm
from collections import Counter
pd.set_option('display.max_rows', 500)

import datetime
def dtnow(): return datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

SEED=101
HOME='/data/git/recsys20'
p_in=f'{HOME}/input'
p_out=f'{HOME}/output/{PRFX}'
Path(p_out).mkdir(exist_ok=True, parents=True)

from sklearn.metrics import precision_recall_curve, auc, log_loss

def compute_prauc(pred, gt):
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return prauc

def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive/float(len(gt))
    return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

# https://towardsdatascience.com/how-to-calibrate-undersampled-model-scores-8f3319c1ea5b
# How to use the function?
# Let’s say your goal is to generate a model that shows the credit default probabilities and your original 
# training data has 50,000 rows with only 500 of them labeled as target class. When you sample your non-target 
# instances randomly and reduce the total row count to 10,000, while conserving 500 target rows, our calibration
# function becomes:
# calibration(model_results, 50000, 500, 10000, 500)
# Here model_results is your model probability output array. After you train your model and put the results in it, your function is ready to use. 

def calibration(data, train_pop, target_pop, sampled_train_pop, sampled_target_pop):
    calibrated_data = \
    ((data * (target_pop / train_pop) / (sampled_target_pop / sampled_train_pop)) /
    ((
        (1 - data) * (1 - target_pop / train_pop) / (1 - sampled_target_pop / sampled_train_pop)
     ) +
     (
        data * (target_pop / train_pop) / (sampled_target_pop / sampled_train_pop)
     )))

    return calibrated_data



cols=[
'toks',
'hshtgs',
'twtid',
'media',
'links',
'domns',
'twttyp',
'lang',
'tm',

'u1id',
'u1_fllwer_cnt',
'u1_fllwng_cnt',
'u1_vrfed',
'u1_create_tm',

'u2id',
'u2_fllwer_cnt',
'u2_fllwng_cnt',
'u2_vrfed',
'u2_create_tm',

'u1_fllw_u2',
'reply_tm',
'retwt_tm',
'retwt_cmmnt_tm',
'like_tm',
]

cols_val = cols[:-4]
cols_tgt_tmstmp=[
    'retwt_tm',
    'reply_tm',
    'like_tm',
    'retwt_cmmnt_tm',
]
cols_tgt=[o.split('_tm')[0] for o in cols_tgt_tmstmp]
tgts             = ['Retweet','Reply','Like','RTwCmnt',]
assert cols_tgt == ['retwt',  'reply','like','retwt_cmmnt',]
ntgts=len(tgts)

tgt2col=dict(zip(tgts,cols_tgt))
tgt2col
# Out:
# {'Retweet': 'retwt',
#  'Reply': 'reply',
#  'Like': 'like',
#  'RTwCmnt': 'retwt_cmmnt'}

# %% [markdown]
# # prepare data

# %% [markdown]
# ## get maps from dfval

# %%
# dfval=dd.read_csv(
#     f'{p_in}/val_{valtmstmp}.tsv',
#     sep='\x01', header=None, names=cols_val,)
# lang2cnt=dict(dfval.lang.value_counts().compute())
# ttl=sum(lang2cnt.values())
# lang2perc={k:v/ttl for k,v in lang2cnt.items()}
langs=['D3164C7FBCF2565DDF915B1B3AEFB1DC', '22C448FF81263D4BAF2A176145EE9EAD', '06D61DCBBE938971E1EA0C38BD9B5446', 'ECED8A16BE2A5E8871FD55F4842F16B1', 'B9175601E87101A984A50F8A62A1C374', '4DC22C3F31C5C43721E6B5815A595ED6', '167115458A0DBDFF7E9C0C53A83BAC9B', '125C57F4FA6D4E110983FB11B52EFD4E', '022EC308651FACB02794A8147AEE1B78', 'FA3F382BC409C271E3D6EAF8BE4648DD', '9BF3403E0EB7EA8A256DA9019C0B0716', '975B38F44D65EE42A547283787FF5A21', '2996EB2FE8162C076D070A4C8D6532CD', 'FF60A88F53E63000266F8B9149E35AD9', '717293301FE296B0B61950D041485825', '3E16B11B7ADE3A22DDFC4423FBCEAD5D', '3820C29CBCA409A33BADF68852057C4A', '9ECD42BC079C20F156F53CB3B99E600E', '76B8A9C3013AE6414A3E6012413CDC3B', 'AEF22666801F0A5846D853B9CEB2E327', '190BA7DA361BC06BC1D7E824C378064D', '1FFD2FE4297F5E70EBC6C3230D95CB9C', 'A0C7021AD8299ADF0C9EBE326C115F6F', 'D413F5FE5236E5650A46FD983AB39212', '48236EC80FDDDFADE99420ABC9210DDF', '691890251F2B9FF922BE6D3699ABEFD2', '920502FAA080485768AA89BC96A55C47', '0331BF70E606D62D92C96CE9AD71A7CF', '89616CFF8EC8637092F885C7EFF43D74', '06BEAB41D66CCFF329D1ED8BA120A6C2', '60FBA0E834CC59D647C3599AD763FFDF', 'C7A400D9AD489ACF673CF12FBB80AAE5', 'E59EF8BB86A6D815331DDF4C467CE0C7', '4249CE88433AEA3F8DCEECF008B3CB95', '544FA32458C903F1125FE6598300A047', 'CB11E9CF42BD0A1BAD5E27BF3422D99D', '3A85BCEC571C3F5AB1069E4924189177', 'FF7EABB5A382356D54D9C41BA0125E09', 'E7BB61D2A87C1E72DF1C7BC292B86A1C', '69C4A33B9AD29AF883D60BA61CC08702', 'F4FD40A716F1572C9A28E9CAA58BE3A5', '259A6F6DFD672CB1F883CBEC01B99F2D', '6431A618DCF7F4CB7F62A95A39BAB77A', '3121F7240D488F74EEED9312E174B217', '54208B51D44E7D91DC2F3DD02ADEDEC2', 'DBEEFB80F8A314311E2B4BD593E11DFE', 'B6D90127A09AB1229731898AEF9D4D7C', 'F3E1016563360F9434FA986CA86C249C', '2216D01F7B48554E4211021A46816FCF', '1BC639981AE88E09129594B11F894A21', 'C942E369C88CE7C56E69A84D04319FF0', '57ADD4576E2AD6648E9B2DE32F3462A5', 'AC1F0671A4B0D5B8112F87DE7B490E6D', 'C2EF5FABE7619D8A333D5F0FF76E1BFA', 'AA0254541959271ED3453119B787D0C3', 'A6B70CDF8C7B934D4A218CA9B6B7FDB4', 'BF477808A37E3E4E9C5D9F1839E8519E', '97F81BD92A1ACA3F1F43C154E689350F', '60A3DB168094D41241E45E0DE3539BC0', '12D8CEB94F89D11D7EB95EAE9689B009', 'F73266A79468BB89C4325FDEDB0B533C', '4690215948DBF6872B8ED1C2BC87B17E', 'D18801336202297E6484F634CAC6592E', '2E18F6F53E3CF073911AF0A93BBE5373', 'B2235C8B73239FDC5780DD132419833A', '515E873C86EE1577E75FA2387B7FA59E',]

# dfval.twttyp.value_counts().compute()
# TopLevel    2932
# Retweet      994
# Quote        213
twttyps=['TopLevel','Retweet','Quote']

# %% [markdown]
# ## prep func

# %%
def prp_df(df, istrn=True):
    tm_min = MIN_TM_TRN if istrn else MIN_TM_TST
    df['len_toks'] = df.toks.apply(len)
    for media in ['Photo', 'Video', 'GIF']:
        df[f'has_media_{media}'] = df.media.fillna('').apply(lambda x: media in x)
    for col in ['hshtgs', 'links', 'domns',]:
        df[f'num_{col}'] = df[col].fillna('').apply(lambda x: len(x.split('\t')) if len(x) else 0)
    
    df['twt_age'] = df.tm - tm_min
    df['u1_age']  = df.tm - df.u1_create_tm
    df['u2_age']  = df.tm - df.u2_create_tm
        
    tm_dt=pd.to_datetime(df.tm, unit='s')
    df['tm_dayofweek']=tm_dt.dt.dayofweek
    df['tm_hour']=tm_dt.dt.hour
    
    df['tmdlta_u2u1']  = df.u2_create_tm - df.u1_create_tm
    
    df['u1_fllwer_cnt_by_age'] = df.u1_fllwer_cnt / df.u1_age
    df['u1_fllwng_cnt_by_age'] = df.u2_fllwng_cnt / df.u2_age
    
    for typ in twttyps:
        df[f'twttyp_{typ}']=(df.twttyp==typ).astype('int8')

    for lang in langs:
        df[f'lang_{lang}']=(df.lang==lang).astype('int8')
    if istrn: 
        df[cols_tgt]=df[cols_tgt_tmstmp].notna().astype('int8')
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 
                                       'tm', 'u1_create_tm','u2_create_tm', 'u1id', 'u2id', 'twtid', ]+cols_tgt_tmstmp, )
    else:
        df.drop(inplace=True, columns=['toks', 'hshtgs', 'media', 'links', 'domns', 'twttyp', 'lang', 
                                       'tm', 'u1_create_tm','u2_create_tm', 'u1id', ])        
    return df

# %% [raw]
# ls -hlS $p_in | grep {trntmstmp}

# %%
grand_total, grand_total/1e6
# Out:
# (150000000.0, 150.0)

# %% [markdown]
# ## valid data

# %%
chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                    header=None,names=cols, 
                        chunksize=1e6)
# first chunk as validate data
for ichnk,df in enumerate(chnks_trn):
    print(dtnow(), 'chunk', ichnk)
    print([datetime.datetime.fromtimestamp(o).strftime('%Y-%m-%d %H:%M:%S') 
           for o in (df.tm.min(), df.tm.max())])
    dfvalid = prp_df(df)
    break
dfvalid.shape

cols_feat=[o for o in dfvalid.columns if o not in cols_tgt]

# Xvl,yvl=dfvl[cols_feat],dfvl[cols_tgt]
# Out:
# 2020-03-23 03:08:35 chunk 0
# ['2020-02-06 00:00:00', '2020-02-12 23:59:59']

# %% [markdown]
# ## trnval data func

# %%
tgt=tgts[1]
tgtcol=tgt2col[tgt]

chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                    header=None,names=cols, 
                        chunksize=1e6)
len_df_wanted = int(1e6)
# retwt          0.113031
# reply          0.027488
# like           0.439499
# retwt_cmmnt    0.007742
pos_rate_wanted = 0.1
n_pos_wanted = int(len_df_wanted*pos_rate_wanted)
print('n_pos_wanted', n_pos_wanted)
np.random.seed(SEED)
lst_df = []
n_pos_ttl = 0
for ichnk,df in enumerate(chnks_trn):
    #skip first chunk (it was validate data)
    if ichnk==0: continue
    print(dtnow(), 'chunk', ichnk)
    df = prp_df(df)
    n_pos_ttl+= df[tgtcol].sum()
    lst_df.append(df)
    if n_pos_ttl>=n_pos_wanted: break

df = pd.concat(lst_df)
df.reset_index(drop=True,inplace=True)


# https://stackoverflow.com/questions/28556942/pandas-remove-rows-at-random-without-shuffling-dataset
idx_neg=np.where(df[tgtcol]==0)[0]
n_neg = len(idx_neg)
n_pos = len(df)-len(idx_neg)
n_neg2keep = len_df_wanted-n_pos
n_neg2rmv = n_neg-n_neg2keep
idx_neg2rmv = np.random.choice(idx_neg, n_neg2rmv, replace=False)
dftrvl = df.drop(idx_neg2rmv)
print('dftrvl.shape:',dftrvl.shape,'dftrvl[tgtcol].mean():',dftrvl[tgtcol].mean())

pops={
    'train_pop':len(df),
    'target_pop':n_pos,
    'sampled_train_pop':len_df_wanted,
    'sampled_target_pop':n_pos,
}
print(pops)
# Out:
# n_pos_wanted 1000
# 2020-03-23 03:08:49 chunk 1
# 2020-03-23 03:08:49 chunk 2
# 2020-03-23 03:08:50 chunk 3
# 2020-03-23 03:08:50 chunk 4
# dftrvl.shape: (10000, 95) dftrvl[tgtcol].mean(): 0.1103
# {'train_pop': 40000, 'target_pop': 1103, 'sampled_train_pop': 10000, 'sampled_target_pop': 1103}

# %%
dftrvl.head()
# Out:
#     u1_fllwer_cnt  u1_fllwng_cnt  u1_vrfed  u2_fllwer_cnt  u2_fllwng_cnt  \
# 6        69943477          60576      True             79            127
# 10         300595            822      True            101            914
# 20            809            499     False           1556            810
# 22         162028            257     False            138            360
# 23        3226988              1      True              0            195
#
#     u2_vrfed  u1_fllw_u2  len_toks  has_media_Photo  has_media_Video  ...  \
# 6      False       False        19            False            False  ...
# 10     False       False       301             True            False  ...
# 20     False        True       131             True            False  ...
# 22     False       False        49            False            False  ...
# 23     False       False       416             True            False  ...
#
#     lang_F73266A79468BB89C4325FDEDB0B533C  \
# 6                                       0
# 10                                      0
# 20                                      0
# 22                                      0
# 23                                      0
#
#     lang_4690215948DBF6872B8ED1C2BC87B17E  \
# 6                                       0
# 10                                      0
# 20                                      0
# 22                                      0
# 23                                      0
#
#     lang_D18801336202297E6484F634CAC6592E  \
# 6                                       0
# 10                                      0
# 20                                      0
# 22                                      0
# 23                                      0
#
#     lang_2E18F6F53E3CF073911AF0A93BBE5373  \
# 6                                       0
# 10                                      0
# 20                                      0
# 22                                      0
# 23                                      0
#
#     lang_B2235C8B73239FDC5780DD132419833A  \
# 6                                       0
# 10                                      0
# 20                                      0
# 22                                      0
# 23                                      0
#
#     lang_515E873C86EE1577E75FA2387B7FA59E  retwt  reply  like  retwt_cmmnt
# 6                                       0      0      0     1            0
# 10                                      0      0      0     1            0
# 20                                      0      0      1     1            0
# 22                                      0      1      1     1            0
# 23                                      0      0      0     0            0
#
# [5 rows x 95 columns]

# %%
# df.columns

# %%
dftrvl = dftrvl.sample(len(dftrvl))

# %%
# tgt2ytr={tgt:ytr.iloc[:,i] for i,tgt in enumerate(tgts)}
# tgt2yvl={tgt:yvl.iloc[:,i] for i,tgt in enumerate(tgts)}

# %%
def getdftrvl(tgt):
    print(tgt)
    tgtcol=tgt2col[tgt]
    chnks_trn = pd.read_csv(f'{p_in}/trn_{trntmstmp}.tsv',sep='\x01',
                        header=None,names=cols, 
                            chunksize=1e4)
    len_df_wanted = int(1e4)
    # retwt          0.113031
    # reply          0.027488
    # like           0.439499
    # retwt_cmmnt    0.007742
    pos_rate_wanted = 0.1
    n_pos_wanted = int(len_df_wanted*pos_rate_wanted)
    print('n_pos_wanted', n_pos_wanted)
    np.random.seed(SEED)
    lst_df = []
    n_pos_ttl = 0
    for ichnk,df in enumerate(chnks_trn):
        #skip first chunk (it was validate data)
        if ichnk==0: continue
        print(dtnow(), 'chunk', ichnk)
        df = prp_df(df)
        n_pos_ttl+= df[tgtcol].sum()
        lst_df.append(df)
        if n_pos_ttl>=n_pos_wanted: break

    df = pd.concat(lst_df)
    df.reset_index(drop=True,inplace=True)


    # https://stackoverflow.com/questions/28556942/pandas-remove-rows-at-random-without-shuffling-dataset
    idx_neg=np.where(df[tgtcol]==0)[0]
    n_neg = len(idx_neg)
    n_pos = len(df)-len(idx_neg)
    n_neg2keep = len_df_wanted-n_pos
    n_neg2rmv = n_neg-n_neg2keep
    idx_neg2rmv = np.random.choice(idx_neg, n_neg2rmv, replace=False)
    dftrvl = df.drop(idx_neg2rmv)
    dftrvl = dftrv.sample(len(dftrvl))
    print('dftrvl.shape:',dftrvl.shape,'dftrvl[tgtcol].mean():',dftrvl[tgtcol].mean())
    print('dftr.shape:',dftr.shape,'dftr[tgtcol].mean():',dftr[tgtcol].mean())

    pops={
        'train_pop':len(df),
        'target_pop':n_pos,
        'sampled_train_pop':len_df_wanted,
        'sampled_target_pop':n_pos,
    }
    print(pops)
    return dftr, pops

# %% [markdown]
# # model

# %%
def train(params,dtr,dvl):
    print(params)
    evals_result = {}
    evallist = [(dtr, 'train'), (dvl, 'eval')]
    bst = xgb.train(params=params, dtrain=dtr, num_boost_round=100,#1000, 
                    evals=evallist, evals_result=evals_result, 
                    verbose_eval=50,
                    early_stopping_rounds=50)
    return bst,evals_result

def valid(bst,dtr,dvl):
    prdtr = bst.predict(dtr, ntree_limit=bst.best_ntree_limit)
    prdvl = bst.predict(dvl, ntree_limit=bst.best_ntree_limit)
    return prdtr,prdvl

def do_tgt(tgt):
    params=tgt2params[tgt]
    tgtcol=tgt2col[tgt]
    split=int(len(dftrvl)*0.85)
    dftr,dfvl=dftrvl[:split],dftrvl[split:]
    dtr = xgb.DMatrix(dftr[cols_feat], label=dftr[tgtcol], feature_names=cols_feat)
    dvl = xgb.DMatrix(dfvl[cols_feat], label=dfvl[tgtcol], feature_names=cols_feat)
    bst,evals_result=train(params,dtr,dvl)
    prdtr,prdvl=valid(bst,dtr,dvl)
    tgt2bst[tgt]=bst
    tgt2evalres[tgt]=evals_result
    tgt2ytr[tgt]=dftr[tgtcol]
    tgt2yvl[tgt]=dfvl[tgtcol]
    tgt2prdtr[tgt]=prdtr
    tgt2prdvl[tgt]=prdvl

# %%
tgt2params = {k:{'objective': 'binary:logistic',
    'verbosity': 1,
    'eval_metric': ['logloss', 'aucpr',],
} for k in tgts}

tgt2bst={}
tgt2evalres={}
tgt2ytr={}
tgt2yvl={}
tgt2prdtr={}
tgt2prdvl={}
for tgt in tgts:
    print(dtnow(), tgt)
    do_tgt(tgt)
    
pickle.dump(tgt2bst, open(f"{p_out}/tgt2bst.p", "wb"))
# Out:
# 2020-03-23 03:12:30 Retweet
# (8500, 95) (1500, 95)
# {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['logloss', 'aucpr']}
# [0]	train-logloss:0.52716	train-aucpr:0.32767	eval-logloss:0.53056	eval-aucpr:0.21264
# Multiple eval metrics have been passed: 'eval-aucpr' will be used for early stopping.
#
# Will train until eval-aucpr hasn't improved in 50 rounds.
# [50]	train-logloss:0.16493	train-aucpr:0.91193	eval-logloss:0.31782	eval-aucpr:0.26730
# Stopping. Best iteration:
# [21]	train-logloss:0.23424	train-aucpr:0.68084	eval-logloss:0.30771	eval-aucpr:0.29085
#
# 2020-03-23 03:12:31 Reply
# (8500, 95) (1500, 95)
# {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['logloss', 'aucpr']}
# [0]	train-logloss:0.52419	train-aucpr:0.34541	eval-logloss:0.53116	eval-aucpr:0.28901
# Multiple eval metrics have been passed: 'eval-aucpr' will be used for early stopping.
#
# Will train until eval-aucpr hasn't improved in 50 rounds.
# [50]	train-logloss:0.15274	train-aucpr:0.91210	eval-logloss:0.33359	eval-aucpr:0.28118
# Stopping. Best iteration:
# [13]	train-logloss:0.23969	train-aucpr:0.61609	eval-logloss:0.31469	eval-aucpr:0.31780
#
# 2020-03-23 03:12:32 Like
# (8500, 95) (1500, 95)
# {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['logloss', 'aucpr']}
# [0]	train-logloss:0.65387	train-aucpr:0.64289	eval-logloss:0.66477	eval-aucpr:0.54341
# Multiple eval metrics have been passed: 'eval-aucpr' will be used for early stopping.
#
# Will train until eval-aucpr hasn't improved in 50 rounds.
# [50]	train-logloss:0.40211	train-aucpr:0.92834	eval-logloss:0.66524	eval-aucpr:0.55178
# Stopping. Best iteration:
# [3]	train-logloss:0.59917	train-aucpr:0.69095	eval-logloss:0.63778	eval-aucpr:0.59215
#
# 2020-03-23 03:12:33 RTwCmnt
# (8500, 95) (1500, 95)
# {'objective': 'binary:logistic', 'verbosity': 1, 'eval_metric': ['logloss', 'aucpr']}
# [0]	train-logloss:0.44583	train-aucpr:0.01237	eval-logloss:0.44658	eval-aucpr:0.03563
# Multiple eval metrics have been passed: 'eval-aucpr' will be used for early stopping.
#
# Will train until eval-aucpr hasn't improved in 50 rounds.
# [50]	train-logloss:0.00423	train-aucpr:1.00000	eval-logloss:0.06981	eval-aucpr:0.00904
# Stopping. Best iteration:
# [0]	train-logloss:0.44583	train-aucpr:0.01237	eval-logloss:0.44658	eval-aucpr:0.03563

# %% [markdown]
# # analyze

# %% [markdown]
# ## tr vl

# %%
for tgt in tgt2evalres:
    evalres=tgt2evalres[tgt]
    plt.plot(evalres['train']['logloss'][10:])
    plt.plot(evalres['eval']['logloss'][10:])
    plt.title(f"{tgt} logloss {len(evalres['train']['logloss'])} rounds")
    plt.show()
    plt.plot(evalres['train']['aucpr'])
    plt.plot(evalres['eval']['aucpr'])
    plt.title(f"{tgt} aucpr {len(evalres['train']['aucpr'])} rounds")
    plt.show()

# %%
def show_feat_importance(tgt):
    bst=tgt2bst[tgt]
    ax = xgb.plot_importance(bst, height=0.8, max_num_features=9)
    ax.grid(False, axis="y")
    ax.set_title(f'{tgt} Estimated feature importance')
    plt.show()
    feat2importance=bst.get_fscore()
    print(tgt)
    display(pd.DataFrame([feat2importance.keys(), 
                          feat2importance.values()]).T.sort_values(1, ascending=False))

for tgt in tgt2bst:
    show_feat_importance(tgt)
# Out:
# Retweet
#                                         0    1
# 4                                len_toks  189
# 5                                  u1_age  188
# 7                           u1_fllwer_cnt  165
# 13                                 u2_age  161
# 1                    u1_fllwng_cnt_by_age  155
# 6                                 twt_age  153
# 14                          u1_fllwng_cnt  151
# 11                   u1_fllwer_cnt_by_age  151
# 12                          u2_fllwng_cnt  151
# 2                           u2_fllwer_cnt  144
# 10                            tmdlta_u2u1  131
# 15                                tm_hour  106
# 25                           tm_dayofweek   36
# 9                              num_hshtgs   35
# 16                         twttyp_Retweet   19
# 21  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   17
# 20                        has_media_Video   15
# 22  lang_22C448FF81263D4BAF2A176145EE9EAD   14
# 27                        has_media_Photo   13
# 0   lang_022EC308651FACB02794A8147AEE1B78   13
# 17                             u1_fllw_u2   12
# 28  lang_4DC22C3F31C5C43721E6B5815A595ED6   11
# 23                               u1_vrfed    8
# 26                        twttyp_TopLevel    8
# 3   lang_125C57F4FA6D4E110983FB11B52EFD4E    7
# 30  lang_3820C29CBCA409A33BADF68852057C4A    6
# 33  lang_06D61DCBBE938971E1EA0C38BD9B5446    6
# 32  lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D    5
# 29  lang_167115458A0DBDFF7E9C0C53A83BAC9B    5
# 19  lang_975B38F44D65EE42A547283787FF5A21    5
# 24                           twttyp_Quote    5
# 18                              num_links    4
# 31  lang_B9175601E87101A984A50F8A62A1C374    3
# 35  lang_ECED8A16BE2A5E8871FD55F4842F16B1    3
# 34                          has_media_GIF    2
# 37  lang_9BF3403E0EB7EA8A256DA9019C0B0716    2
# 8   lang_1FFD2FE4297F5E70EBC6C3230D95CB9C    1
# 36  lang_FF60A88F53E63000266F8B9149E35AD9    1
# Reply
#                                         0    1
# 3                           u2_fllwer_cnt  195
# 10                   u1_fllwng_cnt_by_age  169
# 17                            tmdlta_u2u1  168
# 8                                len_toks  167
# 18                                twt_age  155
# 6                           u1_fllwng_cnt  152
# 9                    u1_fllwer_cnt_by_age  145
# 5                                  u1_age  142
# 2                                  u2_age  125
# 4                           u2_fllwng_cnt  124
# 7                           u1_fllwer_cnt  115
# 14                                tm_hour   87
# 16                           tm_dayofweek   35
# 13                             num_hshtgs   23
# 0                          twttyp_Retweet   21
# 15  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   16
# 23                              num_links   13
# 12  lang_9BF3403E0EB7EA8A256DA9019C0B0716   12
# 27                        twttyp_TopLevel   11
# 1                              u1_fllw_u2   11
# 33                        has_media_Photo   10
# 25  lang_22C448FF81263D4BAF2A176145EE9EAD   10
# 11  lang_9ECD42BC079C20F156F53CB3B99E600E    8
# 28  lang_125C57F4FA6D4E110983FB11B52EFD4E    8
# 22  lang_FA3F382BC409C271E3D6EAF8BE4648DD    8
# 19  lang_ECED8A16BE2A5E8871FD55F4842F16B1    7
# 30  lang_B9175601E87101A984A50F8A62A1C374    7
# 24  lang_4DC22C3F31C5C43721E6B5815A595ED6    6
# 21  lang_167115458A0DBDFF7E9C0C53A83BAC9B    5
# 31                        has_media_Video    4
# 34                               u1_vrfed    4
# 29  lang_06D61DCBBE938971E1EA0C38BD9B5446    3
# 35  lang_2996EB2FE8162C076D070A4C8D6532CD    1
# 26  lang_FF60A88F53E63000266F8B9149E35AD9    1
# 32  lang_022EC308651FACB02794A8147AEE1B78    1
# 20  lang_48236EC80FDDDFADE99420ABC9210DDF    1
# 36                           twttyp_Quote    1
# Like
#                                         0    1
# 3                                len_toks  193
# 7                           u2_fllwer_cnt  178
# 6                                 twt_age  176
# 16                          u1_fllwng_cnt  175
# 4                                  u2_age  168
# 11                                 u1_age  162
# 14                   u1_fllwer_cnt_by_age  151
# 2                    u1_fllwng_cnt_by_age  147
# 8                           u2_fllwng_cnt  137
# 12                          u1_fllwer_cnt  134
# 5                             tmdlta_u2u1  133
# 18                                tm_hour   78
# 10                           tm_dayofweek   34
# 21                        has_media_Photo   19
# 22                             num_hshtgs   19
# 0                          twttyp_Retweet   17
# 1                               num_links   16
# 20                        has_media_Video   16
# 23                        twttyp_TopLevel   14
# 29  lang_06D61DCBBE938971E1EA0C38BD9B5446   11
# 31                             u1_fllw_u2   11
# 19  lang_022EC308651FACB02794A8147AEE1B78   11
# 17  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   10
# 9   lang_9BF3403E0EB7EA8A256DA9019C0B0716   10
# 15                               u1_vrfed    9
# 28  lang_22C448FF81263D4BAF2A176145EE9EAD    8
# 30  lang_167115458A0DBDFF7E9C0C53A83BAC9B    6
# 25  lang_ECED8A16BE2A5E8871FD55F4842F16B1    6
# 27  lang_3E16B11B7ADE3A22DDFC4423FBCEAD5D    4
# 24  lang_B9175601E87101A984A50F8A62A1C374    4
# 13  lang_125C57F4FA6D4E110983FB11B52EFD4E    3
# 32  lang_FA3F382BC409C271E3D6EAF8BE4648DD    3
# 37  lang_4DC22C3F31C5C43721E6B5815A595ED6    3
# 26                           twttyp_Quote    2
# 33                          has_media_GIF    2
# 34  lang_AEF22666801F0A5846D853B9CEB2E327    2
# 36  lang_FF60A88F53E63000266F8B9149E35AD9    2
# 35  lang_3820C29CBCA409A33BADF68852057C4A    1
# 38  lang_06BEAB41D66CCFF329D1ED8BA120A6C2    1
# RTwCmnt
#                                         0    1
# 1                                 twt_age  101
# 8                           u2_fllwer_cnt   77
# 0                           u2_fllwng_cnt   75
# 11                          u1_fllwng_cnt   75
# 3                             tmdlta_u2u1   71
# 9                                  u1_age   58
# 5                                len_toks   56
# 10                   u1_fllwng_cnt_by_age   54
# 2                                 tm_hour   51
# 6                           u1_fllwer_cnt   51
# 7                                  u2_age   49
# 15                   u1_fllwer_cnt_by_age   47
# 24  lang_D3164C7FBCF2565DDF915B1B3AEFB1DC   10
# 23                           tm_dayofweek    7
# 4                              num_hshtgs    7
# 13                           twttyp_Quote    6
# 22                        has_media_Video    6
# 25  lang_22C448FF81263D4BAF2A176145EE9EAD    5
# 16                         twttyp_Retweet    4
# 19                        twttyp_TopLevel    4
# 21                             u1_fllw_u2    4
# 17  lang_167115458A0DBDFF7E9C0C53A83BAC9B    3
# 18  lang_06D61DCBBE938971E1EA0C38BD9B5446    3
# 26                        has_media_Photo    3
# 14  lang_975B38F44D65EE42A547283787FF5A21    2
# 12  lang_717293301FE296B0B61950D041485825    2
# 20  lang_B9175601E87101A984A50F8A62A1C374    1
# 27                               u1_vrfed    1
# 28  lang_ECED8A16BE2A5E8871FD55F4842F16B1    1

# %%
tgt2auc_trn={}
tgt2rce_trn={}
tgt2auc_val={}
tgt2rce_val={}
for tgt in tgt2bst:
    print(tgt)
    prdtr_i, prdvl_i = tgt2prdtr[tgt], tgt2prdvl[tgt]
    ytr_i, yvl_i = tgt2ytr[tgt], tgt2yvl[tgt]
    scr_auc_trn=compute_prauc(prdtr_i, ytr_i)
    scr_rce_trn=compute_rce(prdtr_i, ytr_i)
    scr_auc_val=compute_prauc(prdvl_i, yvl_i)
    scr_rce_val=compute_rce(prdvl_i, yvl_i)

    tgt2auc_trn[tgt]=scr_auc_trn
    tgt2rce_trn[tgt]=scr_rce_trn
    tgt2auc_val[tgt]=scr_auc_val
    tgt2rce_val[tgt]=scr_rce_val
    
    print('train prauc:', f'{scr_auc_trn:.4f}','train rce:', f'{scr_rce_trn:.4f}', )
    print('valid prauc:', f'{scr_auc_val:.4f}','valid rce:', f'{scr_rce_val:.4f}', )
# Out:
# Retweet
# train prauc: 0.6808 train rce: 32.7350
# valid prauc: 0.2907 valid rce: 9.3623
# Reply
# train prauc: 0.6161 train rce: 30.4325
# valid prauc: 0.3174 valid rce: 12.9676
# Like
# train prauc: 0.6915 train rce: 12.5679
# valid prauc: 0.5927 valid rce: 5.7397
# RTwCmnt
# train prauc: 0.1362 train rce: -845.3308
# valid prauc: 0.2067 valid rce: -743.9455

# %%
lsttrn=[]
lstval=[]
for tgt in ['Retweet','Reply','Like','RTwCmnt',]:
    if tgt not in tgt2bst: continue
    lsttrn+=[(f'PRAUC {tgt}',tgt2auc_trn[tgt]),
          (f'RCE {tgt}',tgt2rce_trn[tgt])]
    lstval+=[(f'PRAUC {tgt}',tgt2auc_val[tgt]),
          (f'RCE {tgt}',tgt2rce_val[tgt])]

dfscrtrn=pd.DataFrame(lsttrn)
dfscrtrn.columns=['metric','scr']
dfscrval=pd.DataFrame(lstval)
dfscrval.columns=['metric','scr']
dfscr = pd.merge(dfscrtrn, dfscrval, on='metric', suffixes=('trn','val'))
dfscr.T
# Out:
#                     0            1            2          3           4  \
# metric  PRAUC Retweet  RCE Retweet  PRAUC Reply  RCE Reply  PRAUC Like
# scrtrn       0.680841       32.735      0.61609    30.4325    0.691478
# scrval       0.290706      9.36226     0.317359    12.9676    0.592704
#
#                5              6            7
# metric  RCE Like  PRAUC RTwCmnt  RCE RTwCmnt
# scrtrn   12.5679       0.136246     -845.331
# scrval   5.73974       0.206714     -743.946

# %% [markdown]
# ## valid

# %% [markdown]
# # infer

# %% [raw]
# ls -lhS $p_in | grep val

# %%
# %%time
dftst=pd.read_csv(
    f'{p_in}/val_{valtmstmp}.tsv',
#     f'{p_in}/val_259A6F6DFD672CB1F883CBEC01B99F2D_1584405047.tsv',
    sep='\x01', header=None, names=cols_val,)
# Out:
# CPU times: user 1min 28s, sys: 12.6 s, total: 1min 41s
# Wall time: 2min 34s

# %%
# %%time
dftst = prp_df(dftst, istrn=False)
# Out:
# CPU times: user 1min 42s, sys: 13.9 s, total: 1min 56s
# Wall time: 2min 6s

# %%
# %%time
dtst = xgb.DMatrix(dftst[cols_feat], feature_names=cols_feat)
tgt2prdtst={}
for tgt in tgts:
    print(dtnow(), tgt)
    bst = tgt2bst[tgt]
    tgt2prdtst[tgt] = bst.predict(dtst)
# Out:
# 2020-03-22 16:15:47 Retweet
# 2020-03-22 16:16:25 Reply
# 2020-03-22 16:16:41 Like
# 2020-03-22 16:18:54 RTwCmnt
# CPU times: user 24min 3s, sys: 31 s, total: 24min 34s
# Wall time: 5min 16s

# %%
dfsub_ids = dftst[['twtid','u2id',]]

tgt2dfsub = {}
for tgt,prdtst in tgt2prdtst.items():
    dfsub = dfsub_ids.copy()
    dfsub['scr'] = prdtst
    tgt2dfsub[tgt]=dfsub

# %%
# %%time
for i,tgt in enumerate(['Retweet','Reply','RTwCmnt','Like',]):
    dfsub = tgt2dfsub[tgt]
    print(dtnow(), tgt)
    dfsub.to_csv(f'{p_out}/{i}_{tgt}__{valtmstmp}__{PRFX}.csv',index=False,header=False)
# Out:
# 2020-03-22 16:32:10 Retweet
# 2020-03-22 16:34:07 Reply
# 2020-03-22 16:36:02 RTwCmnt
# 2020-03-22 16:37:55 Like
# CPU times: user 6min 27s, sys: 7.74 s, total: 6min 34s
# Wall time: 7min 37s
